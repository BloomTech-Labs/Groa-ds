# %%
import numpy as np
import pandas as pd

# %%
url = 'https://datasets.imdbws.com/title.basics.tsv.gz'

# %%
df = pd.read_table(url, sep='\t')
# Out:
# /home/ericsmith/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(5)
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult startYear endYear runtimeMinutes                    genres
# 0        0      1894      \N              1         Documentary,Short
# 1        0      1892      \N              5           Animation,Short
# 2        0      1892      \N              4  Animation,Comedy,Romance
# 3        0      1892      \N             \N           Animation,Short
# 4        0      1893      \N              1              Comedy,Short

# %%
df = df[df['titleType'] == "movie"]

# %%
df.head(5)
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry        0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight        0      1897      \N             20
# 332          Soldiers of the Cross        0      1900      \N             \N
# 499                       Bohemios        0      1905      \N            100
# 571    The Story of the Kelly Gang        0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# ...

# %%
dfUniqueMovies = df.drop_duplicates(subset=['tconst'], keep='first')

# %%
893905
# Out:
# 893905

# %%
len(dfUniqueMovies)
# Out:
# 538267

# %%
dfUniqueMovies.head(5)
# Out:
#         tconst titleType                   primaryTitle  \
# 8    tt0000009     movie                     Miss Jerry
# 145  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 332  tt0000335     movie          Soldiers of the Cross
# 499  tt0000502     movie                       Bohemios
# 571  tt0000574     movie    The Story of the Kelly Gang
#
#                      originalTitle  isAdult startYear endYear runtimeMinutes  \
# 8                       Miss Jerry        0      1894      \N             45
# 145  The Corbett-Fitzsimmons Fight        0      1897      \N             20
# 332          Soldiers of the Cross        0      1900      \N             \N
# 499                       Bohemios        0      1905      \N            100
# 571    The Story of the Kelly Gang        0      1906      \N             70
#
#                      genres
# 8                   Romance
# 145  Documentary,News,Sport
# 332         Biography,Drama
# 499                      \N
# ...

# %%
dfUniqueMovies = dfUniqueMovies.replace(r'\N', np.NaN)

# %%
dfUniqueMovies
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 145      tt0000147     movie
# 332      tt0000335     movie
# 499      tt0000502     movie
# 571      tt0000574     movie
# ...            ...       ...
# 6383420  tt9916622     movie
# 6383447  tt9916680     movie
# 6383459  tt9916706     movie
# 6383470  tt9916730     movie
# 6383481  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 145                          The Corbett-Fitzsimmons Fight
# 332                                  Soldiers of the Cross
# 499                                               Bohemios
# 571                            The Story of the Kelly Gang
# ...                                                    ...
# 6383420        Rodolpho Teóphilo - O Legado de um Pioneiro
# 6383447  De la ilusión al desconcierto: cine colombiano...
# 6383459                                    Dankyavar Danka
# ...

# %%
dfUniqueMovies['runtimeMinutes'].dropna()
# Out:
# 8           45
# 145         20
# 499        100
# 571         70
# 673        120
#           ...
# 6383379    123
# 6383420     57
# 6383447    100
# 6383470    116
# 6383481     49
# Name: runtimeMinutes, Length: 341088, dtype: object

# %%
filtered_df = dfUniqueMovies[dfUniqueMovies['runtimeMinutes'].notnull()]
filtered_df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 145      tt0000147     movie
# 499      tt0000502     movie
# 571      tt0000574     movie
# 673      tt0000679     movie
# ...            ...       ...
# 6383379  tt9916538     movie
# 6383420  tt9916622     movie
# 6383447  tt9916680     movie
# 6383470  tt9916730     movie
# 6383481  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 145                          The Corbett-Fitzsimmons Fight
# 499                                               Bohemios
# 571                            The Story of the Kelly Gang
# 673                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 6383379                                Kuambil Lagi Hatiku
# 6383420        Rodolpho Teóphilo - O Legado de um Pioneiro
# 6383447  De la ilusión al desconcierto: cine colombiano...
# ...

# %%
filtered_df['runtimeMinutes'] = filtered_df['runtimeMinutes'].astype('int')
# Out:
# /home/ericsmith/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# filtered_df['runtimeMinutes'] = filtered_df['runtimeMinutes'] >= 70

# %%
filtered_df
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 145      tt0000147     movie
# 499      tt0000502     movie
# 571      tt0000574     movie
# 673      tt0000679     movie
# ...            ...       ...
# 6383379  tt9916538     movie
# 6383420  tt9916622     movie
# 6383447  tt9916680     movie
# 6383470  tt9916730     movie
# 6383481  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 145                          The Corbett-Fitzsimmons Fight
# 499                                               Bohemios
# 571                            The Story of the Kelly Gang
# 673                         The Fairylogue and Radio-Plays
# ...                                                    ...
# 6383379                                Kuambil Lagi Hatiku
# 6383420        Rodolpho Teóphilo - O Legado de um Pioneiro
# 6383447  De la ilusión al desconcierto: cine colombiano...
# ...

# %%
filtered_df['runtimeMinutes']
# Out:
# 8           45
# 145         20
# 499        100
# 571         70
# 673        120
#           ...
# 6383379    123
# 6383420     57
# 6383447    100
# 6383470    116
# 6383481     49
# Name: runtimeMinutes, Length: 341088, dtype: int64

# %%
# filtered_df['runtimeMinutes'] = filtered_df[filtered_df['runtimeMinutes'] >= 70]

# %%
long_movies = filtered_df[filtered_df['runtimeMinutes'] >= 70]

# %%
long_movies = long_movies[long_movies['isAdult'] == 0]

# %%
movieid = long_movies['tconst']
movieid.shape
# Out:
# (268651,)

# %%
# file = movieid.to_csv('./movieid.csv')
