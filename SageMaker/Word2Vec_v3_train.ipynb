# %% [markdown]
# # Word2Vec v2.5: "Mistake Not"

# %% [markdown]
# ## Connect to Database

# %%
! pip3 install psycopg2-binary --user
import pandas as pd
import psycopg2
import numpy as np
from getpass import getpass
# Out:
# Requirement already satisfied: psycopg2-binary in /home/ec2-user/.local/lib/python3.6/site-packages (2.8.4)
# You are using pip version 19.0.2, however version 20.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# connect to database
connection = psycopg2.connect(
    database  = "postgres",
    user      = "postgres",
    password  = getpass(),
    host      = "movie-rec-scrape.cvslmiksgnix.us-east-1.rds.amazonaws.com",
    port      = '5432'
)
# Enter database password below and press Enter.
# Out:
#  ················

# %%
# create cursor that is used throughout
try:
    c = connection.cursor()
    print("Connected!")
except:
    print("Connection problem chief!")
# Out:
# Connected!

# %% [markdown]
# ## Prepare data and train.
# 1. Get the list of reviewers whose reviews we want (about 17k)
# 2. Get the dataframe of reviewers, movie IDs with positive reviews
# 3. Inner join the above two dataframes.
# 4. Run the list constructor on the join table to construct the training data.
#     - Training data is of this format: [['movieid1', 'movieid2', ...], ...]
# 5. Train Word2Vec on the list of watch histories (which are themselves lists of movie IDs).
# 6. Save the model.

# %%
# Get reviewers with at least 10 positive reviews (rating 8-10 inclusive)
c.execute("""
select username
from reviews
where user_rating between 8 and 10
group by username
having count(username) >= 10
order by count(username) desc
""")

'''
Minimum rating for training data has been increased to 8 stars in v3_LimitingFactor.

Explanation: v2_MistakeNot is returning movies with an average rating of 7.66, 
which is towards the low end of the distribution in the training data. It might be 
near the mean, but we want our model to give the user an above-average movie experience.
'''
reviewers = c.fetchall()

# %%
len(reviewers)
# Out:
# 13641

# %%
# Get positive reviews from database
c.execute("SELECT movie_id, username FROM reviews WHERE user_rating BETWEEN 7 and 10")
result = c.fetchall()

'''
Training note: This query currently returns reviews in no discernible order.
This is because the reviews were inserted into the database by multiple scrapers
running in parallel.
Future users of this notebook should take care to note whether their database gives
the same result.
'''

# create reviews dataframe
df = pd.DataFrame(result, columns = ['movieid', 'userid'])
df.head()
# Out:
#    movieid             userid
# 0  0060188  alexanderwilson45
# 1  0060188     JohnHowardReid
# 2  0060189   thedevilprobably
# 3  0060196          manicmeuk
# 4  1727824       jacobtaylort

# %%
# create reviewers dataframe
df_reviewers = pd.DataFrame(reviewers, columns = ['userid'])

# %%
df_reviewers.shape
# Out:
# (13641, 1)

# %%
# merge to get only the IDs relevant to training
df = df.merge(df_reviewers, how='inner', on='userid')
df.shape
# Out:
# (766970, 2)

# %%
# ! sudo su
# ! yum update -y
# ! yum -y install python-pip
# ! python -V

# %%
# ! which pip

# %% [markdown]
# ### Install gensim

# %%
! python -m pip install tqdm
# ! python -c 'import tqdm'
! python -m pip install gensim
# Out:
# Requirement already satisfied: tqdm in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.41.1)
# You are using pip version 10.0.1, however version 20.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: gensim in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.8.1)
# Requirement already satisfied: six>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.1.0)
# Requirement already satisfied: numpy>=1.11.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.14.3)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.9.0)
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim) (1.10.19)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim) (2.20.0)
# Requirement already satisfied: boto>=2.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim) (2.48.0)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.4)
# Requirement already satisfied: botocore<1.14.0,>=1.13.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim) (1.13.19)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (2.6)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.14.0,>=1.13.19->boto3->smart-open>=1.8.1->gensim) (0.14)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.14.0,>=1.13.19->boto3->smart-open>=1.8.1->gensim) (2.7.3)
# You are using pip version 10.0.1, however version 20.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
from tqdm import tqdm
# list to capture watch history of the users
watched_train = []

# populate the list with the movie codes
for i in tqdm(reviewers):
    temp = df[df["userid"] == i[0]]["movieid"].tolist()
    watched_train.append(temp)
    
len(watched_train)
# Out:
# 100%|██████████| 13641/13641 [29:33<00:00,  7.69it/s]
# 13641

# %%
# save the model for later
import pickle
pickle.dump(watched_train, open('watched_train_3.sav', 'wb'))

# %%
# #save the model in protocol 2 so it can be opened in python 2.7
# import pickle
# temp = pickle.load(open('watched_train.sav', 'rb'))
# pickle.dump(temp, open('watched_train.sav', 'wb'), protocol=2)

# %% [markdown]
# ## Train the Model
#
# The first model was trained on movie IDs that were inside lists of length 1, with watch histories being lists of lists.
#
# This model eschews the inner lists. Each watch history is simply a list of strings.

# %%
import pickle
watched_train = pickle.load(open('watched_train_3.sav', 'rb'))
len(watched_train)
# Out:
# 13641

# %%
import random
from gensim.models import Word2Vec 
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings;
warnings.filterwarnings('ignore')

# train word2vec model
model = Word2Vec(window = 10, # perhaps increase this
                 sg = 1, # sets to skip-gram
                 hs = 0, # must be set to 0 for negative sampling
                 negative = 10, # for negative sampling
                 ns_exponent = 0.5, # 0.5 in best results
                 alpha=0.03, min_alpha=0.0007,
                 seed = 14,
                 sample = 0.0001 # 10^-4 in best results
                )

model.build_vocab(watched_train, progress_per=200)

model.train(watched_train, total_examples = model.corpus_count, 
            epochs=90, # best results set this 90-150
            report_delay=60, compute_loss=True)
# Out:
# (58221426, 69027300)

# %%
# save word2vec model
model.save("w2v_LimitingFactor_v2.model")

# %% [markdown]
# ## Test the model

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.8.1)
# Requirement already satisfied: smart-open>=1.8.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.9.0)
# Requirement already satisfied: scipy>=0.18.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.1.0)
# Requirement already satisfied: numpy>=1.11.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.14.3)
# Requirement already satisfied: six>=1.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from gensim) (1.11.0)
# Requirement already satisfied: boto3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim) (1.10.19)
# Requirement already satisfied: boto>=2.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim) (2.48.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from smart-open>=1.8.1->gensim) (2.20.0)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.2.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim) (0.9.4)
# Requirement already satisfied: botocore<1.14.0,>=1.13.19 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3->smart-open>=1.8.1->gensim) (1.13.19)
# Requirement already satisfied: idna<2.8,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (1.23)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->smart-open>=1.8.1->gensim) (2019.9.11)
# Requirement already satisfied: python-dateutil<2.8.1,>=2.1; python_version >= "2.7" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.14.0,>=1.13.19->boto3->smart-open>=1.8.1->gensim) (2.7.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.14.0,>=1.13.19->boto3->smart-open>=1.8.1->gensim) (0.14)
# You are using pip version 10.0.1, however version 20.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# load model

# model = gensim.models.Word2Vec.load("w2v_mistakenot.model") #make sure you specify the right model version.

# %% [markdown]
# ### Split data

# %%
import gensim
import pandas as pd
model.init_sims(replace=True) # prunes the model, making it faster but unable to train any more.
ratings = pd.read_csv('ratings.csv') # import my Letterboxd ratings
ratings.head()
ratings = ratings.dropna(axis=0, subset=['Rating', 'Name', 'Year'])

# set thresholds for minimum "good" rating and maximum "bad rating"
good_threshold = 4
bad_threshold = 3
good = ratings[ratings['Rating'] >= good_threshold]
bad = ratings[ratings['Rating'] <= bad_threshold]

# good_from_4 = ratings[ratings['Rating'] >= good_threshold]
good_from_3p5 = ratings[ratings['Rating'] >= 3.5]

# get watchlist for scoring the model
watchlist = pd.read_csv('watchlist.csv').dropna(axis=0, subset=['Name', 'Year'])

# get watch history sans ratings
full_history = pd.read_csv('watched.csv').dropna(axis=0, subset=['Name', 'Year'])

def df_to_id_list(df):
    """
    Input: dataframe of movies from my ratings.csv Letterboxd export
    
    Output: List of the IDs for those movies, ready for inferencing.
    """
    ids = []
    names = df.Name.tolist()
    names = [x.replace("'", "") for x in names]
    years = df.Year.tolist()
    years = [int(year) for year in years]
    info = list(zip(names, years))
    for i, j in info:
        try:
            c.execute(f"""
                SELECT movie_id
                FROM movies
                WHERE primary_title ILIKE '{i}' AND start_year = {j}
                ORDER BY runtime_minutes DESC
                LIMIT 1""")
            id = c.fetchone()[0]
            ids.append(id)
        except:
            continue
    return ids



# get ids from all lists, Dr. Seuss style
good_list = df_to_id_list(good)
bad_list = df_to_id_list(bad)
print("good and bad done")
val_list = df_to_id_list(watchlist)
hist_list = df_to_id_list(full_history)
print("histlist done")
good_3p5_list = df_to_id_list(good_from_3p5)
good_list_long = good_list[:int(len(good_list)/2)]
good_list_short = good_list[int(len(good_list)/2):]

print(len(good_list), len(bad_list), len(val_list), len(hist_list), len(good_3p5_list))
# Out:
# 377 179 1007 1095 519

# %% [markdown]
# ### Define inferencing functions

# %%
class ScoringService(object):
    model = None                # Where we keep the model when it's loaded
    
    @classmethod
    def get_model(cls):
        """Get the model object for this instance, loading it if it's not already loaded."""
        if cls.model == None:
            # load the gensim model
            w2v_model = gensim.models.Word2Vec.load("w2v_limitingfactor_v2.model")
            # keep only the normalized vectors.
            # This saves memory but makes the model untrainable (read-only).
            w2v_model.init_sims(replace=True)
            # with open(os.path.join(model_path, 'decision-tree-model.pkl'), 'r') as inp:
            #     cls.model = pickle.load(inp)
            cls.model = w2v_model
        return cls.model

    @classmethod
    def predict(cls, input, bad_movies=[], n=20, harshness=1, rec_movies=True, show_vibes=False, scoring=False):
        """Returns a list of recommendations and useful metadata, given a pretrained 
        word2vec model and a list of movies.

        Args:
            cls (.model object): The pretrained word2vec model.
            
            input (list of strings): The list of movies that the user likes.
            
            bad_movies (list of strings): The list of movies that the user dislikes.
            
            n (int): The number of recommendations to return.
            
        Output: A list of tuples: Title, Year, IMDb URL, Similarity score.
        """
        
        # get pretrained model
        clf = cls.get_model()
        
        # list for storing duplicates
        dupes = []

        def _aggregate_vectors(movies):
            """Gets the vector average of a list of movies."""
            movie_vec = []
            for i in movies:
                try:
                    movie_vec.append(clf[i]) # get the vector for each movie
                except KeyError:
                    continue
            return np.mean(movie_vec, axis=0)

        def _similar_movies(v, bad_movies=[], n = 10):
            """Takes aggregated vector of good movies, 
            and optionally, a list of disliked movies.
            Subtracts disliked movies.
            Returns most similar movies for the input vector
            
            n: number of recommendations to return."""
            if bad_movies:
                v = _remove_dislikes(bad_movies, v, input=input, harshness=harshness)
            return clf.similar_by_vector(v, topn= n+1)[1:]
            
        def _remove_dupes(recs, input, bad_movies):
            """remove any recommended IDs that were in the input list"""
            all_seen = input + bad_movies
            # if there is a full watch history list, use it to remove dupes
            if hist_list:
                all_seen = list(set(all_seen+hist_list))
            nonlocal dupes
            dupes = [x for x in recs if x[0] in all_seen]
            return [x for x in recs if x[0] not in all_seen]

        def _get_info(id):
            """Takes an id string and returns the movie info with a url."""
            try:
                c.execute(f"""
                select m.primary_title, m.start_year, r.average_rating, r.num_votes
                from movies m
                join ratings r on m.movie_id = r.movie_id
                where m.movie_id = '{id[0]}'""")
            except:
                return tuple([f"Movie title unknown. ID:{id[0]}", None, None, None, None, None])

            t = c.fetchone()
            if t:
                title = tuple([t[0], t[1], f"https://www.imdb.com/title/tt{id[0]}/", t[2], t[3], id[1]])
                return title
            else:
                return tuple([f"Movie title unknown. ID:{id[0]}", None, None, None, None, None])
            
                
        def _remove_dislikes(bad_movies, good_movies_vec, input=1, harshness=1):
            """Takes a list of movies that the user dislikes. 
            Their embeddings are averaged,
            and subtracted from the input."""
            bad_vec = _aggregate_vectors(bad_movies)
            bad_vec = bad_vec / harshness
            return good_movies_vec - bad_vec
        
        def _score_model(recs, val_list):
            ids = [x[0] for x in recs]
            return len(list(set(ids) & set(val_list)))

        aggregated = _aggregate_vectors(input)
        formatted_recs = []
        testable_number = 0
        while len(formatted_recs) < n:
            testable_number += n
            recs = _similar_movies(aggregated, bad_movies, n=testable_number)
            recs = _remove_dupes(recs, input, bad_movies)
            formatted_recs = [_get_info(x) for x in recs]
            print(len(formatted_recs))
        
        if scoring and val_list:
            print(f"The model recommended {_score_model(recs, val_list)} movies that were on the watchlist!\n")
            print(f"\t\t Average Rating: {sum([i[3] for i in formatted_recs if i[3] is not None])/len(formatted_recs)}\n")
        if show_vibes:
            print("Movies you're likely to vibe with people on: \n")
            for x in dupes:
                print(_get_info(x))
            print('\n')
        if rec_movies:
            return formatted_recs

# %% [markdown]
# ### Add test cases

# %%
# test cases

# A list of some Coen Bros movies.
coen_bros = ['116282', '2042568', '1019452', 
             '1403865', '190590', '138524', 
             '335245', '477348', '887883', '101410']

# Data scientist's recent watches.
cooper_recent = ['0053285', '0038650', '0046022', 
                 '4520988', '1605783', '6751668', 
                 '0083791', '0115685', '0051459', 
                 '8772262', '0061184', '0041959',
                 '7775622']

# dirkh public letterboxd recent watches.
dirkh = ['7975244', '8106534', '1489887', 
         '1302006', '7286456', '6751668', 
         '8364368', '2283362', '6146586', 
         '2194499', '7131622', '6857112']

# Marvin watches
marvin = ['7286456', '0816692', '2543164', '2935510', 
          '2798920', '0468569', '5013056', '1375666', 
          '3659388', '0470752', '0266915', '0092675', 
          '0137523', '0133093', '1285016']  

# Gabe watches
gabe = ['6292852','0816692','2737304','3748528',
        '3065204','4154796','1536537','1825683',
        '1375666','8236336','2488496','1772341',
        '0317705','6857112','5052448']

# Eric watches
eric = ['2974050','1595842','0118539','0093405',
        '3216920','1256535','5612742','3120314',
        '1893371','0046248','0058548','0199481',
        '2296777','0071198','0077834']

chuckie = ['4263482',
'0084787',
'3286052',
'5715874',
'1172994',
'4805316',
'3139756',
'8772262',
'7784604',
'1034415',]

harlan = ['1065073','5052448','0470752','5688932','1853728','1596363','0432283','6412452','4633694','9495224','0443453','0063823',
          '0066921','0405296','1130884','1179933','0120630','0268126','0137523','0374900','8772262','0116996','0107290','7339248']

ryan = ['0166924','2866360','0050825','2798920','3416742','0060827','1817273','0338013','0482571','5715874','2316411','4550098']

karyn = ['4425200','0464141','1465522','0093779','0099810','0076759','3748528','6763664','0317740','2798920','0096283','0258463','0118799','0058092','0107290','0045152','0106364']

richard = ['0074119','0064115','0070735','0080474','0061512','0067774','0057115','0070511','0081283',
           '0065126','0068421','0078227','0079100','0078966','0081696','0082085','0072431','0075784',
           '0093640','0098051','0094226','0097576','0099810','0081633','0080761','0077975','0085244','0095159','0101969']

joe = ['6335734','0291350','0113568','0208502','0169858','0095327','0097814','0983213','0094625','7089878']

lena = ['1990314','3236120','1816518','0241527','0097757','0268978','0467406','2543164','2245084','3741834']

wade = ['0118665','0270846','0288441','2287250','2287238','8668804','9448868','1702443','1608290','5519340']

# %% [markdown]
# ### Try test cases

# %%
s = ScoringService()

# define many parameter sets

# possible good inputs: cooper_recent (13 most recent), good_list(my 4-5 star ratings), good_3p5_list (my 3.5-5 star ratings)
# possible bad_movies: [] (not removing dislikes), bad_list(my ratings 3 and below), karyn (individual whose taste markedly differs from mine)
# possible harshness: 1, 2, 3 (harshness 1 strongly removes disliked movies, while harshness 3 removes with a third of the strength)

params = [
    (cooper_recent, [], 1), #1
    (cooper_recent, bad_list, 1),
    (cooper_recent, bad_list, 2),
    (cooper_recent, bad_list, 3),
    (good_list, [], 1), #5
    (good_list, bad_list, 1),
    (good_list, bad_list, 2),
    (good_list, bad_list, 3),
    (good_3p5_list, [], 1),
    (good_3p5_list, bad_list, 1), #10
    (good_3p5_list, bad_list, 2),
    (good_3p5_list, bad_list, 3),
    (cooper_recent, karyn, 1),
    (good_list, karyn, 1),
    (good_3p5_list, karyn, 1), #15
]

count = 0
# Test all parameter sets
for i, j, k in params:
    count+=1
    print(count, "\t")
    s.predict(input=i, bad_movies=j, n=20, harshness=k, rec_movies=True, show_vibes=False, scoring=True)
    
# Good performance for v2MistakeNot: 6, 7, 11
# Good performance for v3LimitingFactor: 3, 4, 6, 10, 14, 15

# Setting 6 seems robust to significant hyperparameter changes.
# Out:
# 1
# 13
# 24
# The model recommended 9 movies that were on the watchlist!
#
# 		 Average Rating: 7.6125
#
# 2
# 14
# 31
# The model recommended 8 movies that were on the watchlist!
#
# 		 Average Rating: 7.4483870967741925
#
# 3
# 13
# 28
# The model recommended 8 movies that were on the watchlist!
#
# 		 Average Rating: 7.535714285714286
#
# 4
# 12
# 26
# The model recommended 8 movies that were on the watchlist!
#
# 		 Average Rating: 7.630769230769231
#
# 5
# 1
# 4
# 6
# 9
# 15
# 22
# The model recommended 10 movies that were on the watchlist!
#
# 		 Average Rating: 7.968181818181818
#
# 6
# 10
# 25
# The model recommended 7 movies that were on the watchlist!
#
# 		 Average Rating: 7.587999999999999
#
# 7
# 0
# 5
# 10
# 19
# 27
# The model recommended 10 movies that were on the watchlist!
#
# 		 Average Rating: 7.862962962962962
#
# 8
# 0
# 3
# 9
# 12
# 20
# The model recommended 7 movies that were on the watchlist!
#
# 		 Average Rating: 7.970000000000001
#
# 9
# 2
# 3
# 5
# 8
# 13
# 17
# 24
# The model recommended 7 movies that were on the watchlist!
#
# 		 Average Rating: 7.866666666666668
#
# 10
# 11
# 24
# The model recommended 5 movies that were on the watchlist!
#
# 		 Average Rating: 7.6499999999999995
#
# 11
# 0
# 4
# 7
# 13
# 23
# The model recommended 8 movies that were on the watchlist!
#
# 		 Average Rating: 8.060869565217391
#
# 12
# 1
# 2
# 9
# 13
# 20
# The model recommended 6 movies that were on the watchlist!
#
# 		 Average Rating: 8.04
#
# 13
# 19
# 39
# The model recommended 6 movies that were on the watchlist!
#
# 		 Average Rating: 7.107692307692309
#
# 14
# 19
# 38
# The model recommended 3 movies that were on the watchlist!
#
# 		 Average Rating: 7.005263157894737
#
# 15
# 20
# The model recommended 2 movies that were on the watchlist!
#
# 		 Average Rating: 6.924999999999999

# %% [markdown]
# ## Best settings for LimitingFactor_v1

# %%
# focus on the best settings for LimitingFactor_v1
params = [
    (cooper_recent, bad_list, 2), #3
    (cooper_recent, bad_list, 3), #4
    (good_list, bad_list, 1), #6
    (good_3p5_list, bad_list, 1), #10
    (good_list, karyn, 1), #14
    (good_3p5_list, karyn, 1), #15
]

count = 0
settings = [3, 4, 6, 10, 14, 15]
# Test all the promising parameter sets
for i, j, k in params:
    print(settings[count], "\t")
    prediction = s.predict(input=i, bad_movies=j, n=100, harshness=k, rec_movies=True, show_vibes=False, scoring=True)
    for i in prediction:
        print(f"{i[0]}\t{i[1]}\n\t{i[2]}\n\tAvg. Rating: {i[3]}\n\t# Votes: {i[4]}\n\tSimilarity: {i[5]}\n\n")
    count+=1

"""
Settings graded out of 100:
3... 91
4... 86
6... 89 (lots of old stuff)
10.. 90
14.. 91
15.. 90

I'm inclined to pronounce model LimitingFactor_v1 a success, because it gives 
diverse and high-quality results in more cases than its predecessor.
In 6 cases it gives 20+ watchlisted movies, where before we only got 3.

In other words, it gives good results in cases where input data may be rich or sparse.

"""
# Out:
# 3
# The model recommended 23 movies that were on the watchlist!
#
# 		 Average Rating: 7.444999999999996
#
# Marriage Story	2019
# 	https://www.imdb.com/title/tt7653254/
# 	Avg. Rating: 8.1
# 	# Votes: 130590
# 	Similarity: 0.6401818990707397
#
#
# Joker	2019
# 	https://www.imdb.com/title/tt7286456/
# 	Avg. Rating: 8.6
# 	# Votes: 620299
# 	Similarity: 0.6330293416976929
#
#
# The Lighthouse	2019
# 	https://www.imdb.com/title/tt7984734/
# 	Avg. Rating: 7.8
# 	# Votes: 52091
# 	Similarity: 0.6307841539382935
#
#
# Apollo 11	2019
# 	https://www.imdb.com/title/tt8760684/
# 	Avg. Rating: 8.2
# 	# Votes: 15085
# 	Similarity: 0.6201057434082031
#
#
# Once Upon a Time... in Hollywood	2019
# 	https://www.imdb.com/title/tt7131622/
# 	Avg. Rating: 7.8
# 	# Votes: 342653
# 	Similarity: 0.6006509065628052
#
#
# Knives Out	2019
# 	https://www.imdb.com/title/tt8946378/
# 	Avg. Rating: 8.0
# 	# Votes: 124017
# 	Similarity: 0.6003093719482422
#
#
# A Star Is Born	2018
# 	https://www.imdb.com/title/tt1517451/
# 	Avg. Rating: 7.7
# 	# Votes: 293127
# 	Similarity: 0.5982445478439331
#
#
# The Favourite	2018
# 	https://www.imdb.com/title/tt5083738/
# 	Avg. Rating: 7.6
# 	# Votes: 143686
# 	Similarity: 0.5952358245849609
#
#
# Waves	2019
# 	https://www.imdb.com/title/tt8652728/
# 	Avg. Rating: 7.9
# 	# Votes: 3112
# 	Similarity: 0.590678334236145
#
#
# Pain and Glory	2019
# 	https://www.imdb.com/title/tt8291806/
# 	Avg. Rating: 7.7
# 	# Votes: 26573
# 	Similarity: 0.585023045539856
#
#
# Uncut Gems	2019
# 	https://www.imdb.com/title/tt5727208/
# 	Avg. Rating: 8.0
# 	# Votes: 29442
# 	Similarity: 0.5738497376441956
#
#
# So Long, My Son	2019
# 	https://www.imdb.com/title/tt9581076/
# 	Avg. Rating: 7.7
# 	# Votes: 1596
# 	Similarity: 0.5690385699272156
#
#
# Doctor Sleep	2019
# 	https://www.imdb.com/title/tt5606664/
# 	Avg. Rating: 7.5
# 	# Votes: 50088
# 	Similarity: 0.5664464235305786
#
#
# Hustlers	2019
# 	https://www.imdb.com/title/tt5503686/
# 	Avg. Rating: 6.4
# 	# Votes: 45611
# 	Similarity: 0.5660709738731384
#
#
# If Beale Street Could Talk	2018
# 	https://www.imdb.com/title/tt7125860/
# 	Avg. Rating: 7.1
# 	# Votes: 33427
# 	Similarity: 0.5645859241485596
#
#
# Jhalki	2019
# 	https://www.imdb.com/title/tt7743400/
# 	Avg. Rating: 8.4
# 	# Votes: 455
# 	Similarity: 0.5641476511955261
#
#
# I, Tonya	2017
# 	https://www.imdb.com/title/tt5580036/
# 	Avg. Rating: 7.5
# 	# Votes: 157145
# 	Similarity: 0.5638233423233032
#
#
# Climax	2018
# 	https://www.imdb.com/title/tt8359848/
# 	Avg. Rating: 7.1
# 	# Votes: 37167
# 	Similarity: 0.5604292154312134
#
#
# Honey Boy	2019
# 	https://www.imdb.com/title/tt8151874/
# 	Avg. Rating: 7.4
# 	# Votes: 4767
# 	Similarity: 0.5599175691604614
#
#
# Jojo Rabbit	2019
# 	https://www.imdb.com/title/tt2584384/
# 	Avg. Rating: 8.0
# 	# Votes: 50797
# 	Similarity: 0.5596699714660645
#
#
# La Dolce Vita	1960
# 	https://www.imdb.com/title/tt0053779/
# 	Avg. Rating: 8.0
# 	# Votes: 61072
# 	Similarity: 0.5580697059631348
#
#
# Some Like It Hot	1959
# 	https://www.imdb.com/title/tt0053291/
# 	Avg. Rating: 8.2
# 	# Votes: 228904
# 	Similarity: 0.5576834678649902
#
#
# The Art of Self-Defense	2019
# 	https://www.imdb.com/title/tt7339248/
# 	Avg. Rating: 6.7
# 	# Votes: 16478
# 	Similarity: 0.5572347640991211
#
#
# She's Gotta Have It	1986
# 	https://www.imdb.com/title/tt0091939/
# 	Avg. Rating: 6.7
# 	# Votes: 8736
# 	Similarity: 0.5570517778396606
#
#
# Portrait of a Lady on Fire	2019
# 	https://www.imdb.com/title/tt8613070/
# 	Avg. Rating: 8.3
# 	# Votes: 12184
# 	Similarity: 0.5569319128990173
#
#
# Ad Astra	2019
# 	https://www.imdb.com/title/tt2935510/
# 	Avg. Rating: 6.7
# 	# Votes: 128551
# 	Similarity: 0.5549951791763306
#
#
# The Shape of Water	2017
# 	https://www.imdb.com/title/tt5580390/
# 	Avg. Rating: 7.3
# 	# Votes: 334603
# 	Similarity: 0.5545586347579956
#
#
# The Asphalt Jungle	1950
# 	https://www.imdb.com/title/tt0042208/
# 	Avg. Rating: 7.9
# 	# Votes: 22447
# 	Similarity: 0.5539990663528442
#
#
# Shoplifters	2018
# 	https://www.imdb.com/title/tt8075192/
# 	Avg. Rating: 8.0
# 	# Votes: 44673
# 	Similarity: 0.5538998246192932
#
#
# Hotel Mumbai	2018
# 	https://www.imdb.com/title/tt5461944/
# 	Avg. Rating: 7.6
# 	# Votes: 39015
# 	Similarity: 0.5536304712295532
#
#
# Western Stars	2019
# 	https://www.imdb.com/title/tt10687158/
# 	Avg. Rating: 7.6
# 	# Votes: 799
# 	Similarity: 0.549168586730957
#
#
# The Old Man & the Gun	2018
# 	https://www.imdb.com/title/tt2837574/
# 	Avg. Rating: 6.7
# 	# Votes: 34284
# 	Similarity: 0.5483548641204834
#
#
# K-12	2019
# 	https://www.imdb.com/title/tt10521814/
# 	Avg. Rating: 6.4
# 	# Votes: 1810
# 	Similarity: 0.5477921962738037
#
#
# Green Book	2018
# 	https://www.imdb.com/title/tt6966692/
# 	Avg. Rating: 8.2
# 	# Votes: 280935
# 	Similarity: 0.5463670492172241
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.545650839805603
#
#
# The Umbrellas of Cherbourg	1964
# 	https://www.imdb.com/title/tt0058450/
# 	Avg. Rating: 7.8
# 	# Votes: 21487
# 	Similarity: 0.5453619956970215
#
#
# La Poison	1951
# 	https://www.imdb.com/title/tt0043927/
# 	Avg. Rating: 7.5
# 	# Votes: 973
# 	Similarity: 0.5425326824188232
#
#
# Gates of the Night	1946
# 	https://www.imdb.com/title/tt0038853/
# 	Avg. Rating: 7.2
# 	# Votes: 957
# 	Similarity: 0.5424655675888062
#
#
# Good Boys	2019
# 	https://www.imdb.com/title/tt7343762/
# 	Avg. Rating: 6.7
# 	# Votes: 38320
# 	Similarity: 0.5416730046272278
#
#
# Blinded by the Light	2019
# 	https://www.imdb.com/title/tt8266310/
# 	Avg. Rating: 6.9
# 	# Votes: 11557
# 	Similarity: 0.5412341356277466
#
#
# Beanpole	2019
# 	https://www.imdb.com/title/tt10199640/
# 	Avg. Rating: 7.2
# 	# Votes: 2930
# 	Similarity: 0.541143536567688
#
#
# Notes on Blindness	2016
# 	https://www.imdb.com/title/tt5117222/
# 	Avg. Rating: 7.1
# 	# Votes: 1780
# 	Similarity: 0.5397154092788696
#
#
# Where the Green Ants Dream	1984
# 	https://www.imdb.com/title/tt0088412/
# 	Avg. Rating: 7.1
# 	# Votes: 1909
# 	Similarity: 0.5378804802894592
#
#
# Eighth Grade	2018
# 	https://www.imdb.com/title/tt7014006/
# 	Avg. Rating: 7.4
# 	# Votes: 51859
# 	Similarity: 0.5377098321914673
#
#
# Summertime	1955
# 	https://www.imdb.com/title/tt0048673/
# 	Avg. Rating: 7.2
# 	# Votes: 7154
# 	Similarity: 0.5363396406173706
#
#
# A Beautiful Day in the Neighborhood	2019
# 	https://www.imdb.com/title/tt3224458/
# 	Avg. Rating: 7.6
# 	# Votes: 14601
# 	Similarity: 0.5363019108772278
#
#
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# 	Avg. Rating: 8.0
# 	# Votes: 3332
# 	Similarity: 0.5360580086708069
#
#
# Lolita	1962
# 	https://www.imdb.com/title/tt0056193/
# 	Avg. Rating: 7.6
# 	# Votes: 86559
# 	Similarity: 0.5354243516921997
#
#
# Suddenly, Last Summer	1959
# 	https://www.imdb.com/title/tt0053318/
# 	Avg. Rating: 7.6
# 	# Votes: 12954
# 	Similarity: 0.5340777635574341
#
#
# The Florida Project	2017
# 	https://www.imdb.com/title/tt5649144/
# 	Avg. Rating: 7.6
# 	# Votes: 79343
# 	Similarity: 0.5325284004211426
#
#
# Mid90s	2018
# 	https://www.imdb.com/title/tt5613484/
# 	Avg. Rating: 7.4
# 	# Votes: 35240
# 	Similarity: 0.5321773886680603
#
#
# Diego Maradona	2019
# 	https://www.imdb.com/title/tt5433114/
# 	Avg. Rating: 7.7
# 	# Votes: 5412
# 	Similarity: 0.5321325659751892
#
#
# Black Christmas	2019
# 	https://www.imdb.com/title/tt10481868/
# 	Avg. Rating: 3.1
# 	# Votes: 4443
# 	Similarity: 0.5314134359359741
#
#
# Booksmart	2019
# 	https://www.imdb.com/title/tt1489887/
# 	Avg. Rating: 7.2
# 	# Votes: 59567
# 	Similarity: 0.5313711166381836
#
#
# Three Identical Strangers	2018
# 	https://www.imdb.com/title/tt7664504/
# 	Avg. Rating: 7.7
# 	# Votes: 18970
# 	Similarity: 0.5309891700744629
#
#
# The King and the Mockingbird	1952
# 	https://www.imdb.com/title/tt0079820/
# 	Avg. Rating: 7.9
# 	# Votes: 4114
# 	Similarity: 0.5300388932228088
#
#
# BlacKkKlansman	2018
# 	https://www.imdb.com/title/tt7349662/
# 	Avg. Rating: 7.5
# 	# Votes: 175963
# 	Similarity: 0.5299261212348938
#
#
# L'Avventura	1960
# 	https://www.imdb.com/title/tt0053619/
# 	Avg. Rating: 7.9
# 	# Votes: 24011
# 	Similarity: 0.5296541452407837
#
#
# Man on a Tightrope	1953
# 	https://www.imdb.com/title/tt0046040/
# 	Avg. Rating: 7.1
# 	# Votes: 1018
# 	Similarity: 0.5296255946159363
#
#
# Long Day's Journey Into Night	2018
# 	https://www.imdb.com/title/tt8185182/
# 	Avg. Rating: 7.2
# 	# Votes: 3849
# 	Similarity: 0.5293831825256348
#
#
# For Sama	2019
# 	https://www.imdb.com/title/tt9617456/
# 	Avg. Rating: 8.6
# 	# Votes: 1900
# 	Similarity: 0.5280323624610901
#
#
# Stromboli	1950
# 	https://www.imdb.com/title/tt0041931/
# 	Avg. Rating: 7.3
# 	# Votes: 5334
# 	Similarity: 0.5273748636245728
#
#
# 3 Faces	2018
# 	https://www.imdb.com/title/tt8269552/
# 	Avg. Rating: 7.1
# 	# Votes: 2513
# 	Similarity: 0.5265215635299683
#
#
# Burning	2018
# 	https://www.imdb.com/title/tt7282468/
# 	Avg. Rating: 7.6
# 	# Votes: 33297
# 	Similarity: 0.5261660218238831
#
#
# The Sun Shines Bright	1953
# 	https://www.imdb.com/title/tt0046384/
# 	Avg. Rating: 7.0
# 	# Votes: 1219
# 	Similarity: 0.5256109833717346
#
#
# Gigi	1958
# 	https://www.imdb.com/title/tt0051658/
# 	Avg. Rating: 6.7
# 	# Votes: 18452
# 	Similarity: 0.5253244638442993
#
#
# The Scapegoat	1959
# 	https://www.imdb.com/title/tt0053247/
# 	Avg. Rating: 6.9
# 	# Votes: 1621
# 	Similarity: 0.5253182649612427
#
#
# Three Billboards Outside Ebbing, Missouri	2017
# 	https://www.imdb.com/title/tt5027774/
# 	Avg. Rating: 8.2
# 	# Votes: 377394
# 	Similarity: 0.5235332250595093
#
#
# Rome, Open City	1945
# 	https://www.imdb.com/title/tt0038890/
# 	Avg. Rating: 8.1
# 	# Votes: 21319
# 	Similarity: 0.5232964754104614
#
#
# They Shall Not Grow Old	2018
# 	https://www.imdb.com/title/tt7905466/
# 	Avg. Rating: 8.3
# 	# Votes: 22102
# 	Similarity: 0.5232222080230713
#
#
# Elmer Gantry	1960
# 	https://www.imdb.com/title/tt0053793/
# 	Avg. Rating: 7.8
# 	# Votes: 9578
# 	Similarity: 0.5228180289268494
#
#
# Last Christmas	2019
# 	https://www.imdb.com/title/tt8623904/
# 	Avg. Rating: 6.5
# 	# Votes: 20240
# 	Similarity: 0.5225669741630554
#
#
# Searching	2018
# 	https://www.imdb.com/title/tt7668870/
# 	Avg. Rating: 7.6
# 	# Votes: 117313
# 	Similarity: 0.5220737457275391
#
#
# The Manchurian Candidate	1962
# 	https://www.imdb.com/title/tt0056218/
# 	Avg. Rating: 7.9
# 	# Votes: 68765
# 	Similarity: 0.5215533375740051
#
#
# Fahrenheit 11/9	2018
# 	https://www.imdb.com/title/tt8632862/
# 	Avg. Rating: 6.9
# 	# Votes: 14798
# 	Similarity: 0.5214530825614929
#
#
# Sword of Trust	2019
# 	https://www.imdb.com/title/tt8484012/
# 	Avg. Rating: 6.3
# 	# Votes: 1108
# 	Similarity: 0.5213090181350708
#
#
# Boy Erased	2018
# 	https://www.imdb.com/title/tt7008872/
# 	Avg. Rating: 6.9
# 	# Votes: 25016
# 	Similarity: 0.5212324857711792
#
#
# The Children's Hour	1961
# 	https://www.imdb.com/title/tt0054743/
# 	Avg. Rating: 7.8
# 	# Votes: 13469
# 	Similarity: 0.5201632380485535
#
#
# Shoot the Piano Player	1960
# 	https://www.imdb.com/title/tt0054389/
# 	Avg. Rating: 7.5
# 	# Votes: 16178
# 	Similarity: 0.5197607278823853
#
#
# Take Me Out to the Ball Game	1949
# 	https://www.imdb.com/title/tt0041944/
# 	Avg. Rating: 6.8
# 	# Votes: 2991
# 	Similarity: 0.5195473432540894
#
#
# 4
# The model recommended 22 movies that were on the watchlist!
#
# 		 Average Rating: 7.413333333333335
#
# The Farewell	2019
# 	https://www.imdb.com/title/tt8637428/
# 	Avg. Rating: 7.7
# 	# Votes: 24641
# 	Similarity: 0.661097526550293
#
#
# Jhalki	2019
# 	https://www.imdb.com/title/tt7743400/
# 	Avg. Rating: 8.4
# 	# Votes: 455
# 	Similarity: 0.6606577634811401
#
#
# Marriage Story	2019
# 	https://www.imdb.com/title/tt7653254/
# 	Avg. Rating: 8.1
# 	# Votes: 130590
# 	Similarity: 0.6590180397033691
#
#
# The Lighthouse	2019
# 	https://www.imdb.com/title/tt7984734/
# 	Avg. Rating: 7.8
# 	# Votes: 52091
# 	Similarity: 0.6445708274841309
#
#
# Once Upon a Time... in Hollywood	2019
# 	https://www.imdb.com/title/tt7131622/
# 	Avg. Rating: 7.8
# 	# Votes: 342653
# 	Similarity: 0.6443772315979004
#
#
# Apollo 11	2019
# 	https://www.imdb.com/title/tt8760684/
# 	Avg. Rating: 8.2
# 	# Votes: 15085
# 	Similarity: 0.6388225555419922
#
#
# A Star Is Born	2018
# 	https://www.imdb.com/title/tt1517451/
# 	Avg. Rating: 7.7
# 	# Votes: 293127
# 	Similarity: 0.6354790925979614
#
#
# Knives Out	2019
# 	https://www.imdb.com/title/tt8946378/
# 	Avg. Rating: 8.0
# 	# Votes: 124017
# 	Similarity: 0.6301100254058838
#
#
# The Favourite	2018
# 	https://www.imdb.com/title/tt5083738/
# 	Avg. Rating: 7.6
# 	# Votes: 143686
# 	Similarity: 0.618744969367981
#
#
# Waves	2019
# 	https://www.imdb.com/title/tt8652728/
# 	Avg. Rating: 7.9
# 	# Votes: 3112
# 	Similarity: 0.6077413558959961
#
#
# Pain and Glory	2019
# 	https://www.imdb.com/title/tt8291806/
# 	Avg. Rating: 7.7
# 	# Votes: 26573
# 	Similarity: 0.5988456010818481
#
#
# Doctor Sleep	2019
# 	https://www.imdb.com/title/tt5606664/
# 	Avg. Rating: 7.5
# 	# Votes: 50088
# 	Similarity: 0.59747314453125
#
#
# Uncut Gems	2019
# 	https://www.imdb.com/title/tt5727208/
# 	Avg. Rating: 8.0
# 	# Votes: 29442
# 	Similarity: 0.5929195880889893
#
#
# Green Book	2018
# 	https://www.imdb.com/title/tt6966692/
# 	Avg. Rating: 8.2
# 	# Votes: 280935
# 	Similarity: 0.5922415852546692
#
#
# Jojo Rabbit	2019
# 	https://www.imdb.com/title/tt2584384/
# 	Avg. Rating: 8.0
# 	# Votes: 50797
# 	Similarity: 0.5921573638916016
#
#
# I, Tonya	2017
# 	https://www.imdb.com/title/tt5580036/
# 	Avg. Rating: 7.5
# 	# Votes: 157145
# 	Similarity: 0.5906435251235962
#
#
# If Beale Street Could Talk	2018
# 	https://www.imdb.com/title/tt7125860/
# 	Avg. Rating: 7.1
# 	# Votes: 33427
# 	Similarity: 0.5893588066101074
#
#
# Ad Astra	2019
# 	https://www.imdb.com/title/tt2935510/
# 	Avg. Rating: 6.7
# 	# Votes: 128551
# 	Similarity: 0.5893076062202454
#
#
# The Shape of Water	2017
# 	https://www.imdb.com/title/tt5580390/
# 	Avg. Rating: 7.3
# 	# Votes: 334603
# 	Similarity: 0.5888671875
#
#
# Hustlers	2019
# 	https://www.imdb.com/title/tt5503686/
# 	Avg. Rating: 6.4
# 	# Votes: 45611
# 	Similarity: 0.585257887840271
#
#
# Western Stars	2019
# 	https://www.imdb.com/title/tt10687158/
# 	Avg. Rating: 7.6
# 	# Votes: 799
# 	Similarity: 0.5828081369400024
#
#
# Honey Boy	2019
# 	https://www.imdb.com/title/tt8151874/
# 	Avg. Rating: 7.4
# 	# Votes: 4767
# 	Similarity: 0.5808002352714539
#
#
# Good Boys	2019
# 	https://www.imdb.com/title/tt7343762/
# 	Avg. Rating: 6.7
# 	# Votes: 38320
# 	Similarity: 0.5805062055587769
#
#
# K-12	2019
# 	https://www.imdb.com/title/tt10521814/
# 	Avg. Rating: 6.4
# 	# Votes: 1810
# 	Similarity: 0.5803930163383484
#
#
# The Art of Self-Defense	2019
# 	https://www.imdb.com/title/tt7339248/
# 	Avg. Rating: 6.7
# 	# Votes: 16478
# 	Similarity: 0.5798460841178894
#
#
# Some Like It Hot	1959
# 	https://www.imdb.com/title/tt0053291/
# 	Avg. Rating: 8.2
# 	# Votes: 228904
# 	Similarity: 0.5777258276939392
#
#
# Climax	2018
# 	https://www.imdb.com/title/tt8359848/
# 	Avg. Rating: 7.1
# 	# Votes: 37167
# 	Similarity: 0.575914740562439
#
#
# The Old Man & the Gun	2018
# 	https://www.imdb.com/title/tt2837574/
# 	Avg. Rating: 6.7
# 	# Votes: 34284
# 	Similarity: 0.5739579200744629
#
#
# Eighth Grade	2018
# 	https://www.imdb.com/title/tt7014006/
# 	Avg. Rating: 7.4
# 	# Votes: 51859
# 	Similarity: 0.5736775994300842
#
#
# So Long, My Son	2019
# 	https://www.imdb.com/title/tt9581076/
# 	Avg. Rating: 7.7
# 	# Votes: 1596
# 	Similarity: 0.5722376108169556
#
#
# Hotel Mumbai	2018
# 	https://www.imdb.com/title/tt5461944/
# 	Avg. Rating: 7.6
# 	# Votes: 39015
# 	Similarity: 0.5718296766281128
#
#
# Blinded by the Light	2019
# 	https://www.imdb.com/title/tt8266310/
# 	Avg. Rating: 6.9
# 	# Votes: 11557
# 	Similarity: 0.5714738965034485
#
#
# Shoplifters	2018
# 	https://www.imdb.com/title/tt8075192/
# 	Avg. Rating: 8.0
# 	# Votes: 44673
# 	Similarity: 0.5713927149772644
#
#
# Portrait of a Lady on Fire	2019
# 	https://www.imdb.com/title/tt8613070/
# 	Avg. Rating: 8.3
# 	# Votes: 12184
# 	Similarity: 0.5698908567428589
#
#
# BlacKkKlansman	2018
# 	https://www.imdb.com/title/tt7349662/
# 	Avg. Rating: 7.5
# 	# Votes: 175963
# 	Similarity: 0.5697100758552551
#
#
# Booksmart	2019
# 	https://www.imdb.com/title/tt1489887/
# 	Avg. Rating: 7.2
# 	# Votes: 59567
# 	Similarity: 0.5674028396606445
#
#
# She's Gotta Have It	1986
# 	https://www.imdb.com/title/tt0091939/
# 	Avg. Rating: 6.7
# 	# Votes: 8736
# 	Similarity: 0.564989447593689
#
#
# La Dolce Vita	1960
# 	https://www.imdb.com/title/tt0053779/
# 	Avg. Rating: 8.0
# 	# Votes: 61072
# 	Similarity: 0.5648361444473267
#
#
# The Asphalt Jungle	1950
# 	https://www.imdb.com/title/tt0042208/
# 	Avg. Rating: 7.9
# 	# Votes: 22447
# 	Similarity: 0.5618872046470642
#
#
# A Beautiful Day in the Neighborhood	2019
# 	https://www.imdb.com/title/tt3224458/
# 	Avg. Rating: 7.6
# 	# Votes: 14601
# 	Similarity: 0.5616661310195923
#
#
# The King and the Mockingbird	1952
# 	https://www.imdb.com/title/tt0079820/
# 	Avg. Rating: 7.9
# 	# Votes: 4114
# 	Similarity: 0.5614544749259949
#
#
# Three Billboards Outside Ebbing, Missouri	2017
# 	https://www.imdb.com/title/tt5027774/
# 	Avg. Rating: 8.2
# 	# Votes: 377394
# 	Similarity: 0.5606828927993774
#
#
# Black Christmas	2019
# 	https://www.imdb.com/title/tt10481868/
# 	Avg. Rating: 3.1
# 	# Votes: 4443
# 	Similarity: 0.5598429441452026
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.5597143173217773
#
#
# Last Christmas	2019
# 	https://www.imdb.com/title/tt8623904/
# 	Avg. Rating: 6.5
# 	# Votes: 20240
# 	Similarity: 0.5596418380737305
#
#
# Mid90s	2018
# 	https://www.imdb.com/title/tt5613484/
# 	Avg. Rating: 7.4
# 	# Votes: 35240
# 	Similarity: 0.5576949715614319
#
#
# Notes on Blindness	2016
# 	https://www.imdb.com/title/tt5117222/
# 	Avg. Rating: 7.1
# 	# Votes: 1780
# 	Similarity: 0.5570248365402222
#
#
# The Florida Project	2017
# 	https://www.imdb.com/title/tt5649144/
# 	Avg. Rating: 7.6
# 	# Votes: 79343
# 	Similarity: 0.5563017129898071
#
#
# La Poison	1951
# 	https://www.imdb.com/title/tt0043927/
# 	Avg. Rating: 7.5
# 	# Votes: 973
# 	Similarity: 0.5558491945266724
#
#
# Boy Erased	2018
# 	https://www.imdb.com/title/tt7008872/
# 	Avg. Rating: 6.9
# 	# Votes: 25016
# 	Similarity: 0.5556831955909729
#
#
# Diego Maradona	2019
# 	https://www.imdb.com/title/tt5433114/
# 	Avg. Rating: 7.7
# 	# Votes: 5412
# 	Similarity: 0.555618405342102
#
#
# Lolita	1962
# 	https://www.imdb.com/title/tt0056193/
# 	Avg. Rating: 7.6
# 	# Votes: 86559
# 	Similarity: 0.554857611656189
#
#
# It Chapter Two	2019
# 	https://www.imdb.com/title/tt7349950/
# 	Avg. Rating: 6.7
# 	# Votes: 149797
# 	Similarity: 0.5545299053192139
#
#
# Where the Green Ants Dream	1984
# 	https://www.imdb.com/title/tt0088412/
# 	Avg. Rating: 7.1
# 	# Votes: 1909
# 	Similarity: 0.5535032749176025
#
#
# Searching	2018
# 	https://www.imdb.com/title/tt7668870/
# 	Avg. Rating: 7.6
# 	# Votes: 117313
# 	Similarity: 0.5530704259872437
#
#
# For Sama	2019
# 	https://www.imdb.com/title/tt9617456/
# 	Avg. Rating: 8.6
# 	# Votes: 1900
# 	Similarity: 0.5525985956192017
#
#
# The Umbrellas of Cherbourg	1964
# 	https://www.imdb.com/title/tt0058450/
# 	Avg. Rating: 7.8
# 	# Votes: 21487
# 	Similarity: 0.552497148513794
#
#
# Child's Play	2019
# 	https://www.imdb.com/title/tt8663516/
# 	Avg. Rating: 5.8
# 	# Votes: 31503
# 	Similarity: 0.5515198707580566
#
#
# Crazy Rich Asians	2018
# 	https://www.imdb.com/title/tt3104988/
# 	Avg. Rating: 6.9
# 	# Votes: 117044
# 	Similarity: 0.5497665405273438
#
#
# Beanpole	2019
# 	https://www.imdb.com/title/tt10199640/
# 	Avg. Rating: 7.2
# 	# Votes: 2930
# 	Similarity: 0.5491738319396973
#
#
# Blue Skies	1946
# 	https://www.imdb.com/title/tt0038370/
# 	Avg. Rating: 6.5
# 	# Votes: 1172
# 	Similarity: 0.5483018159866333
#
#
# Take Me Out to the Ball Game	1949
# 	https://www.imdb.com/title/tt0041944/
# 	Avg. Rating: 6.8
# 	# Votes: 2991
# 	Similarity: 0.5479400753974915
#
#
# Gates of the Night	1946
# 	https://www.imdb.com/title/tt0038853/
# 	Avg. Rating: 7.2
# 	# Votes: 957
# 	Similarity: 0.546991229057312
#
#
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# 	Avg. Rating: 8.0
# 	# Votes: 3332
# 	Similarity: 0.5466668605804443
#
#
# Suddenly, Last Summer	1959
# 	https://www.imdb.com/title/tt0053318/
# 	Avg. Rating: 7.6
# 	# Votes: 12954
# 	Similarity: 0.5464619994163513
#
#
# Rome, Open City	1945
# 	https://www.imdb.com/title/tt0038890/
# 	Avg. Rating: 8.1
# 	# Votes: 21319
# 	Similarity: 0.5460752248764038
#
#
# Summertime	1955
# 	https://www.imdb.com/title/tt0048673/
# 	Avg. Rating: 7.2
# 	# Votes: 7154
# 	Similarity: 0.5457260608673096
#
#
# Star Wars: Episode IX - The Rise of Skywalker	2019
# 	https://www.imdb.com/title/tt2527338/
# 	Avg. Rating: 6.9
# 	# Votes: 234163
# 	Similarity: 0.5448552370071411
#
#
# Bohemian Rhapsody	2018
# 	https://www.imdb.com/title/tt1727824/
# 	Avg. Rating: 8.0
# 	# Votes: 403626
# 	Similarity: 0.5446131229400635
#
#
# Deadpool 2	2018
# 	https://www.imdb.com/title/tt5463162/
# 	Avg. Rating: 7.7
# 	# Votes: 433315
# 	Similarity: 0.5443914532661438
#
#
# Ralph Breaks the Internet	2018
# 	https://www.imdb.com/title/tt5848272/
# 	Avg. Rating: 7.1
# 	# Votes: 110658
# 	Similarity: 0.5442745685577393
#
#
# Burning	2018
# 	https://www.imdb.com/title/tt7282468/
# 	Avg. Rating: 7.6
# 	# Votes: 33297
# 	Similarity: 0.544192910194397
#
#
# Three Identical Strangers	2018
# 	https://www.imdb.com/title/tt7664504/
# 	Avg. Rating: 7.7
# 	# Votes: 18970
# 	Similarity: 0.5435730218887329
#
#
# 3 Faces	2018
# 	https://www.imdb.com/title/tt8269552/
# 	Avg. Rating: 7.1
# 	# Votes: 2513
# 	Similarity: 0.5432610511779785
#
#
# They Shall Not Grow Old	2018
# 	https://www.imdb.com/title/tt7905466/
# 	Avg. Rating: 8.3
# 	# Votes: 22102
# 	Similarity: 0.5428827404975891
#
#
# 6
# The model recommended 20 movies that were on the watchlist!
#
# 		 Average Rating: 7.597101449275363
#
# So Long, My Son	2019
# 	https://www.imdb.com/title/tt9581076/
# 	Avg. Rating: 7.7
# 	# Votes: 1596
# 	Similarity: 0.45123404264450073
#
#
# Do the Right Thing	1989
# 	https://www.imdb.com/title/tt0097216/
# 	Avg. Rating: 7.9
# 	# Votes: 78577
# 	Similarity: 0.445713609457016
#
#
# Floating Weeds	1959
# 	https://www.imdb.com/title/tt0053390/
# 	Avg. Rating: 8.0
# 	# Votes: 6592
# 	Similarity: 0.4387935698032379
#
#
# On the Waterfront	1954
# 	https://www.imdb.com/title/tt0047296/
# 	Avg. Rating: 8.1
# 	# Votes: 132973
# 	Similarity: 0.4353717863559723
#
#
# Last Year at Marienbad	1961
# 	https://www.imdb.com/title/tt0054632/
# 	Avg. Rating: 7.8
# 	# Votes: 18788
# 	Similarity: 0.434095174074173
#
#
# Shadows	1958
# 	https://www.imdb.com/title/tt0053270/
# 	Avg. Rating: 7.3
# 	# Votes: 9380
# 	Similarity: 0.4259818196296692
#
#
# The Decline of the American Empire	1986
# 	https://www.imdb.com/title/tt0090985/
# 	Avg. Rating: 7.3
# 	# Votes: 7380
# 	Similarity: 0.41903048753738403
#
#
# La Dolce Vita	1960
# 	https://www.imdb.com/title/tt0053779/
# 	Avg. Rating: 8.0
# 	# Votes: 61072
# 	Similarity: 0.41565442085266113
#
#
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# 	Avg. Rating: 8.0
# 	# Votes: 3332
# 	Similarity: 0.41396012902259827
#
#
# That Obscure Object of Desire	1977
# 	https://www.imdb.com/title/tt0075824/
# 	Avg. Rating: 7.9
# 	# Votes: 18958
# 	Similarity: 0.41301023960113525
#
#
# Things Change	1988
# 	https://www.imdb.com/title/tt0096259/
# 	Avg. Rating: 7.0
# 	# Votes: 3027
# 	Similarity: 0.40951699018478394
#
#
# Cinema Paradiso	1988
# 	https://www.imdb.com/title/tt0095765/
# 	Avg. Rating: 8.5
# 	# Votes: 211046
# 	Similarity: 0.40887895226478577
#
#
# Lancelot of the Lake	1974
# 	https://www.imdb.com/title/tt0071737/
# 	Avg. Rating: 7.0
# 	# Votes: 3157
# 	Similarity: 0.4039168655872345
#
#
# The Devil, Probably	1977
# 	https://www.imdb.com/title/tt0075938/
# 	Avg. Rating: 7.3
# 	# Votes: 3150
# 	Similarity: 0.3997810482978821
#
#
# Tales from the Gimli Hospital	1988
# 	https://www.imdb.com/title/tt0096218/
# 	Avg. Rating: 6.6
# 	# Votes: 1182
# 	Similarity: 0.3985412120819092
#
#
# La Ronde	1950
# 	https://www.imdb.com/title/tt0042906/
# 	Avg. Rating: 7.6
# 	# Votes: 4515
# 	Similarity: 0.39718300104141235
#
#
# Stranger Than Paradise	1984
# 	https://www.imdb.com/title/tt0088184/
# 	Avg. Rating: 7.5
# 	# Votes: 32237
# 	Similarity: 0.39539897441864014
#
#
# The Killing	1956
# 	https://www.imdb.com/title/tt0049406/
# 	Avg. Rating: 8.0
# 	# Votes: 76183
# 	Similarity: 0.39430326223373413
#
#
# The Thin Blue Line	1988
# 	https://www.imdb.com/title/tt0096257/
# 	Avg. Rating: 8.0
# 	# Votes: 20413
# 	Similarity: 0.39305031299591064
#
#
# Viridiana	1961
# 	https://www.imdb.com/title/tt0055601/
# 	Avg. Rating: 8.2
# 	# Votes: 20482
# 	Similarity: 0.39289331436157227
#
#
# The Revolution Will Not Be Televised	2003
# 	https://www.imdb.com/title/tt0363510/
# 	Avg. Rating: 8.3
# 	# Votes: 2337
# 	Similarity: 0.3926727771759033
#
#
# A Short Film About Killing	1988
# 	https://www.imdb.com/title/tt0095468/
# 	Avg. Rating: 8.1
# 	# Votes: 15515
# 	Similarity: 0.391721248626709
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.39160504937171936
#
#
# Rocco and His Brothers	1960
# 	https://www.imdb.com/title/tt0054248/
# 	Avg. Rating: 8.3
# 	# Votes: 15031
# 	Similarity: 0.3910568356513977
#
#
# Jules and Jim	1962
# 	https://www.imdb.com/title/tt0055032/
# 	Avg. Rating: 7.8
# 	# Votes: 34736
# 	Similarity: 0.3885900378227234
#
#
# Le parfum d'Yvonne	1994
# 	https://www.imdb.com/title/tt0110776/
# 	Avg. Rating: 6.5
# 	# Votes: 971
# 	Similarity: 0.3883627653121948
#
#
# Man Is Not a Bird	1965
# 	https://www.imdb.com/title/tt0059063/
# 	Avg. Rating: 7.2
# 	# Votes: 961
# 	Similarity: 0.3881550431251526
#
#
# Punchline	1988
# 	https://www.imdb.com/title/tt0095927/
# 	Avg. Rating: 5.9
# 	# Votes: 7645
# 	Similarity: 0.38757938146591187
#
#
# L'Avventura	1960
# 	https://www.imdb.com/title/tt0053619/
# 	Avg. Rating: 7.9
# 	# Votes: 24011
# 	Similarity: 0.38745370507240295
#
#
# The Five Senses	1999
# 	https://www.imdb.com/title/tt0168794/
# 	Avg. Rating: 6.6
# 	# Votes: 2936
# 	Similarity: 0.3866598308086395
#
#
# La Collectionneuse	1967
# 	https://www.imdb.com/title/tt0061495/
# 	Avg. Rating: 7.5
# 	# Votes: 5523
# 	Similarity: 0.3864232301712036
#
#
# Bonnie and Clyde	1967
# 	https://www.imdb.com/title/tt0061418/
# 	Avg. Rating: 7.8
# 	# Votes: 97109
# 	Similarity: 0.38623571395874023
#
#
# Sweetie	1989
# 	https://www.imdb.com/title/tt0098725/
# 	Avg. Rating: 6.8
# 	# Votes: 3092
# 	Similarity: 0.38589802384376526
#
#
# Sunset Blvd.	1950
# 	https://www.imdb.com/title/tt0043014/
# 	Avg. Rating: 8.4
# 	# Votes: 186742
# 	Similarity: 0.38506877422332764
#
#
# Paths of Glory	1957
# 	https://www.imdb.com/title/tt0050825/
# 	Avg. Rating: 8.4
# 	# Votes: 163638
# 	Similarity: 0.38288575410842896
#
#
# Sandra	1965
# 	https://www.imdb.com/title/tt0059856/
# 	Avg. Rating: 7.2
# 	# Votes: 1564
# 	Similarity: 0.3825686573982239
#
#
# The Bridge on the River Kwai	1957
# 	https://www.imdb.com/title/tt0050212/
# 	Avg. Rating: 8.1
# 	# Votes: 191813
# 	Similarity: 0.38228505849838257
#
#
# La Notte	1961
# 	https://www.imdb.com/title/tt0054130/
# 	Avg. Rating: 8.1
# 	# Votes: 16105
# 	Similarity: 0.38110482692718506
#
#
# Kanal	1957
# 	https://www.imdb.com/title/tt0050585/
# 	Avg. Rating: 7.9
# 	# Votes: 6155
# 	Similarity: 0.38101476430892944
#
#
# Pather Panchali	1955
# 	https://www.imdb.com/title/tt0048473/
# 	Avg. Rating: 8.6
# 	# Votes: 20230
# 	Similarity: 0.3800814151763916
#
#
# Effi Briest	1974
# 	https://www.imdb.com/title/tt0071458/
# 	Avg. Rating: 6.9
# 	# Votes: 2091
# 	Similarity: 0.379747211933136
#
#
# Fando and Lis	1968
# 	https://www.imdb.com/title/tt0061643/
# 	Avg. Rating: 7.0
# 	# Votes: 4680
# 	Similarity: 0.3769488036632538
#
#
# Crimes and Misdemeanors	1989
# 	https://www.imdb.com/title/tt0097123/
# 	Avg. Rating: 7.9
# 	# Votes: 51826
# 	Similarity: 0.37663906812667847
#
#
# The Trial	1962
# 	https://www.imdb.com/title/tt0057427/
# 	Avg. Rating: 7.8
# 	# Votes: 17901
# 	Similarity: 0.3762255609035492
#
#
# This Is Spinal Tap	1984
# 	https://www.imdb.com/title/tt0088258/
# 	Avg. Rating: 7.9
# 	# Votes: 123100
# 	Similarity: 0.3755991756916046
#
#
# A Lesson in Love	1954
# 	https://www.imdb.com/title/tt0047167/
# 	Avg. Rating: 7.1
# 	# Votes: 2568
# 	Similarity: 0.3749561905860901
#
#
# Boredom	1998
# 	https://www.imdb.com/title/tt0168740/
# 	Avg. Rating: 6.1
# 	# Votes: 1869
# 	Similarity: 0.3748646378517151
#
#
# A Short Film About Love	1988
# 	https://www.imdb.com/title/tt0095467/
# 	Avg. Rating: 8.2
# 	# Votes: 17487
# 	Similarity: 0.37351107597351074
#
#
# Diary of a Country Priest	1951
# 	https://www.imdb.com/title/tt0042619/
# 	Avg. Rating: 8.0
# 	# Votes: 8821
# 	Similarity: 0.3732222318649292
#
#
# Buffet Froid	1979
# 	https://www.imdb.com/title/tt0078913/
# 	Avg. Rating: 7.5
# 	# Votes: 4475
# 	Similarity: 0.3708639442920685
#
#
# Conversation Piece	1974
# 	https://www.imdb.com/title/tt0071585/
# 	Avg. Rating: 7.5
# 	# Votes: 3627
# 	Similarity: 0.370431125164032
#
#
# Autumn Sonata	1978
# 	https://www.imdb.com/title/tt0077711/
# 	Avg. Rating: 8.3
# 	# Votes: 22284
# 	Similarity: 0.3703230023384094
#
#
# Un Coeur en Hiver	1992
# 	https://www.imdb.com/title/tt0105682/
# 	Avg. Rating: 7.6
# 	# Votes: 8454
# 	Similarity: 0.3699333667755127
#
#
# Of Freaks and Men	1998
# 	https://www.imdb.com/title/tt0156849/
# 	Avg. Rating: 7.1
# 	# Votes: 2808
# 	Similarity: 0.3686727285385132
#
#
# Where Is the Friend's House?	1987
# 	https://www.imdb.com/title/tt0093342/
# 	Avg. Rating: 8.1
# 	# Votes: 8628
# 	Similarity: 0.3677094876766205
#
#
# Mishima: A Life in Four Chapters	1985
# 	https://www.imdb.com/title/tt0089603/
# 	Avg. Rating: 7.9
# 	# Votes: 7756
# 	Similarity: 0.36759185791015625
#
#
# Unknown Pleasures	2002
# 	https://www.imdb.com/title/tt0318025/
# 	Avg. Rating: 6.9
# 	# Votes: 2025
# 	Similarity: 0.3667809069156647
#
#
# Shadows of Forgotten Ancestors	1964
# 	https://www.imdb.com/title/tt0058642/
# 	Avg. Rating: 8.0
# 	# Votes: 5485
# 	Similarity: 0.36615437269210815
#
#
# La Strada	1954
# 	https://www.imdb.com/title/tt0047528/
# 	Avg. Rating: 8.0
# 	# Votes: 54582
# 	Similarity: 0.3660788834095001
#
#
# The Hawks and the Sparrows	1966
# 	https://www.imdb.com/title/tt0061132/
# 	Avg. Rating: 7.4
# 	# Votes: 3869
# 	Similarity: 0.3659638464450836
#
#
# The Long Day Closes	1992
# 	https://www.imdb.com/title/tt0104753/
# 	Avg. Rating: 7.4
# 	# Votes: 2541
# 	Similarity: 0.36519643664360046
#
#
# On Body and Soul	2017
# 	https://www.imdb.com/title/tt5607714/
# 	Avg. Rating: 7.6
# 	# Votes: 20656
# 	Similarity: 0.36410844326019287
#
#
# Clash	2016
# 	https://www.imdb.com/title/tt5599692/
# 	Avg. Rating: 7.5
# 	# Votes: 4437
# 	Similarity: 0.3631417751312256
#
#
# San tiao ren	1999
# 	https://www.imdb.com/title/tt0187590/
# 	Avg. Rating: 6.3
# 	# Votes: 565
# 	Similarity: 0.36273956298828125
#
#
# Two Men in Manhattan	1959
# 	https://www.imdb.com/title/tt0052733/
# 	Avg. Rating: 6.7
# 	# Votes: 1393
# 	Similarity: 0.36246204376220703
#
#
# Night Train	1959
# 	https://www.imdb.com/title/tt0053176/
# 	Avg. Rating: 7.8
# 	# Votes: 2420
# 	Similarity: 0.3624119758605957
#
#
# The Trials of Henry Kissinger	2002
# 	https://www.imdb.com/title/tt0326306/
# 	Avg. Rating: 7.6
# 	# Votes: 1880
# 	Similarity: 0.3620590567588806
#
#
# Stray Dog	1949
# 	https://www.imdb.com/title/tt0041699/
# 	Avg. Rating: 7.9
# 	# Votes: 13786
# 	Similarity: 0.36182165145874023
#
#
# A Tale of Springtime	1990
# 	https://www.imdb.com/title/tt0097106/
# 	Avg. Rating: 7.3
# 	# Votes: 3213
# 	Similarity: 0.3616260290145874
#
#
# 10
# The model recommended 21 movies that were on the watchlist!
#
# 		 Average Rating: 7.604054054054053
#
# So Long, My Son	2019
# 	https://www.imdb.com/title/tt9581076/
# 	Avg. Rating: 7.7
# 	# Votes: 1596
# 	Similarity: 0.46701180934906006
#
#
# Do the Right Thing	1989
# 	https://www.imdb.com/title/tt0097216/
# 	Avg. Rating: 7.9
# 	# Votes: 78577
# 	Similarity: 0.4613545835018158
#
#
# Last Year at Marienbad	1961
# 	https://www.imdb.com/title/tt0054632/
# 	Avg. Rating: 7.8
# 	# Votes: 18788
# 	Similarity: 0.45880237221717834
#
#
# Floating Weeds	1959
# 	https://www.imdb.com/title/tt0053390/
# 	Avg. Rating: 8.0
# 	# Votes: 6592
# 	Similarity: 0.45369231700897217
#
#
# Shadows	1958
# 	https://www.imdb.com/title/tt0053270/
# 	Avg. Rating: 7.3
# 	# Votes: 9380
# 	Similarity: 0.4392998218536377
#
#
# On the Waterfront	1954
# 	https://www.imdb.com/title/tt0047296/
# 	Avg. Rating: 8.1
# 	# Votes: 132973
# 	Similarity: 0.43454623222351074
#
#
# La Dolce Vita	1960
# 	https://www.imdb.com/title/tt0053779/
# 	Avg. Rating: 8.0
# 	# Votes: 61072
# 	Similarity: 0.43286997079849243
#
#
# Cinema Paradiso	1988
# 	https://www.imdb.com/title/tt0095765/
# 	Avg. Rating: 8.5
# 	# Votes: 211046
# 	Similarity: 0.4256000518798828
#
#
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# 	Avg. Rating: 8.0
# 	# Votes: 3332
# 	Similarity: 0.42197009921073914
#
#
# The Decline of the American Empire	1986
# 	https://www.imdb.com/title/tt0090985/
# 	Avg. Rating: 7.3
# 	# Votes: 7380
# 	Similarity: 0.4188201129436493
#
#
# Tales from the Gimli Hospital	1988
# 	https://www.imdb.com/title/tt0096218/
# 	Avg. Rating: 6.6
# 	# Votes: 1182
# 	Similarity: 0.41168472170829773
#
#
# Man Is Not a Bird	1965
# 	https://www.imdb.com/title/tt0059063/
# 	Avg. Rating: 7.2
# 	# Votes: 961
# 	Similarity: 0.4096478223800659
#
#
# Lancelot of the Lake	1974
# 	https://www.imdb.com/title/tt0071737/
# 	Avg. Rating: 7.0
# 	# Votes: 3157
# 	Similarity: 0.40588197112083435
#
#
# Pather Panchali	1955
# 	https://www.imdb.com/title/tt0048473/
# 	Avg. Rating: 8.6
# 	# Votes: 20230
# 	Similarity: 0.404144823551178
#
#
# Things Change	1988
# 	https://www.imdb.com/title/tt0096259/
# 	Avg. Rating: 7.0
# 	# Votes: 3027
# 	Similarity: 0.4039543569087982
#
#
# That Obscure Object of Desire	1977
# 	https://www.imdb.com/title/tt0075824/
# 	Avg. Rating: 7.9
# 	# Votes: 18958
# 	Similarity: 0.40285181999206543
#
#
# Jules and Jim	1962
# 	https://www.imdb.com/title/tt0055032/
# 	Avg. Rating: 7.8
# 	# Votes: 34736
# 	Similarity: 0.40236467123031616
#
#
# L'Avventura	1960
# 	https://www.imdb.com/title/tt0053619/
# 	Avg. Rating: 7.9
# 	# Votes: 24011
# 	Similarity: 0.40155425667762756
#
#
# Sweetie	1989
# 	https://www.imdb.com/title/tt0098725/
# 	Avg. Rating: 6.8
# 	# Votes: 3092
# 	Similarity: 0.39893192052841187
#
#
# The Revolution Will Not Be Televised	2003
# 	https://www.imdb.com/title/tt0363510/
# 	Avg. Rating: 8.3
# 	# Votes: 2337
# 	Similarity: 0.3972437381744385
#
#
# The Killing	1956
# 	https://www.imdb.com/title/tt0049406/
# 	Avg. Rating: 8.0
# 	# Votes: 76183
# 	Similarity: 0.3967445492744446
#
#
# The Thin Blue Line	1988
# 	https://www.imdb.com/title/tt0096257/
# 	Avg. Rating: 8.0
# 	# Votes: 20413
# 	Similarity: 0.39584434032440186
#
#
# Rocco and His Brothers	1960
# 	https://www.imdb.com/title/tt0054248/
# 	Avg. Rating: 8.3
# 	# Votes: 15031
# 	Similarity: 0.3957299292087555
#
#
# La Ronde	1950
# 	https://www.imdb.com/title/tt0042906/
# 	Avg. Rating: 7.6
# 	# Votes: 4515
# 	Similarity: 0.39335086941719055
#
#
# Bonnie and Clyde	1967
# 	https://www.imdb.com/title/tt0061418/
# 	Avg. Rating: 7.8
# 	# Votes: 97109
# 	Similarity: 0.39263445138931274
#
#
# This Is Spinal Tap	1984
# 	https://www.imdb.com/title/tt0088258/
# 	Avg. Rating: 7.9
# 	# Votes: 123100
# 	Similarity: 0.3924759328365326
#
#
# A Short Film About Killing	1988
# 	https://www.imdb.com/title/tt0095468/
# 	Avg. Rating: 8.1
# 	# Votes: 15515
# 	Similarity: 0.39234697818756104
#
#
# Paths of Glory	1957
# 	https://www.imdb.com/title/tt0050825/
# 	Avg. Rating: 8.4
# 	# Votes: 163638
# 	Similarity: 0.39209115505218506
#
#
# The Devil, Probably	1977
# 	https://www.imdb.com/title/tt0075938/
# 	Avg. Rating: 7.3
# 	# Votes: 3150
# 	Similarity: 0.39161545038223267
#
#
# Viridiana	1961
# 	https://www.imdb.com/title/tt0055601/
# 	Avg. Rating: 8.2
# 	# Votes: 20482
# 	Similarity: 0.3915269672870636
#
#
# Sandra	1965
# 	https://www.imdb.com/title/tt0059856/
# 	Avg. Rating: 7.2
# 	# Votes: 1564
# 	Similarity: 0.38886523246765137
#
#
# Bright Future	2002
# 	https://www.imdb.com/title/tt0363235/
# 	Avg. Rating: 6.8
# 	# Votes: 2431
# 	Similarity: 0.3885098099708557
#
#
# Crimes and Misdemeanors	1989
# 	https://www.imdb.com/title/tt0097123/
# 	Avg. Rating: 7.9
# 	# Votes: 51826
# 	Similarity: 0.3880196213722229
#
#
# A Tale of Springtime	1990
# 	https://www.imdb.com/title/tt0097106/
# 	Avg. Rating: 7.3
# 	# Votes: 3213
# 	Similarity: 0.3875685930252075
#
#
# The Hawks and the Sparrows	1966
# 	https://www.imdb.com/title/tt0061132/
# 	Avg. Rating: 7.4
# 	# Votes: 3869
# 	Similarity: 0.3871138095855713
#
#
# Clash	2016
# 	https://www.imdb.com/title/tt5599692/
# 	Avg. Rating: 7.5
# 	# Votes: 4437
# 	Similarity: 0.3858293890953064
#
#
# The Trial	1962
# 	https://www.imdb.com/title/tt0057427/
# 	Avg. Rating: 7.8
# 	# Votes: 17901
# 	Similarity: 0.38495928049087524
#
#
# La Collectionneuse	1967
# 	https://www.imdb.com/title/tt0061495/
# 	Avg. Rating: 7.5
# 	# Votes: 5523
# 	Similarity: 0.38467538356781006
#
#
# On Body and Soul	2017
# 	https://www.imdb.com/title/tt5607714/
# 	Avg. Rating: 7.6
# 	# Votes: 20656
# 	Similarity: 0.38286900520324707
#
#
# Punchline	1988
# 	https://www.imdb.com/title/tt0095927/
# 	Avg. Rating: 5.9
# 	# Votes: 7645
# 	Similarity: 0.38277319073677063
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.3826446831226349
#
#
# Violent Cop	1989
# 	https://www.imdb.com/title/tt0098360/
# 	Avg. Rating: 7.2
# 	# Votes: 9729
# 	Similarity: 0.3817817270755768
#
#
# The Bridge on the River Kwai	1957
# 	https://www.imdb.com/title/tt0050212/
# 	Avg. Rating: 8.1
# 	# Votes: 191813
# 	Similarity: 0.3807884752750397
#
#
# Diary of a Chambermaid	1964
# 	https://www.imdb.com/title/tt0058249/
# 	Avg. Rating: 7.5
# 	# Votes: 7714
# 	Similarity: 0.3807217478752136
#
#
# Where Is the Friend's House?	1987
# 	https://www.imdb.com/title/tt0093342/
# 	Avg. Rating: 8.1
# 	# Votes: 8628
# 	Similarity: 0.3802908658981323
#
#
# A Lesson in Love	1954
# 	https://www.imdb.com/title/tt0047167/
# 	Avg. Rating: 7.1
# 	# Votes: 2568
# 	Similarity: 0.379585325717926
#
#
# Shoot the Piano Player	1960
# 	https://www.imdb.com/title/tt0054389/
# 	Avg. Rating: 7.5
# 	# Votes: 16178
# 	Similarity: 0.3789726197719574
#
#
# Le parfum d'Yvonne	1994
# 	https://www.imdb.com/title/tt0110776/
# 	Avg. Rating: 6.5
# 	# Votes: 971
# 	Similarity: 0.37884342670440674
#
#
# Gate of Flesh	1964
# 	https://www.imdb.com/title/tt0058409/
# 	Avg. Rating: 7.4
# 	# Votes: 2580
# 	Similarity: 0.3783033788204193
#
#
# Shadows of Forgotten Ancestors	1964
# 	https://www.imdb.com/title/tt0058642/
# 	Avg. Rating: 8.0
# 	# Votes: 5485
# 	Similarity: 0.3772994875907898
#
#
# La Notte	1961
# 	https://www.imdb.com/title/tt0054130/
# 	Avg. Rating: 8.1
# 	# Votes: 16105
# 	Similarity: 0.3763447701931
#
#
# The Five Senses	1999
# 	https://www.imdb.com/title/tt0168794/
# 	Avg. Rating: 6.6
# 	# Votes: 2936
# 	Similarity: 0.3763387203216553
#
#
# The Umbrellas of Cherbourg	1964
# 	https://www.imdb.com/title/tt0058450/
# 	Avg. Rating: 7.8
# 	# Votes: 21487
# 	Similarity: 0.37563830614089966
#
#
# Of Freaks and Men	1998
# 	https://www.imdb.com/title/tt0156849/
# 	Avg. Rating: 7.1
# 	# Votes: 2808
# 	Similarity: 0.37557452917099
#
#
# Stranger Than Paradise	1984
# 	https://www.imdb.com/title/tt0088184/
# 	Avg. Rating: 7.5
# 	# Votes: 32237
# 	Similarity: 0.3752962350845337
#
#
# Fando and Lis	1968
# 	https://www.imdb.com/title/tt0061643/
# 	Avg. Rating: 7.0
# 	# Votes: 4680
# 	Similarity: 0.3737179934978485
#
#
# Effi Briest	1974
# 	https://www.imdb.com/title/tt0071458/
# 	Avg. Rating: 6.9
# 	# Votes: 2091
# 	Similarity: 0.37342432141304016
#
#
# A Short Film About Love	1988
# 	https://www.imdb.com/title/tt0095467/
# 	Avg. Rating: 8.2
# 	# Votes: 17487
# 	Similarity: 0.3726921081542969
#
#
# Le Trou	1960
# 	https://www.imdb.com/title/tt0054407/
# 	Avg. Rating: 8.6
# 	# Votes: 13654
# 	Similarity: 0.37221503257751465
#
#
# Night Train	1959
# 	https://www.imdb.com/title/tt0053176/
# 	Avg. Rating: 7.8
# 	# Votes: 2420
# 	Similarity: 0.37195807695388794
#
#
# The Long Day Closes	1992
# 	https://www.imdb.com/title/tt0104753/
# 	Avg. Rating: 7.4
# 	# Votes: 2541
# 	Similarity: 0.3707348704338074
#
#
# Un Coeur en Hiver	1992
# 	https://www.imdb.com/title/tt0105682/
# 	Avg. Rating: 7.6
# 	# Votes: 8454
# 	Similarity: 0.37050220370292664
#
#
# Kanal	1957
# 	https://www.imdb.com/title/tt0050585/
# 	Avg. Rating: 7.9
# 	# Votes: 6155
# 	Similarity: 0.3698173463344574
#
#
# Mishima: A Life in Four Chapters	1985
# 	https://www.imdb.com/title/tt0089603/
# 	Avg. Rating: 7.9
# 	# Votes: 7756
# 	Similarity: 0.36972808837890625
#
#
# Charulata	1964
# 	https://www.imdb.com/title/tt0057935/
# 	Avg. Rating: 8.2
# 	# Votes: 4491
# 	Similarity: 0.36953115463256836
#
#
# Sunset Blvd.	1950
# 	https://www.imdb.com/title/tt0043014/
# 	Avg. Rating: 8.4
# 	# Votes: 186742
# 	Similarity: 0.3682686984539032
#
#
# Autumn Sonata	1978
# 	https://www.imdb.com/title/tt0077711/
# 	Avg. Rating: 8.3
# 	# Votes: 22284
# 	Similarity: 0.3679852783679962
#
#
# San tiao ren	1999
# 	https://www.imdb.com/title/tt0187590/
# 	Avg. Rating: 6.3
# 	# Votes: 565
# 	Similarity: 0.36737728118896484
#
#
# La Strada	1954
# 	https://www.imdb.com/title/tt0047528/
# 	Avg. Rating: 8.0
# 	# Votes: 54582
# 	Similarity: 0.3672236204147339
#
#
# Merci pour le Chocolat	2000
# 	https://www.imdb.com/title/tt0232083/
# 	Avg. Rating: 6.6
# 	# Votes: 4536
# 	Similarity: 0.3670766353607178
#
#
# Boredom	1998
# 	https://www.imdb.com/title/tt0168740/
# 	Avg. Rating: 6.1
# 	# Votes: 1869
# 	Similarity: 0.36673760414123535
#
#
# The Best Intentions	1992
# 	https://www.imdb.com/title/tt0104350/
# 	Avg. Rating: 7.8
# 	# Votes: 2752
# 	Similarity: 0.36638909578323364
#
#
# Ida	2013
# 	https://www.imdb.com/title/tt2718492/
# 	Avg. Rating: 7.4
# 	# Votes: 48896
# 	Similarity: 0.3660389184951782
#
#
# All About My Mother	1999
# 	https://www.imdb.com/title/tt0185125/
# 	Avg. Rating: 7.8
# 	# Votes: 83490
# 	Similarity: 0.365336537361145
#
#
# 14
# The model recommended 24 movies that were on the watchlist!
#
# 		 Average Rating: 7.172340425531913
#
# Kadosh	1999
# 	https://www.imdb.com/title/tt0189630/
# 	Avg. Rating: 6.8
# 	# Votes: 1662
# 	Similarity: 0.3661081790924072
#
#
# The Band's Visit	2007
# 	https://www.imdb.com/title/tt1032856/
# 	Avg. Rating: 7.5
# 	# Votes: 12378
# 	Similarity: 0.35510748624801636
#
#
# Flanders	2006
# 	https://www.imdb.com/title/tt0450680/
# 	Avg. Rating: 6.5
# 	# Votes: 2728
# 	Similarity: 0.3492412567138672
#
#
# Shotgun Stories	2007
# 	https://www.imdb.com/title/tt0952682/
# 	Avg. Rating: 7.2
# 	# Votes: 9443
# 	Similarity: 0.3323823809623718
#
#
# Two Men in Manhattan	1959
# 	https://www.imdb.com/title/tt0052733/
# 	Avg. Rating: 6.7
# 	# Votes: 1393
# 	Similarity: 0.32917097210884094
#
#
# Shame	2011
# 	https://www.imdb.com/title/tt1723811/
# 	Avg. Rating: 7.2
# 	# Votes: 175304
# 	Similarity: 0.3276209831237793
#
#
# La Strada	1954
# 	https://www.imdb.com/title/tt0047528/
# 	Avg. Rating: 8.0
# 	# Votes: 54582
# 	Similarity: 0.32567298412323
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.3246321380138397
#
#
# The Young One	1960
# 	https://www.imdb.com/title/tt0053967/
# 	Avg. Rating: 7.4
# 	# Votes: 2309
# 	Similarity: 0.32161039113998413
#
#
# Welcome	2009
# 	https://www.imdb.com/title/tt1314280/
# 	Avg. Rating: 7.5
# 	# Votes: 6908
# 	Similarity: 0.3202363848686218
#
#
# Certified Copy	2010
# 	https://www.imdb.com/title/tt1020773/
# 	Avg. Rating: 7.3
# 	# Votes: 19238
# 	Similarity: 0.320228636264801
#
#
# Rendez-vous	1985
# 	https://www.imdb.com/title/tt0089902/
# 	Avg. Rating: 6.6
# 	# Votes: 2253
# 	Similarity: 0.318548321723938
#
#
# Crimes and Misdemeanors	1989
# 	https://www.imdb.com/title/tt0097123/
# 	Avg. Rating: 7.9
# 	# Votes: 51826
# 	Similarity: 0.3163875341415405
#
#
# Departure	2015
# 	https://www.imdb.com/title/tt2248739/
# 	Avg. Rating: 6.7
# 	# Votes: 1821
# 	Similarity: 0.31624385714530945
#
#
# 4 Months, 3 Weeks and 2 Days	2007
# 	https://www.imdb.com/title/tt1032846/
# 	Avg. Rating: 7.9
# 	# Votes: 53494
# 	Similarity: 0.3140760064125061
#
#
# Good Morning, Night	2003
# 	https://www.imdb.com/title/tt0377569/
# 	Avg. Rating: 7.1
# 	# Votes: 3189
# 	Similarity: 0.31263667345046997
#
#
# The Last Mitterrand	2005
# 	https://www.imdb.com/title/tt0364301/
# 	Avg. Rating: 7.1
# 	# Votes: 958
# 	Similarity: 0.3124888837337494
#
#
# Lars and the Real Girl	2007
# 	https://www.imdb.com/title/tt0805564/
# 	Avg. Rating: 7.3
# 	# Votes: 133658
# 	Similarity: 0.31098008155822754
#
#
# Goodbye, Dragon Inn	2003
# 	https://www.imdb.com/title/tt0377556/
# 	Avg. Rating: 7.1
# 	# Votes: 3680
# 	Similarity: 0.3103960156440735
#
#
# Tous les matins du monde	1991
# 	https://www.imdb.com/title/tt0103110/
# 	Avg. Rating: 7.5
# 	# Votes: 6102
# 	Similarity: 0.3096446692943573
#
#
# Bright Leaves	2003
# 	https://www.imdb.com/title/tt0372806/
# 	Avg. Rating: 7.1
# 	# Votes: 569
# 	Similarity: 0.3095864951610565
#
#
# Colonel Redl	1985
# 	https://www.imdb.com/title/tt0089716/
# 	Avg. Rating: 7.6
# 	# Votes: 2516
# 	Similarity: 0.3078509569168091
#
#
# The Blue Room	2014
# 	https://www.imdb.com/title/tt3230082/
# 	Avg. Rating: 6.3
# 	# Votes: 2953
# 	Similarity: 0.30630868673324585
#
#
# A Girl Cut in Two	2007
# 	https://www.imdb.com/title/tt0901485/
# 	Avg. Rating: 6.3
# 	# Votes: 3349
# 	Similarity: 0.30607277154922485
#
#
# Samson & Delilah	2009
# 	https://www.imdb.com/title/tt1340123/
# 	Avg. Rating: 7.0
# 	# Votes: 3097
# 	Similarity: 0.3053107261657715
#
#
# Blessed	2009
# 	https://www.imdb.com/title/tt1282024/
# 	Avg. Rating: 6.7
# 	# Votes: 663
# 	Similarity: 0.30504554510116577
#
#
# Off the Map	2003
# 	https://www.imdb.com/title/tt0332285/
# 	Avg. Rating: 7.2
# 	# Votes: 3146
# 	Similarity: 0.3041735887527466
#
#
# Shine a Light	2008
# 	https://www.imdb.com/title/tt0893382/
# 	Avg. Rating: 7.2
# 	# Votes: 10690
# 	Similarity: 0.30315300822257996
#
#
# Oedipus Rex	1967
# 	https://www.imdb.com/title/tt0061613/
# 	Avg. Rating: 7.4
# 	# Votes: 4652
# 	Similarity: 0.30159109830856323
#
#
# The Cook, the Thief, His Wife & Her Lover	1989
# 	https://www.imdb.com/title/tt0097108/
# 	Avg. Rating: 7.6
# 	# Votes: 32751
# 	Similarity: 0.3014945983886719
#
#
# The Descendants	2011
# 	https://www.imdb.com/title/tt1033575/
# 	Avg. Rating: 7.3
# 	# Votes: 226417
# 	Similarity: 0.3006402254104614
#
#
# Pierrot le Fou	1965
# 	https://www.imdb.com/title/tt0059592/
# 	Avg. Rating: 7.6
# 	# Votes: 26351
# 	Similarity: 0.30048832297325134
#
#
# Sukiyaki Western Django	2007
# 	https://www.imdb.com/title/tt0906665/
# 	Avg. Rating: 6.2
# 	# Votes: 14212
# 	Similarity: 0.2992080748081207
#
#
# Hunger	2008
# 	https://www.imdb.com/title/tt0986233/
# 	Avg. Rating: 7.6
# 	# Votes: 62703
# 	Similarity: 0.29915040731430054
#
#
# The Art of the Steal	2009
# 	https://www.imdb.com/title/tt1326733/
# 	Avg. Rating: 7.6
# 	# Votes: 2179
# 	Similarity: 0.29901742935180664
#
#
# Chinese Take-Out	2011
# 	https://www.imdb.com/title/tt1705786/
# 	Avg. Rating: 7.3
# 	# Votes: 16142
# 	Similarity: 0.29869887232780457
#
#
# Dans Paris	2006
# 	https://www.imdb.com/title/tt0769508/
# 	Avg. Rating: 6.5
# 	# Votes: 3793
# 	Similarity: 0.2985684871673584
#
#
# Il Bidone	1955
# 	https://www.imdb.com/title/tt0047876/
# 	Avg. Rating: 7.5
# 	# Votes: 4514
# 	Similarity: 0.2976677417755127
#
#
# Museum Hours	2012
# 	https://www.imdb.com/title/tt2268732/
# 	Avg. Rating: 6.9
# 	# Votes: 1839
# 	Similarity: 0.2975655496120453
#
#
# Blue Is the Warmest Color	2013
# 	https://www.imdb.com/title/tt2278871/
# 	Avg. Rating: 7.7
# 	# Votes: 129237
# 	Similarity: 0.2965128421783447
#
#
# 4 Moons	2014
# 	https://www.imdb.com/title/tt2260850/
# 	Avg. Rating: 7.5
# 	# Votes: 3599
# 	Similarity: 0.2960975170135498
#
#
# Wilbur Wants to Kill Himself	2002
# 	https://www.imdb.com/title/tt0329767/
# 	Avg. Rating: 6.8
# 	# Votes: 7467
# 	Similarity: 0.29472389817237854
#
#
# La Grande Bouffe	1973
# 	https://www.imdb.com/title/tt0070130/
# 	Avg. Rating: 7.2
# 	# Votes: 11038
# 	Similarity: 0.2938305735588074
#
#
# A Zed & Two Noughts	1985
# 	https://www.imdb.com/title/tt0090366/
# 	Avg. Rating: 7.4
# 	# Votes: 6041
# 	Similarity: 0.2937714457511902
#
#
# A Royal Affair	2012
# 	https://www.imdb.com/title/tt1276419/
# 	Avg. Rating: 7.5
# 	# Votes: 41970
# 	Similarity: 0.2935808300971985
#
#
# Meek's Cutoff	2010
# 	https://www.imdb.com/title/tt1518812/
# 	Avg. Rating: 6.5
# 	# Votes: 10893
# 	Similarity: 0.29313769936561584
#
#
# The White Diamond	2004
# 	https://www.imdb.com/title/tt0435776/
# 	Avg. Rating: 7.5
# 	# Votes: 4141
# 	Similarity: 0.29290497303009033
#
#
# The Good Heart	2009
# 	https://www.imdb.com/title/tt0808285/
# 	Avg. Rating: 6.9
# 	# Votes: 4146
# 	Similarity: 0.2924483120441437
#
#
# Susana	1951
# 	https://www.imdb.com/title/tt0043018/
# 	Avg. Rating: 7.2
# 	# Votes: 1709
# 	Similarity: 0.29232943058013916
#
#
# Amour	2012
# 	https://www.imdb.com/title/tt1602620/
# 	Avg. Rating: 7.9
# 	# Votes: 87520
# 	Similarity: 0.2912088632583618
#
#
# The Babysitters	2007
# 	https://www.imdb.com/title/tt0796302/
# 	Avg. Rating: 5.6
# 	# Votes: 10351
# 	Similarity: 0.2911072373390198
#
#
# The Man Without a Past	2002
# 	https://www.imdb.com/title/tt0311519/
# 	Avg. Rating: 7.7
# 	# Votes: 20955
# 	Similarity: 0.2875056862831116
#
#
# Empties	2007
# 	https://www.imdb.com/title/tt0809951/
# 	Avg. Rating: 7.3
# 	# Votes: 4349
# 	Similarity: 0.28702011704444885
#
#
# Story of Women	1988
# 	https://www.imdb.com/title/tt0096336/
# 	Avg. Rating: 7.5
# 	# Votes: 3599
# 	Similarity: 0.28686267137527466
#
#
# I Wish	2011
# 	https://www.imdb.com/title/tt1650453/
# 	Avg. Rating: 7.4
# 	# Votes: 5515
# 	Similarity: 0.28663551807403564
#
#
# To the Wonder	2012
# 	https://www.imdb.com/title/tt1595656/
# 	Avg. Rating: 5.9
# 	# Votes: 25995
# 	Similarity: 0.286355584859848
#
#
# Sympathy for Mr. Vengeance	2002
# 	https://www.imdb.com/title/tt0310775/
# 	Avg. Rating: 7.6
# 	# Votes: 57967
# 	Similarity: 0.2859395444393158
#
#
# The Life Before Her Eyes	2007
# 	https://www.imdb.com/title/tt0815178/
# 	Avg. Rating: 6.4
# 	# Votes: 13268
# 	Similarity: 0.2858407497406006
#
#
# The Robber	2010
# 	https://www.imdb.com/title/tt1339161/
# 	Avg. Rating: 6.8
# 	# Votes: 4182
# 	Similarity: 0.28452765941619873
#
#
# La Notte	1961
# 	https://www.imdb.com/title/tt0054130/
# 	Avg. Rating: 8.1
# 	# Votes: 16105
# 	Similarity: 0.28372716903686523
#
#
# La Chinoise	1967
# 	https://www.imdb.com/title/tt0061473/
# 	Avg. Rating: 7.2
# 	# Votes: 5408
# 	Similarity: 0.2830943167209625
#
#
# Under the Hawthorn Tree	2010
# 	https://www.imdb.com/title/tt1554523/
# 	Avg. Rating: 7.1
# 	# Votes: 2569
# 	Similarity: 0.2828012704849243
#
#
# I Just Didn't Do It	2006
# 	https://www.imdb.com/title/tt0794350/
# 	Avg. Rating: 7.6
# 	# Votes: 1365
# 	Similarity: 0.2820521891117096
#
#
# Elephant	2003
# 	https://www.imdb.com/title/tt0363589/
# 	Avg. Rating: 7.2
# 	# Votes: 82249
# 	Similarity: 0.281626433134079
#
#
# Cría Cuervos	1976
# 	https://www.imdb.com/title/tt0074360/
# 	Avg. Rating: 8.0
# 	# Votes: 8411
# 	Similarity: 0.2810303568840027
#
#
# Time of the Gypsies	1988
# 	https://www.imdb.com/title/tt0097223/
# 	Avg. Rating: 8.3
# 	# Votes: 23250
# 	Similarity: 0.2805422842502594
#
#
# The Limits of Control	2009
# 	https://www.imdb.com/title/tt1135092/
# 	Avg. Rating: 6.3
# 	# Votes: 18731
# 	Similarity: 0.27977776527404785
#
#
# Fill the Void	2012
# 	https://www.imdb.com/title/tt2219514/
# 	Avg. Rating: 6.7
# 	# Votes: 3523
# 	Similarity: 0.2794249951839447
#
#
# Le Bonheur	1965
# 	https://www.imdb.com/title/tt0058985/
# 	Avg. Rating: 7.6
# 	# Votes: 4468
# 	Similarity: 0.2793683409690857
#
#
# Breakfast with Scot	2007
# 	https://www.imdb.com/title/tt0910847/
# 	Avg. Rating: 6.8
# 	# Votes: 2857
# 	Similarity: 0.2793218791484833
#
#
# The House on Telegraph Hill	1951
# 	https://www.imdb.com/title/tt0043660/
# 	Avg. Rating: 7.0
# 	# Votes: 2407
# 	Similarity: 0.2765675187110901
#
#
# The Turin Horse	2011
# 	https://www.imdb.com/title/tt1316540/
# 	Avg. Rating: 7.8
# 	# Votes: 14291
# 	Similarity: 0.2765112817287445
#
#
# Mister Lonely	2007
# 	https://www.imdb.com/title/tt0475984/
# 	Avg. Rating: 6.5
# 	# Votes: 7110
# 	Similarity: 0.27630773186683655
#
#
# Story of a Love Affair	1950
# 	https://www.imdb.com/title/tt0042355/
# 	Avg. Rating: 7.1
# 	# Votes: 2245
# 	Similarity: 0.2755814790725708
#
#
# Tales from the Script	2009
# 	https://www.imdb.com/title/tt1045642/
# 	Avg. Rating: 7.1
# 	# Votes: 1408
# 	Similarity: 0.27551761269569397
#
#
# Rabbit Hole	2010
# 	https://www.imdb.com/title/tt0935075/
# 	Avg. Rating: 7.0
# 	# Votes: 45977
# 	Similarity: 0.2746531665325165
#
#
# Little White Lies	2010
# 	https://www.imdb.com/title/tt1440232/
# 	Avg. Rating: 7.1
# 	# Votes: 22585
# 	Similarity: 0.2745583653450012
#
#
# Caterina in the Big City	2003
# 	https://www.imdb.com/title/tt0366287/
# 	Avg. Rating: 6.8
# 	# Votes: 2551
# 	Similarity: 0.2745024263858795
#
#
# Lucky Miles	2007
# 	https://www.imdb.com/title/tt0452644/
# 	Avg. Rating: 7.1
# 	# Votes: 708
# 	Similarity: 0.2741495370864868
#
#
# Route Irish	2010
# 	https://www.imdb.com/title/tt1528312/
# 	Avg. Rating: 6.4
# 	# Votes: 4101
# 	Similarity: 0.2736826539039612
#
#
# Gainsbourg: A Heroic Life	2010
# 	https://www.imdb.com/title/tt1329457/
# 	Avg. Rating: 6.9
# 	# Votes: 9138
# 	Similarity: 0.2735167145729065
#
#
# Revolutionary Road	2008
# 	https://www.imdb.com/title/tt0959337/
# 	Avg. Rating: 7.3
# 	# Votes: 184287
# 	Similarity: 0.27290067076683044
#
#
# After Lucia	2012
# 	https://www.imdb.com/title/tt2368749/
# 	Avg. Rating: 7.1
# 	# Votes: 5746
# 	Similarity: 0.2728783190250397
#
#
# The Fire Within	1963
# 	https://www.imdb.com/title/tt0057058/
# 	Avg. Rating: 8.0
# 	# Votes: 7335
# 	Similarity: 0.27277588844299316
#
#
# Happy-Go-Lucky	2008
# 	https://www.imdb.com/title/tt1045670/
# 	Avg. Rating: 7.0
# 	# Votes: 36448
# 	Similarity: 0.27238714694976807
#
#
# Palindromes	2004
# 	https://www.imdb.com/title/tt0362004/
# 	Avg. Rating: 6.7
# 	# Votes: 11733
# 	Similarity: 0.271693617105484
#
#
# Since Otar Left	2003
# 	https://www.imdb.com/title/tt0336264/
# 	Avg. Rating: 7.5
# 	# Votes: 2473
# 	Similarity: 0.2716444134712219
#
#
# A Late Quartet	2012
# 	https://www.imdb.com/title/tt1226240/
# 	Avg. Rating: 7.1
# 	# Votes: 13279
# 	Similarity: 0.26906314492225647
#
#
# The Savages	2007
# 	https://www.imdb.com/title/tt0775529/
# 	Avg. Rating: 7.1
# 	# Votes: 34917
# 	Similarity: 0.2677103281021118
#
#
# Beasts of the Southern Wild	2012
# 	https://www.imdb.com/title/tt2125435/
# 	Avg. Rating: 7.3
# 	# Votes: 78511
# 	Similarity: 0.26745542883872986
#
#
# Happy, Happy	2010
# 	https://www.imdb.com/title/tt1664892/
# 	Avg. Rating: 6.5
# 	# Votes: 2876
# 	Similarity: 0.26736587285995483
#
#
# A Prophet	2009
# 	https://www.imdb.com/title/tt1235166/
# 	Avg. Rating: 7.9
# 	# Votes: 89672
# 	Similarity: 0.26694202423095703
#
#
# Alamar	2009
# 	https://www.imdb.com/title/tt1502396/
# 	Avg. Rating: 7.3
# 	# Votes: 2296
# 	Similarity: 0.26638859510421753
#
#
# Café de Flore	2011
# 	https://www.imdb.com/title/tt1550312/
# 	Avg. Rating: 7.4
# 	# Votes: 14110
# 	Similarity: 0.26636555790901184
#
#
# 15
# The model recommended 20 movies that were on the watchlist!
#
# 		 Average Rating: 7.054166666666666
#
# The Band's Visit	2007
# 	https://www.imdb.com/title/tt1032856/
# 	Avg. Rating: 7.5
# 	# Votes: 12378
# 	Similarity: 0.3431171774864197
#
#
# Shame	2011
# 	https://www.imdb.com/title/tt1723811/
# 	Avg. Rating: 7.2
# 	# Votes: 175304
# 	Similarity: 0.32840582728385925
#
#
# Flanders	2006
# 	https://www.imdb.com/title/tt0450680/
# 	Avg. Rating: 6.5
# 	# Votes: 2728
# 	Similarity: 0.325125515460968
#
#
# Lars and the Real Girl	2007
# 	https://www.imdb.com/title/tt0805564/
# 	Avg. Rating: 7.3
# 	# Votes: 133658
# 	Similarity: 0.32421693205833435
#
#
# Kadosh	1999
# 	https://www.imdb.com/title/tt0189630/
# 	Avg. Rating: 6.8
# 	# Votes: 1662
# 	Similarity: 0.3237183690071106
#
#
# Departure	2015
# 	https://www.imdb.com/title/tt2248739/
# 	Avg. Rating: 6.7
# 	# Votes: 1821
# 	Similarity: 0.3200188875198364
#
#
# Rendez-vous	1985
# 	https://www.imdb.com/title/tt0089902/
# 	Avg. Rating: 6.6
# 	# Votes: 2253
# 	Similarity: 0.31966662406921387
#
#
# Sukiyaki Western Django	2007
# 	https://www.imdb.com/title/tt0906665/
# 	Avg. Rating: 6.2
# 	# Votes: 14212
# 	Similarity: 0.3182726502418518
#
#
# Shotgun Stories	2007
# 	https://www.imdb.com/title/tt0952682/
# 	Avg. Rating: 7.2
# 	# Votes: 9443
# 	Similarity: 0.31803256273269653
#
#
# Certified Copy	2010
# 	https://www.imdb.com/title/tt1020773/
# 	Avg. Rating: 7.3
# 	# Votes: 19238
# 	Similarity: 0.31375575065612793
#
#
# Blessed	2009
# 	https://www.imdb.com/title/tt1282024/
# 	Avg. Rating: 6.7
# 	# Votes: 663
# 	Similarity: 0.3109307289123535
#
#
# Rabbit Hole	2010
# 	https://www.imdb.com/title/tt0935075/
# 	Avg. Rating: 7.0
# 	# Votes: 45977
# 	Similarity: 0.31079378724098206
#
#
# A Girl Cut in Two	2007
# 	https://www.imdb.com/title/tt0901485/
# 	Avg. Rating: 6.3
# 	# Votes: 3349
# 	Similarity: 0.3095431923866272
#
#
# Welcome	2009
# 	https://www.imdb.com/title/tt1314280/
# 	Avg. Rating: 7.5
# 	# Votes: 6908
# 	Similarity: 0.3095248341560364
#
#
# Shine a Light	2008
# 	https://www.imdb.com/title/tt0893382/
# 	Avg. Rating: 7.2
# 	# Votes: 10690
# 	Similarity: 0.3089783191680908
#
#
# Off the Map	2003
# 	https://www.imdb.com/title/tt0332285/
# 	Avg. Rating: 7.2
# 	# Votes: 3146
# 	Similarity: 0.3062368929386139
#
#
# The Descendants	2011
# 	https://www.imdb.com/title/tt1033575/
# 	Avg. Rating: 7.3
# 	# Votes: 226417
# 	Similarity: 0.3052549362182617
#
#
# The Babysitters	2007
# 	https://www.imdb.com/title/tt0796302/
# 	Avg. Rating: 5.6
# 	# Votes: 10351
# 	Similarity: 0.30148687958717346
#
#
# Il Bidone	1955
# 	https://www.imdb.com/title/tt0047876/
# 	Avg. Rating: 7.5
# 	# Votes: 4514
# 	Similarity: 0.3005243241786957
#
#
# The Young One	1960
# 	https://www.imdb.com/title/tt0053967/
# 	Avg. Rating: 7.4
# 	# Votes: 2309
# 	Similarity: 0.29780107736587524
#
#
# Chinese Take-Out	2011
# 	https://www.imdb.com/title/tt1705786/
# 	Avg. Rating: 7.3
# 	# Votes: 16142
# 	Similarity: 0.2971603572368622
#
#
# The Good Heart	2009
# 	https://www.imdb.com/title/tt0808285/
# 	Avg. Rating: 6.9
# 	# Votes: 4146
# 	Similarity: 0.2956247925758362
#
#
# Good Morning, Night	2003
# 	https://www.imdb.com/title/tt0377569/
# 	Avg. Rating: 7.1
# 	# Votes: 3189
# 	Similarity: 0.29561281204223633
#
#
# The Art of the Steal	2009
# 	https://www.imdb.com/title/tt1326733/
# 	Avg. Rating: 7.6
# 	# Votes: 2179
# 	Similarity: 0.29454708099365234
#
#
# Wilbur Wants to Kill Himself	2002
# 	https://www.imdb.com/title/tt0329767/
# 	Avg. Rating: 6.8
# 	# Votes: 7467
# 	Similarity: 0.29448795318603516
#
#
# Two Men in Manhattan	1959
# 	https://www.imdb.com/title/tt0052733/
# 	Avg. Rating: 6.7
# 	# Votes: 1393
# 	Similarity: 0.2944503724575043
#
#
# Samson & Delilah	2009
# 	https://www.imdb.com/title/tt1340123/
# 	Avg. Rating: 7.0
# 	# Votes: 3097
# 	Similarity: 0.2936677038669586
#
#
# Bright Leaves	2003
# 	https://www.imdb.com/title/tt0372806/
# 	Avg. Rating: 7.1
# 	# Votes: 569
# 	Similarity: 0.2922306954860687
#
#
# Pierrot le Fou	1965
# 	https://www.imdb.com/title/tt0059592/
# 	Avg. Rating: 7.6
# 	# Votes: 26351
# 	Similarity: 0.29206186532974243
#
#
# Hunger	2008
# 	https://www.imdb.com/title/tt0986233/
# 	Avg. Rating: 7.6
# 	# Votes: 62703
# 	Similarity: 0.29144954681396484
#
#
# La Strada	1954
# 	https://www.imdb.com/title/tt0047528/
# 	Avg. Rating: 8.0
# 	# Votes: 54582
# 	Similarity: 0.29110756516456604
#
#
# The Blue Room	2014
# 	https://www.imdb.com/title/tt3230082/
# 	Avg. Rating: 6.3
# 	# Votes: 2953
# 	Similarity: 0.2902488112449646
#
#
# Chicago 10	2007
# 	https://www.imdb.com/title/tt0905979/
# 	Avg. Rating: 7.4
# 	# Votes: 1162
# 	Similarity: 0.2900339365005493
#
#
# Gainsbourg: A Heroic Life	2010
# 	https://www.imdb.com/title/tt1329457/
# 	Avg. Rating: 6.9
# 	# Votes: 9138
# 	Similarity: 0.289663702249527
#
#
# Goodbye, Dragon Inn	2003
# 	https://www.imdb.com/title/tt0377556/
# 	Avg. Rating: 7.1
# 	# Votes: 3680
# 	Similarity: 0.2885567545890808
#
#
# The Life Before Her Eyes	2007
# 	https://www.imdb.com/title/tt0815178/
# 	Avg. Rating: 6.4
# 	# Votes: 13268
# 	Similarity: 0.28846028447151184
#
#
# Crimes and Misdemeanors	1989
# 	https://www.imdb.com/title/tt0097123/
# 	Avg. Rating: 7.9
# 	# Votes: 51826
# 	Similarity: 0.28773927688598633
#
#
# Museum Hours	2012
# 	https://www.imdb.com/title/tt2268732/
# 	Avg. Rating: 6.9
# 	# Votes: 1839
# 	Similarity: 0.2877369523048401
#
#
# Breakfast with Scot	2007
# 	https://www.imdb.com/title/tt0910847/
# 	Avg. Rating: 6.8
# 	# Votes: 2857
# 	Similarity: 0.2877175211906433
#
#
# A Royal Affair	2012
# 	https://www.imdb.com/title/tt1276419/
# 	Avg. Rating: 7.5
# 	# Votes: 41970
# 	Similarity: 0.28620201349258423
#
#
# The Last Mitterrand	2005
# 	https://www.imdb.com/title/tt0364301/
# 	Avg. Rating: 7.1
# 	# Votes: 958
# 	Similarity: 0.2856663465499878
#
#
# 4 Months, 3 Weeks and 2 Days	2007
# 	https://www.imdb.com/title/tt1032846/
# 	Avg. Rating: 7.9
# 	# Votes: 53494
# 	Similarity: 0.2856558561325073
#
#
# Colonel Redl	1985
# 	https://www.imdb.com/title/tt0089716/
# 	Avg. Rating: 7.6
# 	# Votes: 2516
# 	Similarity: 0.28539741039276123
#
#
# To the Wonder	2012
# 	https://www.imdb.com/title/tt1595656/
# 	Avg. Rating: 5.9
# 	# Votes: 25995
# 	Similarity: 0.28464388847351074
#
#
# Amour	2012
# 	https://www.imdb.com/title/tt1602620/
# 	Avg. Rating: 7.9
# 	# Votes: 87520
# 	Similarity: 0.28437066078186035
#
#
# Meek's Cutoff	2010
# 	https://www.imdb.com/title/tt1518812/
# 	Avg. Rating: 6.5
# 	# Votes: 10893
# 	Similarity: 0.2840418517589569
#
#
# Tous les matins du monde	1991
# 	https://www.imdb.com/title/tt0103110/
# 	Avg. Rating: 7.5
# 	# Votes: 6102
# 	Similarity: 0.2832987308502197
#
#
# I Just Didn't Do It	2006
# 	https://www.imdb.com/title/tt0794350/
# 	Avg. Rating: 7.6
# 	# Votes: 1365
# 	Similarity: 0.2830007076263428
#
#
# I Wish	2011
# 	https://www.imdb.com/title/tt1650453/
# 	Avg. Rating: 7.4
# 	# Votes: 5515
# 	Similarity: 0.2827409505844116
#
#
# The White Diamond	2004
# 	https://www.imdb.com/title/tt0435776/
# 	Avg. Rating: 7.5
# 	# Votes: 4141
# 	Similarity: 0.28169193863868713
#
#
# Blue Is the Warmest Color	2013
# 	https://www.imdb.com/title/tt2278871/
# 	Avg. Rating: 7.7
# 	# Votes: 129237
# 	Similarity: 0.28079771995544434
#
#
# 4 Moons	2014
# 	https://www.imdb.com/title/tt2260850/
# 	Avg. Rating: 7.5
# 	# Votes: 3599
# 	Similarity: 0.2799381613731384
#
#
# Le Bonheur	1965
# 	https://www.imdb.com/title/tt0058985/
# 	Avg. Rating: 7.6
# 	# Votes: 4468
# 	Similarity: 0.27900761365890503
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.27841395139694214
#
#
# Caterina in the Big City	2003
# 	https://www.imdb.com/title/tt0366287/
# 	Avg. Rating: 6.8
# 	# Votes: 2551
# 	Similarity: 0.2770307660102844
#
#
# Little White Lies	2010
# 	https://www.imdb.com/title/tt1440232/
# 	Avg. Rating: 7.1
# 	# Votes: 22585
# 	Similarity: 0.2765518128871918
#
#
# House of Tolerance	2011
# 	https://www.imdb.com/title/tt1660379/
# 	Avg. Rating: 6.7
# 	# Votes: 5811
# 	Similarity: 0.27626389265060425
#
#
# The Cook, the Thief, His Wife & Her Lover	1989
# 	https://www.imdb.com/title/tt0097108/
# 	Avg. Rating: 7.6
# 	# Votes: 32751
# 	Similarity: 0.2757534086704254
#
#
# Oedipus Rex	1967
# 	https://www.imdb.com/title/tt0061613/
# 	Avg. Rating: 7.4
# 	# Votes: 4652
# 	Similarity: 0.27465900778770447
#
#
# The Limits of Control	2009
# 	https://www.imdb.com/title/tt1135092/
# 	Avg. Rating: 6.3
# 	# Votes: 18731
# 	Similarity: 0.2734864056110382
#
#
# The Savages	2007
# 	https://www.imdb.com/title/tt0775529/
# 	Avg. Rating: 7.1
# 	# Votes: 34917
# 	Similarity: 0.2733948230743408
#
#
# A Zed & Two Noughts	1985
# 	https://www.imdb.com/title/tt0090366/
# 	Avg. Rating: 7.4
# 	# Votes: 6041
# 	Similarity: 0.2725748121738434
#
#
# Sympathy for Mr. Vengeance	2002
# 	https://www.imdb.com/title/tt0310775/
# 	Avg. Rating: 7.6
# 	# Votes: 57967
# 	Similarity: 0.27190935611724854
#
#
# Towelhead	2007
# 	https://www.imdb.com/title/tt0787523/
# 	Avg. Rating: 6.9
# 	# Votes: 11161
# 	Similarity: 0.27088508009910583
#
#
# Susana	1951
# 	https://www.imdb.com/title/tt0043018/
# 	Avg. Rating: 7.2
# 	# Votes: 1709
# 	Similarity: 0.27075791358947754
#
#
# La Grande Bouffe	1973
# 	https://www.imdb.com/title/tt0070130/
# 	Avg. Rating: 7.2
# 	# Votes: 11038
# 	Similarity: 0.270698219537735
#
#
# Breath	2007
# 	https://www.imdb.com/title/tt0901475/
# 	Avg. Rating: 6.9
# 	# Votes: 4363
# 	Similarity: 0.2697684168815613
#
#
# Under the Hawthorn Tree	2010
# 	https://www.imdb.com/title/tt1554523/
# 	Avg. Rating: 7.1
# 	# Votes: 2569
# 	Similarity: 0.26936855912208557
#
#
# Palindromes	2004
# 	https://www.imdb.com/title/tt0362004/
# 	Avg. Rating: 6.7
# 	# Votes: 11733
# 	Similarity: 0.2691708207130432
#
#
# Wendy and Lucy	2008
# 	https://www.imdb.com/title/tt1152850/
# 	Avg. Rating: 7.1
# 	# Votes: 15243
# 	Similarity: 0.2686160206794739
#
#
# Dans Paris	2006
# 	https://www.imdb.com/title/tt0769508/
# 	Avg. Rating: 6.5
# 	# Votes: 3793
# 	Similarity: 0.26836344599723816
#
#
# Revolutionary Road	2008
# 	https://www.imdb.com/title/tt0959337/
# 	Avg. Rating: 7.3
# 	# Votes: 184287
# 	Similarity: 0.2680509686470032
#
#
# Lucky Miles	2007
# 	https://www.imdb.com/title/tt0452644/
# 	Avg. Rating: 7.1
# 	# Votes: 708
# 	Similarity: 0.2679751515388489
#
#
# Time of the Gypsies	1988
# 	https://www.imdb.com/title/tt0097223/
# 	Avg. Rating: 8.3
# 	# Votes: 23250
# 	Similarity: 0.26796966791152954
#
#
# Elephant	2003
# 	https://www.imdb.com/title/tt0363589/
# 	Avg. Rating: 7.2
# 	# Votes: 82249
# 	Similarity: 0.267162561416626
#
#
# Happy-Go-Lucky	2008
# 	https://www.imdb.com/title/tt1045670/
# 	Avg. Rating: 7.0
# 	# Votes: 36448
# 	Similarity: 0.26711857318878174
#
#
# Beasts of the Southern Wild	2012
# 	https://www.imdb.com/title/tt2125435/
# 	Avg. Rating: 7.3
# 	# Votes: 78511
# 	Similarity: 0.2670289874076843
#
#
# The Robber	2010
# 	https://www.imdb.com/title/tt1339161/
# 	Avg. Rating: 6.8
# 	# Votes: 4182
# 	Similarity: 0.26646333932876587
#
#
# Happy, Happy	2010
# 	https://www.imdb.com/title/tt1664892/
# 	Avg. Rating: 6.5
# 	# Votes: 2876
# 	Similarity: 0.26643815636634827
#
#
# Tales from the Script	2009
# 	https://www.imdb.com/title/tt1045642/
# 	Avg. Rating: 7.1
# 	# Votes: 1408
# 	Similarity: 0.2661818861961365
#
#
# Trust	2010
# 	https://www.imdb.com/title/tt1529572/
# 	Avg. Rating: 6.9
# 	# Votes: 40008
# 	Similarity: 0.2661530375480652
#
#
# Killer Joe	2011
# 	https://www.imdb.com/title/tt1726669/
# 	Avg. Rating: 6.7
# 	# Votes: 69358
# 	Similarity: 0.26592445373535156
#
#
# Fill the Void	2012
# 	https://www.imdb.com/title/tt2219514/
# 	Avg. Rating: 6.7
# 	# Votes: 3523
# 	Similarity: 0.264926016330719
#
#
# Route Irish	2010
# 	https://www.imdb.com/title/tt1528312/
# 	Avg. Rating: 6.4
# 	# Votes: 4101
# 	Similarity: 0.2649037837982178
#
#
# Mister Lonely	2007
# 	https://www.imdb.com/title/tt0475984/
# 	Avg. Rating: 6.5
# 	# Votes: 7110
# 	Similarity: 0.2648466229438782
#
#
# 3	2010
# 	https://www.imdb.com/title/tt1517177/
# 	Avg. Rating: 6.7
# 	# Votes: 4803
# 	Similarity: 0.2646713852882385
#
#
# Mammoth	2009
# 	https://www.imdb.com/title/tt1038043/
# 	Avg. Rating: 6.8
# 	# Votes: 9433
# 	Similarity: 0.26459449529647827
#
#
# Since Otar Left	2003
# 	https://www.imdb.com/title/tt0336264/
# 	Avg. Rating: 7.5
# 	# Votes: 2473
# 	Similarity: 0.26395896077156067
#
#
# Natural Selection	2011
# 	https://www.imdb.com/title/tt1621426/
# 	Avg. Rating: 6.5
# 	# Votes: 1282
# 	Similarity: 0.2634907066822052
#
#
# Trash Humpers	2009
# 	https://www.imdb.com/title/tt1488163/
# 	Avg. Rating: 5.0
# 	# Votes: 4081
# 	Similarity: 0.2627592086791992
#
#
# Compartiment tueurs	1965
# 	https://www.imdb.com/title/tt0059050/
# 	Avg. Rating: 7.3
# 	# Votes: 1314
# 	Similarity: 0.2627580165863037
#
#
# Rampage	1987
# 	https://www.imdb.com/title/tt0095958/
# 	Avg. Rating: 6.3
# 	# Votes: 1848
# 	Similarity: 0.2621691823005676
#
#
# RocknRolla	2008
# 	https://www.imdb.com/title/tt1032755/
# 	Avg. Rating: 7.3
# 	# Votes: 224457
# 	Similarity: 0.26214396953582764
#
#
# The Man Without a Past	2002
# 	https://www.imdb.com/title/tt0311519/
# 	Avg. Rating: 7.7
# 	# Votes: 20955
# 	Similarity: 0.26187169551849365
#
#
# The City of Your Final Destination	2009
# 	https://www.imdb.com/title/tt0896923/
# 	Avg. Rating: 6.3
# 	# Votes: 2727
# 	Similarity: 0.26182836294174194
#
#
# The Secrets	2007
# 	https://www.imdb.com/title/tt0782867/
# 	Avg. Rating: 7.0
# 	# Votes: 1853
# 	Similarity: 0.2617873251438141

# %% [markdown]
# ### Compare two test cases for v1

# %%
#Compare the unique recs of settings 7 and 11 from above.
#The param difference is that setting 7 uses movies rated 4 and above,
#while setting 11 uses movies rated 3.5 and above.

p4 = s.predict(input=good_list, bad_movies=bad_list, n=200, harshness=2, scoring=True)
p35 = s.predict(input=good_3p5_list, bad_movies=bad_list, n=200, harshness=2, scoring=True)

print(len(p4), len(p35))

p4_unique = [x for x in p4 if x[0] not in [x[0] for x in p35]]
p35_unique = [x for x in p35 if x[0] not in [x[0] for x in p4]]

print(len(p4_unique), len(p35_unique))
# Out:
# The model recommended 29 movies that were on the watchlist!
#
# 		 Average Rating: 7.786516853932587
#
# The model recommended 27 movies that were on the watchlist!
#
# 		 Average Rating: 7.732142857142859
#
# 89 84
# 27 22

# %%
for i in p4_unique:
    print(f"{i[0]}\t{i[1]}\n\t{i[2]}")
# Out:
# Le parfum d'Yvonne	1994
# 	https://www.imdb.com/title/tt0110776/
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# Journey to Italy	1954
# 	https://www.imdb.com/title/tt0046511/
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# Manhattan	1979
# 	https://www.imdb.com/title/tt0079522/
# The Circus	1928
# 	https://www.imdb.com/title/tt0018773/
# Cold War	2018
# 	https://www.imdb.com/title/tt6543652/
# Aguirre, the Wrath of God	1972
# 	https://www.imdb.com/title/tt0068182/
# La Dolce Vita	1960
# 	https://www.imdb.com/title/tt0053779/
# The Thin Blue Line	1988
# 	https://www.imdb.com/title/tt0096257/
# Lancelot of the Lake	1974
# 	https://www.imdb.com/title/tt0071737/
# Conversation Piece	1974
# 	https://www.imdb.com/title/tt0071585/
# 4 Months, 3 Weeks and 2 Days	2007
# 	https://www.imdb.com/title/tt1032846/
# Romero	1989
# 	https://www.imdb.com/title/tt0098219/
# Stagecoach	1939
# 	https://www.imdb.com/title/tt0031971/
# Miller's Crossing	1990
# 	https://www.imdb.com/title/tt0100150/
# Ankur: The Seedling	1974
# 	https://www.imdb.com/title/tt0071145/
# Mera Naam Joker	1970
# 	https://www.imdb.com/title/tt0066070/
# Stranger Than Paradise	1984
# 	https://www.imdb.com/title/tt0088184/
# Sandra	1965
# 	https://www.imdb.com/title/tt0059856/
# The Story of the Last Chrysanthemum	1939
# 	https://www.imdb.com/title/tt0032156/
# Bikram: Yogi, Guru, Predator	2019
# 	https://www.imdb.com/title/tt10883004/
# The Handmaiden	2016
# 	https://www.imdb.com/title/tt4016934/
# The Five Senses	1999
# 	https://www.imdb.com/title/tt0168794/
# My Man Godfrey	1936
# 	https://www.imdb.com/title/tt0028010/
# Notes on Blindness	2016
# 	https://www.imdb.com/title/tt5117222/
# The Mirror	1975
# 	https://www.imdb.com/title/tt0072443/

# %%
for i in p35_unique:
    print(f"{i[0]}\t{i[1]}\n\t{i[2]}")
# Out:
# Once Upon a Time in High School: The Spirit of Jeet Kune Do	2004
# 	https://www.imdb.com/title/tt0390205/
# Chillar Party	2011
# 	https://www.imdb.com/title/tt1841542/
# Angel's Egg	1985
# 	https://www.imdb.com/title/tt0208502/
# Unacknowledged	2017
# 	https://www.imdb.com/title/tt6400614/
# Lootera	2013
# 	https://www.imdb.com/title/tt2224317/
# Awe!	2018
# 	https://www.imdb.com/title/tt7797658/
# Vada Chennai	2018
# 	https://www.imdb.com/title/tt5959980/
# Aruvi	2016
# 	https://www.imdb.com/title/tt5867800/
# Big Fish & Begonia	2016
# 	https://www.imdb.com/title/tt1920885/
# Thithi	2015
# 	https://www.imdb.com/title/tt4881362/
# Boy and the World	2013
# 	https://www.imdb.com/title/tt3183630/
# Neon Genesis Evangelion: The End of Evangelion	1997
# 	https://www.imdb.com/title/tt0169858/
# That Girl in Yellow Boots	2010
# 	https://www.imdb.com/title/tt1580704/
# The Breath	2009
# 	https://www.imdb.com/title/tt1171701/
# The Stupids	1996
# 	https://www.imdb.com/title/tt0117768/
# To the Wonder	2012
# 	https://www.imdb.com/title/tt1595656/
# The Meyerowitz Stories	2017
# 	https://www.imdb.com/title/tt5536736/
# Aspen Extreme	1993
# 	https://www.imdb.com/title/tt0106315/
# I Went Down	1997
# 	https://www.imdb.com/title/tt0126344/
# The Kingdom of Dreams and Madness	2013
# 	https://www.imdb.com/title/tt3204392/
# Heat	1995
# 	https://www.imdb.com/title/tt0113277/
# Ravening	2019
# 	https://www.imdb.com/title/tt9010522/
# Vaaranam Aayiram	2008
# 	https://www.imdb.com/title/tt1180583/
# El Mariachi	1992
# 	https://www.imdb.com/title/tt0104815/
# Tamasha	2015
# 	https://www.imdb.com/title/tt3148502/
# Bliss	1997
# 	https://www.imdb.com/title/tt0118742/
# Thamaasha	2019
# 	https://www.imdb.com/title/tt10187686/
# Chittagong	2012
# 	https://www.imdb.com/title/tt1785333/
# Kapoor & Sons	2016
# 	https://www.imdb.com/title/tt4900716/
# Inescapable	2012
# 	https://www.imdb.com/title/tt1844203/
# Birdman or (The Unexpected Virtue of Ignorance)	2014
# 	https://www.imdb.com/title/tt2562232/
# War Dogs	2016
# 	https://www.imdb.com/title/tt2005151/
# Spotlight	2015
# 	https://www.imdb.com/title/tt1895587/
# Suture	1993
# 	https://www.imdb.com/title/tt0108260/
# Gangs of Wasseypur	2012
# 	https://www.imdb.com/title/tt1954470/
# Asuran	2019
# 	https://www.imdb.com/title/tt9477520/
# Inside Llewyn Davis	2013
# 	https://www.imdb.com/title/tt2042568/

# %% [markdown]
# ### Examine ideal case

# %%
prediction = s.predict(input=good_list, bad_movies=bad_list, n=200, harshness=2)
for i in prediction:
    print(f"{i[0]}\t{i[1]}\n\t{i[2]}\n\tAvg. Rating: {i[3]}\n\t# Votes: {i[4]}\n\tSimilarity: {i[5]}\n\n")
# Out:
# One Flew Over the Cuckoo's Nest	1975
# 	https://www.imdb.com/title/tt0073486/
# 	Avg. Rating: 8.7
# 	# Votes: 860775
# 	Similarity: 0.637021541595459
#
#
# The Devil, Probably	1977
# 	https://www.imdb.com/title/tt0075938/
# 	Avg. Rating: 7.3
# 	# Votes: 3150
# 	Similarity: 0.6019104719161987
#
#
# Do the Right Thing	1989
# 	https://www.imdb.com/title/tt0097216/
# 	Avg. Rating: 7.9
# 	# Votes: 78577
# 	Similarity: 0.5995447635650635
#
#
# Chinatown	1974
# 	https://www.imdb.com/title/tt0071315/
# 	Avg. Rating: 8.2
# 	# Votes: 275306
# 	Similarity: 0.5974133014678955
#
#
# Sunset Blvd.	1950
# 	https://www.imdb.com/title/tt0043014/
# 	Avg. Rating: 8.4
# 	# Votes: 186742
# 	Similarity: 0.5961176753044128
#
#
# On the Waterfront	1954
# 	https://www.imdb.com/title/tt0047296/
# 	Avg. Rating: 8.1
# 	# Votes: 132973
# 	Similarity: 0.5904337763786316
#
#
# La Collectionneuse	1967
# 	https://www.imdb.com/title/tt0061495/
# 	Avg. Rating: 7.5
# 	# Votes: 5523
# 	Similarity: 0.5855226516723633
#
#
# The Elephant Man	1980
# 	https://www.imdb.com/title/tt0080678/
# 	Avg. Rating: 8.1
# 	# Votes: 206385
# 	Similarity: 0.5850623846054077
#
#
# Mulholland Dr.	2001
# 	https://www.imdb.com/title/tt0166924/
# 	Avg. Rating: 7.9
# 	# Votes: 299680
# 	Similarity: 0.5803588032722473
#
#
# American Psycho	2000
# 	https://www.imdb.com/title/tt0144084/
# 	Avg. Rating: 7.6
# 	# Votes: 450780
# 	Similarity: 0.5798133015632629
#
#
# Mommy	2014
# 	https://www.imdb.com/title/tt3612616/
# 	Avg. Rating: 8.1
# 	# Votes: 45282
# 	Similarity: 0.5735290050506592
#
#
# Schindler's List	1993
# 	https://www.imdb.com/title/tt0108052/
# 	Avg. Rating: 8.9
# 	# Votes: 1138968
# 	Similarity: 0.5707247257232666
#
#
# Clash	2016
# 	https://www.imdb.com/title/tt5599692/
# 	Avg. Rating: 7.5
# 	# Votes: 4437
# 	Similarity: 0.5705288648605347
#
#
# Singin' in the Rain	1952
# 	https://www.imdb.com/title/tt0045152/
# 	Avg. Rating: 8.3
# 	# Votes: 204746
# 	Similarity: 0.5704002380371094
#
#
# Casino	1995
# 	https://www.imdb.com/title/tt0112641/
# 	Avg. Rating: 8.2
# 	# Votes: 432378
# 	Similarity: 0.5684496164321899
#
#
# It's a Wonderful Life	1946
# 	https://www.imdb.com/title/tt0038650/
# 	Avg. Rating: 8.6
# 	# Votes: 374566
# 	Similarity: 0.5684366226196289
#
#
# The Long Day Closes	1992
# 	https://www.imdb.com/title/tt0104753/
# 	Avg. Rating: 7.4
# 	# Votes: 2541
# 	Similarity: 0.56637042760849
#
#
# Love Affair, or The Case of the Missing Switchboard Operator	1967
# 	https://www.imdb.com/title/tt0061912/
# 	Avg. Rating: 7.4
# 	# Votes: 1394
# 	Similarity: 0.5659621953964233
#
#
# The Bridge on the River Kwai	1957
# 	https://www.imdb.com/title/tt0050212/
# 	Avg. Rating: 8.1
# 	# Votes: 191813
# 	Similarity: 0.5659129619598389
#
#
# His Girl Friday	1940
# 	https://www.imdb.com/title/tt0032599/
# 	Avg. Rating: 7.9
# 	# Votes: 50020
# 	Similarity: 0.5656683444976807
#
#
# This Is Spinal Tap	1984
# 	https://www.imdb.com/title/tt0088258/
# 	Avg. Rating: 7.9
# 	# Votes: 123100
# 	Similarity: 0.565614640712738
#
#
# Bonnie and Clyde	1967
# 	https://www.imdb.com/title/tt0061418/
# 	Avg. Rating: 7.8
# 	# Votes: 97109
# 	Similarity: 0.5655946731567383
#
#
# That Obscure Object of Desire	1977
# 	https://www.imdb.com/title/tt0075824/
# 	Avg. Rating: 7.9
# 	# Votes: 18958
# 	Similarity: 0.564788818359375
#
#
# The Last Supper	1976
# 	https://www.imdb.com/title/tt0075363/
# 	Avg. Rating: 7.5
# 	# Votes: 518
# 	Similarity: 0.5646094083786011
#
#
# Heat	1995
# 	https://www.imdb.com/title/tt0113277/
# 	Avg. Rating: 8.2
# 	# Votes: 541306
# 	Similarity: 0.5635089874267578
#
#
# King Lear	1970
# 	https://www.imdb.com/title/tt0064553/
# 	Avg. Rating: 8.1
# 	# Votes: 1323
# 	Similarity: 0.5610218048095703
#
#
# Effi Briest	1974
# 	https://www.imdb.com/title/tt0071458/
# 	Avg. Rating: 6.9
# 	# Votes: 2091
# 	Similarity: 0.5599777698516846
#
#
# Life Is Beautiful	1997
# 	https://www.imdb.com/title/tt0118799/
# 	Avg. Rating: 8.6
# 	# Votes: 577812
# 	Similarity: 0.5598816871643066
#
#
# Paths of Glory	1957
# 	https://www.imdb.com/title/tt0050825/
# 	Avg. Rating: 8.4
# 	# Votes: 163638
# 	Similarity: 0.5594697594642639
#
#
# Cinema Paradiso	1988
# 	https://www.imdb.com/title/tt0095765/
# 	Avg. Rating: 8.5
# 	# Votes: 211046
# 	Similarity: 0.5583636164665222
#
#
# Memories of a Marriage	1989
# 	https://www.imdb.com/title/tt0097155/
# 	Avg. Rating: 7.0
# 	# Votes: 611
# 	Similarity: 0.5579560995101929
#
#
# The Killing	1956
# 	https://www.imdb.com/title/tt0049406/
# 	Avg. Rating: 8.0
# 	# Votes: 76183
# 	Similarity: 0.5578919053077698
#
#
# Eyes Wide Shut	1999
# 	https://www.imdb.com/title/tt0120663/
# 	Avg. Rating: 7.4
# 	# Votes: 282165
# 	Similarity: 0.5574255585670471
#
#
# The Deer Hunter	1978
# 	https://www.imdb.com/title/tt0077416/
# 	Avg. Rating: 8.1
# 	# Votes: 293399
# 	Similarity: 0.5572633743286133
#
#
# Le parfum d'Yvonne	1994
# 	https://www.imdb.com/title/tt0110776/
# 	Avg. Rating: 6.5
# 	# Votes: 971
# 	Similarity: 0.5565727949142456
#
#
# Man Is Not a Bird	1965
# 	https://www.imdb.com/title/tt0059063/
# 	Avg. Rating: 7.2
# 	# Votes: 961
# 	Similarity: 0.55650794506073
#
#
# Abacus: Small Enough to Jail	2016
# 	https://www.imdb.com/title/tt5952382/
# 	Avg. Rating: 7.2
# 	# Votes: 2508
# 	Similarity: 0.5564699172973633
#
#
# So Long, My Son	2019
# 	https://www.imdb.com/title/tt9581076/
# 	Avg. Rating: 7.7
# 	# Votes: 1596
# 	Similarity: 0.5563457012176514
#
#
# A Moment of Innocence	1996
# 	https://www.imdb.com/title/tt0117214/
# 	Avg. Rating: 7.9
# 	# Votes: 2804
# 	Similarity: 0.555978536605835
#
#
# Monty Python's Life of Brian	1979
# 	https://www.imdb.com/title/tt0079470/
# 	Avg. Rating: 8.1
# 	# Votes: 346002
# 	Similarity: 0.5546754598617554
#
#
# Beautiful	1951
# 	https://www.imdb.com/title/tt0043332/
# 	Avg. Rating: 7.8
# 	# Votes: 3685
# 	Similarity: 0.5541081428527832
#
#
# Shanghai	2012
# 	https://www.imdb.com/title/tt2072227/
# 	Avg. Rating: 7.2
# 	# Votes: 9203
# 	Similarity: 0.5538479089736938
#
#
# Floating Weeds	1959
# 	https://www.imdb.com/title/tt0053390/
# 	Avg. Rating: 8.0
# 	# Votes: 6592
# 	Similarity: 0.5523635149002075
#
#
# Journey to Italy	1954
# 	https://www.imdb.com/title/tt0046511/
# 	Avg. Rating: 7.4
# 	# Votes: 7980
# 	Similarity: 0.5519384145736694
#
#
# The War Is Over	1966
# 	https://www.imdb.com/title/tt0060481/
# 	Avg. Rating: 7.3
# 	# Votes: 1809
# 	Similarity: 0.5510011315345764
#
#
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# 	Avg. Rating: 8.0
# 	# Votes: 3332
# 	Similarity: 0.5500478744506836
#
#
# For Sama	2019
# 	https://www.imdb.com/title/tt9617456/
# 	Avg. Rating: 8.6
# 	# Votes: 1900
# 	Similarity: 0.5499578714370728
#
#
# Lolita	1962
# 	https://www.imdb.com/title/tt0056193/
# 	Avg. Rating: 7.6
# 	# Votes: 86559
# 	Similarity: 0.5497459173202515
#
#
# Manhattan	1979
# 	https://www.imdb.com/title/tt0079522/
# 	Avg. Rating: 7.9
# 	# Votes: 124936
# 	Similarity: 0.5493083000183105
#
#
# Tales from the Gimli Hospital	1988
# 	https://www.imdb.com/title/tt0096218/
# 	Avg. Rating: 6.6
# 	# Votes: 1182
# 	Similarity: 0.5490767955780029
#
#
# Pelli Choopulu	2016
# 	https://www.imdb.com/title/tt5824826/
# 	Avg. Rating: 8.3
# 	# Votes: 4624
# 	Similarity: 0.5489094257354736
#
#
# Pan's Labyrinth	2006
# 	https://www.imdb.com/title/tt0457430/
# 	Avg. Rating: 8.2
# 	# Votes: 588428
# 	Similarity: 0.5482964515686035
#
#
# The Killing of a Sacred Deer	2017
# 	https://www.imdb.com/title/tt5715874/
# 	Avg. Rating: 7.0
# 	# Votes: 100970
# 	Similarity: 0.5480961203575134
#
#
# The Circus	1928
# 	https://www.imdb.com/title/tt0018773/
# 	Avg. Rating: 8.2
# 	# Votes: 24017
# 	Similarity: 0.5475348234176636
#
#
# Some Like It Hot	1959
# 	https://www.imdb.com/title/tt0053291/
# 	Avg. Rating: 8.2
# 	# Votes: 228904
# 	Similarity: 0.5475244522094727
#
#
# Cold War	2018
# 	https://www.imdb.com/title/tt6543652/
# 	Avg. Rating: 7.6
# 	# Votes: 40124
# 	Similarity: 0.5474047660827637
#
#
# Bright Future	2002
# 	https://www.imdb.com/title/tt0363235/
# 	Avg. Rating: 6.8
# 	# Votes: 2431
# 	Similarity: 0.5463124513626099
#
#
# Still Walking	2008
# 	https://www.imdb.com/title/tt1087578/
# 	Avg. Rating: 8.0
# 	# Votes: 11847
# 	Similarity: 0.546265721321106
#
#
# Aguirre, the Wrath of God	1972
# 	https://www.imdb.com/title/tt0068182/
# 	Avg. Rating: 8.0
# 	# Votes: 48551
# 	Similarity: 0.5450074672698975
#
#
# Birdman or (The Unexpected Virtue of Ignorance)	2014
# 	https://www.imdb.com/title/tt2562232/
# 	Avg. Rating: 7.7
# 	# Votes: 541750
# 	Similarity: 0.5447478294372559
#
#
# Brother	2010
# 	https://www.imdb.com/title/tt1588358/
# 	Avg. Rating: 7.3
# 	# Votes: 2413
# 	Similarity: 0.5436833500862122
#
#
# La Dolce Vita	1960
# 	https://www.imdb.com/title/tt0053779/
# 	Avg. Rating: 8.0
# 	# Votes: 61072
# 	Similarity: 0.5433980822563171
#
#
# The Thin Blue Line	1988
# 	https://www.imdb.com/title/tt0096257/
# 	Avg. Rating: 8.0
# 	# Votes: 20413
# 	Similarity: 0.543150007724762
#
#
# Lancelot of the Lake	1974
# 	https://www.imdb.com/title/tt0071737/
# 	Avg. Rating: 7.0
# 	# Votes: 3157
# 	Similarity: 0.5430499315261841
#
#
# 12 Monkeys	1995
# 	https://www.imdb.com/title/tt0114746/
# 	Avg. Rating: 8.0
# 	# Votes: 551324
# 	Similarity: 0.5425547361373901
#
#
# Asuran	2019
# 	https://www.imdb.com/title/tt9477520/
# 	Avg. Rating: 8.6
# 	# Votes: 5692
# 	Similarity: 0.542016863822937
#
#
# Conversation Piece	1974
# 	https://www.imdb.com/title/tt0071585/
# 	Avg. Rating: 7.5
# 	# Votes: 3627
# 	Similarity: 0.5418083667755127
#
#
# 4 Months, 3 Weeks and 2 Days	2007
# 	https://www.imdb.com/title/tt1032846/
# 	Avg. Rating: 7.9
# 	# Votes: 53494
# 	Similarity: 0.5416526794433594
#
#
# Romero	1989
# 	https://www.imdb.com/title/tt0098219/
# 	Avg. Rating: 7.1
# 	# Votes: 1978
# 	Similarity: 0.5415934324264526
#
#
# Stagecoach	1939
# 	https://www.imdb.com/title/tt0031971/
# 	Avg. Rating: 7.9
# 	# Votes: 39835
# 	Similarity: 0.5411977767944336
#
#
# Miller's Crossing	1990
# 	https://www.imdb.com/title/tt0100150/
# 	Avg. Rating: 7.8
# 	# Votes: 120744
# 	Similarity: 0.5409858226776123
#
#
# Platoon	1986
# 	https://www.imdb.com/title/tt0091763/
# 	Avg. Rating: 8.1
# 	# Votes: 361945
# 	Similarity: 0.5403895974159241
#
#
# Ankur: The Seedling	1974
# 	https://www.imdb.com/title/tt0071145/
# 	Avg. Rating: 8.2
# 	# Votes: 797
# 	Similarity: 0.5400163531303406
#
#
# The Devil's Eye	1960
# 	https://www.imdb.com/title/tt0053772/
# 	Avg. Rating: 7.2
# 	# Votes: 3249
# 	Similarity: 0.5399154424667358
#
#
# Birdwatchers	2008
# 	https://www.imdb.com/title/tt1054674/
# 	Avg. Rating: 6.8
# 	# Votes: 793
# 	Similarity: 0.5390143394470215
#
#
# Mera Naam Joker	1970
# 	https://www.imdb.com/title/tt0066070/
# 	Avg. Rating: 8.0
# 	# Votes: 4331
# 	Similarity: 0.5382165908813477
#
#
# Star Wars: Episode IV - A New Hope	1977
# 	https://www.imdb.com/title/tt0076759/
# 	Avg. Rating: 8.6
# 	# Votes: 1168067
# 	Similarity: 0.5379565358161926
#
#
# Minority Report	2002
# 	https://www.imdb.com/title/tt0181689/
# 	Avg. Rating: 7.6
# 	# Votes: 482321
# 	Similarity: 0.537308931350708
#
#
# Stranger Than Paradise	1984
# 	https://www.imdb.com/title/tt0088184/
# 	Avg. Rating: 7.5
# 	# Votes: 32237
# 	Similarity: 0.5372731685638428
#
#
# Ee. Ma. Yau	2018
# 	https://www.imdb.com/title/tt7231194/
# 	Avg. Rating: 8.3
# 	# Votes: 1567
# 	Similarity: 0.5368318557739258
#
#
# Sandra	1965
# 	https://www.imdb.com/title/tt0059856/
# 	Avg. Rating: 7.2
# 	# Votes: 1564
# 	Similarity: 0.5365461707115173
#
#
# Ravening	2019
# 	https://www.imdb.com/title/tt9010522/
# 	Avg. Rating: 8.5
# 	# Votes: 195
# 	Similarity: 0.5360842943191528
#
#
# The Story of the Last Chrysanthemum	1939
# 	https://www.imdb.com/title/tt0032156/
# 	Avg. Rating: 7.9
# 	# Votes: 2902
# 	Similarity: 0.5359249114990234
#
#
# Bikram: Yogi, Guru, Predator	2019
# 	https://www.imdb.com/title/tt10883004/
# 	Avg. Rating: 6.7
# 	# Votes: 3235
# 	Similarity: 0.5355088710784912
#
#
# The Handmaiden	2016
# 	https://www.imdb.com/title/tt4016934/
# 	Avg. Rating: 8.1
# 	# Votes: 89960
# 	Similarity: 0.5353394746780396
#
#
# The Five Senses	1999
# 	https://www.imdb.com/title/tt0168794/
# 	Avg. Rating: 6.6
# 	# Votes: 2936
# 	Similarity: 0.5351389646530151
#
#
# My Man Godfrey	1936
# 	https://www.imdb.com/title/tt0028010/
# 	Avg. Rating: 8.0
# 	# Votes: 19412
# 	Similarity: 0.5349496603012085
#
#
# Notes on Blindness	2016
# 	https://www.imdb.com/title/tt5117222/
# 	Avg. Rating: 7.1
# 	# Votes: 1780
# 	Similarity: 0.5348818898200989
#
#
# The Mirror	1975
# 	https://www.imdb.com/title/tt0072443/
# 	Avg. Rating: 8.1
# 	# Votes: 34831
# 	Similarity: 0.5348027348518372

# %% [markdown]
# ## Best settings for v2

# %%
"""LimitingFactor_v2 is trained on movies rated 8 stars and above. The first thing I notice 
about it is that, using my movie history, whenever its recommendations get a high
average score, it strays farther an farther from my watchlist. So this is where it may become 
challenging to evaluate the model."""

# focus on the best settings for LimitingFactor_v2
params = [
    (good_3p5_list, bad_list, 2), #11
    (good_3p5_list, bad_list, 3)  #12
]

count = 0
settings = [11, 12]
# Test all the promising parameter sets
for i, j, k in params:
    print(settings[count], "\t")
    prediction = s.predict(input=i, bad_movies=j, n=100, harshness=k, rec_movies=True, show_vibes=False, scoring=True)
    for i in prediction:
        print(f"{i[0]}\t{i[1]}\n\t{i[2]}\n\tAvg. Rating: {i[3]}\n\t# Votes: {i[4]}\n\tSimilarity: {i[5]}\n\n")
    count+=1

"""
Settings graded out of 100:
11... 
12... 




"""
# Out:
# 11
# 23
# 78
# 154
# The model recommended 49 movies that were on the watchlist!
#
# 		 Average Rating: 7.586363636363638
#
# One Flew Over the Cuckoo's Nest	1975
# 	https://www.imdb.com/title/tt0073486/
# 	Avg. Rating: 8.7
# 	# Votes: 860775
# 	Similarity: 0.6070456504821777
#
#
# Schindler's List	1993
# 	https://www.imdb.com/title/tt0108052/
# 	Avg. Rating: 8.9
# 	# Votes: 1138968
# 	Similarity: 0.6057159900665283
#
#
# 78/52: Hitchcock's Shower Scene	2017
# 	https://www.imdb.com/title/tt4372240/
# 	Avg. Rating: 7.3
# 	# Votes: 2652
# 	Similarity: 0.5958279967308044
#
#
# The Last Supper	1976
# 	https://www.imdb.com/title/tt0075363/
# 	Avg. Rating: 7.5
# 	# Votes: 518
# 	Similarity: 0.5952874422073364
#
#
# Casino	1995
# 	https://www.imdb.com/title/tt0112641/
# 	Avg. Rating: 8.2
# 	# Votes: 432378
# 	Similarity: 0.5854454040527344
#
#
# American Psycho	2000
# 	https://www.imdb.com/title/tt0144084/
# 	Avg. Rating: 7.6
# 	# Votes: 450780
# 	Similarity: 0.5853142142295837
#
#
# Chinatown	1974
# 	https://www.imdb.com/title/tt0071315/
# 	Avg. Rating: 8.2
# 	# Votes: 275306
# 	Similarity: 0.5789845585823059
#
#
# Sunset Blvd.	1950
# 	https://www.imdb.com/title/tt0043014/
# 	Avg. Rating: 8.4
# 	# Votes: 186742
# 	Similarity: 0.5697900056838989
#
#
# Mommy	2014
# 	https://www.imdb.com/title/tt3612616/
# 	Avg. Rating: 8.1
# 	# Votes: 45282
# 	Similarity: 0.5676702857017517
#
#
# Pan's Labyrinth	2006
# 	https://www.imdb.com/title/tt0457430/
# 	Avg. Rating: 8.2
# 	# Votes: 588428
# 	Similarity: 0.5668918490409851
#
#
# The Elephant Man	1980
# 	https://www.imdb.com/title/tt0080678/
# 	Avg. Rating: 8.1
# 	# Votes: 206385
# 	Similarity: 0.5662493109703064
#
#
# Raatchasi	2019
# 	https://www.imdb.com/title/tt10431010/
# 	Avg. Rating: 7.3
# 	# Votes: 589
# 	Similarity: 0.565953254699707
#
#
# Brother	2010
# 	https://www.imdb.com/title/tt1588358/
# 	Avg. Rating: 7.3
# 	# Votes: 2413
# 	Similarity: 0.5658589601516724
#
#
# Star Wars: Episode IV - A New Hope	1977
# 	https://www.imdb.com/title/tt0076759/
# 	Avg. Rating: 8.6
# 	# Votes: 1168067
# 	Similarity: 0.5657225847244263
#
#
# Trainspotting	1996
# 	https://www.imdb.com/title/tt0117951/
# 	Avg. Rating: 8.1
# 	# Votes: 606132
# 	Similarity: 0.5656270980834961
#
#
# Heat	1995
# 	https://www.imdb.com/title/tt0113277/
# 	Avg. Rating: 8.2
# 	# Votes: 541306
# 	Similarity: 0.5640144944190979
#
#
# Ravening	2019
# 	https://www.imdb.com/title/tt9010522/
# 	Avg. Rating: 8.5
# 	# Votes: 195
# 	Similarity: 0.5639973282814026
#
#
# Do the Right Thing	1989
# 	https://www.imdb.com/title/tt0097216/
# 	Avg. Rating: 7.9
# 	# Votes: 78577
# 	Similarity: 0.5632853507995605
#
#
# Aruvi	2016
# 	https://www.imdb.com/title/tt5867800/
# 	Avg. Rating: 8.7
# 	# Votes: 9036
# 	Similarity: 0.5621950626373291
#
#
# Floating Weeds	1959
# 	https://www.imdb.com/title/tt0053390/
# 	Avg. Rating: 8.0
# 	# Votes: 6592
# 	Similarity: 0.5620924234390259
#
#
# Aliens	1986
# 	https://www.imdb.com/title/tt0090605/
# 	Avg. Rating: 8.3
# 	# Votes: 619790
# 	Similarity: 0.5620121955871582
#
#
# The Devil, Probably	1977
# 	https://www.imdb.com/title/tt0075938/
# 	Avg. Rating: 7.3
# 	# Votes: 3150
# 	Similarity: 0.5616232752799988
#
#
# 12 Monkeys	1995
# 	https://www.imdb.com/title/tt0114746/
# 	Avg. Rating: 8.0
# 	# Votes: 551324
# 	Similarity: 0.5601765513420105
#
#
# Sawdust and Tinsel	1953
# 	https://www.imdb.com/title/tt0045848/
# 	Avg. Rating: 7.6
# 	# Votes: 5550
# 	Similarity: 0.5597811937332153
#
#
# The Agronomist	2003
# 	https://www.imdb.com/title/tt0377031/
# 	Avg. Rating: 7.4
# 	# Votes: 868
# 	Similarity: 0.5596674084663391
#
#
# Birdman or (The Unexpected Virtue of Ignorance)	2014
# 	https://www.imdb.com/title/tt2562232/
# 	Avg. Rating: 7.7
# 	# Votes: 541750
# 	Similarity: 0.5595698356628418
#
#
# Mulholland Dr.	2001
# 	https://www.imdb.com/title/tt0166924/
# 	Avg. Rating: 7.9
# 	# Votes: 299680
# 	Similarity: 0.5590791702270508
#
#
# It's a Wonderful Life	1946
# 	https://www.imdb.com/title/tt0038650/
# 	Avg. Rating: 8.6
# 	# Votes: 374566
# 	Similarity: 0.5581150054931641
#
#
# Love Affair, or The Case of the Missing Switchboard Operator	1967
# 	https://www.imdb.com/title/tt0061912/
# 	Avg. Rating: 7.4
# 	# Votes: 1394
# 	Similarity: 0.5571741461753845
#
#
# Color Me Kubrick	2005
# 	https://www.imdb.com/title/tt0376543/
# 	Avg. Rating: 6.1
# 	# Votes: 6142
# 	Similarity: 0.5571376085281372
#
#
# Eyes Wide Shut	1999
# 	https://www.imdb.com/title/tt0120663/
# 	Avg. Rating: 7.4
# 	# Votes: 282165
# 	Similarity: 0.5566332340240479
#
#
# Minority Report	2002
# 	https://www.imdb.com/title/tt0181689/
# 	Avg. Rating: 7.6
# 	# Votes: 482321
# 	Similarity: 0.5561339855194092
#
#
# A Moment of Innocence	1996
# 	https://www.imdb.com/title/tt0117214/
# 	Avg. Rating: 7.9
# 	# Votes: 2804
# 	Similarity: 0.5552890300750732
#
#
# Whitey: United States of America v. James J. Bulger	2014
# 	https://www.imdb.com/title/tt3326366/
# 	Avg. Rating: 6.8
# 	# Votes: 2787
# 	Similarity: 0.5547307729721069
#
#
# The Killing of a Sacred Deer	2017
# 	https://www.imdb.com/title/tt5715874/
# 	Avg. Rating: 7.0
# 	# Votes: 100970
# 	Similarity: 0.5541710257530212
#
#
# Madeline's Madeline	2018
# 	https://www.imdb.com/title/tt6101602/
# 	Avg. Rating: 6.4
# 	# Votes: 2909
# 	Similarity: 0.5522677898406982
#
#
# Shanghai	2012
# 	https://www.imdb.com/title/tt2072227/
# 	Avg. Rating: 7.2
# 	# Votes: 9203
# 	Similarity: 0.5499934554100037
#
#
# Manhattan	1979
# 	https://www.imdb.com/title/tt0079522/
# 	Avg. Rating: 7.9
# 	# Votes: 124936
# 	Similarity: 0.54958176612854
#
#
# Star Wars: Episode V - The Empire Strikes Back	1980
# 	https://www.imdb.com/title/tt0080684/
# 	Avg. Rating: 8.7
# 	# Votes: 1095881
# 	Similarity: 0.5493374466896057
#
#
# Flirting	1991
# 	https://www.imdb.com/title/tt0101898/
# 	Avg. Rating: 7.2
# 	# Votes: 5472
# 	Similarity: 0.5490610599517822
#
#
# Pelli Choopulu	2016
# 	https://www.imdb.com/title/tt5824826/
# 	Avg. Rating: 8.3
# 	# Votes: 4624
# 	Similarity: 0.5481967926025391
#
#
# His Girl Friday	1940
# 	https://www.imdb.com/title/tt0032599/
# 	Avg. Rating: 7.9
# 	# Votes: 50020
# 	Similarity: 0.5480201840400696
#
#
# Life Is Beautiful	1997
# 	https://www.imdb.com/title/tt0118799/
# 	Avg. Rating: 8.6
# 	# Votes: 577812
# 	Similarity: 0.5479668974876404
#
#
# Memories of a Marriage	1989
# 	https://www.imdb.com/title/tt0097155/
# 	Avg. Rating: 7.0
# 	# Votes: 611
# 	Similarity: 0.5478112697601318
#
#
# Chashme Buddoor	1981
# 	https://www.imdb.com/title/tt0082162/
# 	Avg. Rating: 8.0
# 	# Votes: 2069
# 	Similarity: 0.5477496981620789
#
#
# Werckmeister Harmonies	2000
# 	https://www.imdb.com/title/tt0249241/
# 	Avg. Rating: 8.2
# 	# Votes: 11693
# 	Similarity: 0.5473290681838989
#
#
# Tales from the Gimli Hospital	1988
# 	https://www.imdb.com/title/tt0096218/
# 	Avg. Rating: 6.6
# 	# Votes: 1182
# 	Similarity: 0.5462737679481506
#
#
# My Name Is Joe	1998
# 	https://www.imdb.com/title/tt0151691/
# 	Avg. Rating: 7.5
# 	# Votes: 7236
# 	Similarity: 0.5462067723274231
#
#
# 13th	2016
# 	https://www.imdb.com/title/tt5895028/
# 	Avg. Rating: 8.2
# 	# Votes: 21078
# 	Similarity: 0.5460242629051208
#
#
# Singin' in the Rain	1952
# 	https://www.imdb.com/title/tt0045152/
# 	Avg. Rating: 8.3
# 	# Votes: 204746
# 	Similarity: 0.5459728240966797
#
#
# Amores Perros	2000
# 	https://www.imdb.com/title/tt0245712/
# 	Avg. Rating: 8.1
# 	# Votes: 212203
# 	Similarity: 0.5458259582519531
#
#
# Summer 1993	2017
# 	https://www.imdb.com/title/tt5897636/
# 	Avg. Rating: 7.1
# 	# Votes: 5151
# 	Similarity: 0.5456125736236572
#
#
# Wheel of Time	2003
# 	https://www.imdb.com/title/tt0331080/
# 	Avg. Rating: 7.1
# 	# Votes: 2067
# 	Similarity: 0.5455676317214966
#
#
# The Handmaiden	2016
# 	https://www.imdb.com/title/tt4016934/
# 	Avg. Rating: 8.1
# 	# Votes: 89960
# 	Similarity: 0.5453145503997803
#
#
# Platoon	1986
# 	https://www.imdb.com/title/tt0091763/
# 	Avg. Rating: 8.1
# 	# Votes: 361945
# 	Similarity: 0.5449163913726807
#
#
# General Idi Amin Dada: A Self Portrait	1974
# 	https://www.imdb.com/title/tt0071544/
# 	Avg. Rating: 7.4
# 	# Votes: 1555
# 	Similarity: 0.5447714328765869
#
#
# Ivan's Childhood	1962
# 	https://www.imdb.com/title/tt0056111/
# 	Avg. Rating: 8.1
# 	# Votes: 27884
# 	Similarity: 0.5445961952209473
#
#
# Cinema Paradiso	1988
# 	https://www.imdb.com/title/tt0095765/
# 	Avg. Rating: 8.5
# 	# Votes: 211046
# 	Similarity: 0.5433292388916016
#
#
# Dog Park	2017
# 	https://www.imdb.com/title/tt7070486/
# 	Avg. Rating: 6.3
# 	# Votes: 59
# 	Similarity: 0.5433250665664673
#
#
# Widow	2009
# 	https://www.imdb.com/title/tt1508702/
# 	Avg. Rating: 5.3
# 	# Votes: 46
# 	Similarity: 0.5426260232925415
#
#
# On the Waterfront	1954
# 	https://www.imdb.com/title/tt0047296/
# 	Avg. Rating: 8.1
# 	# Votes: 132973
# 	Similarity: 0.5423851013183594
#
#
# Monty Python's Life of Brian	1979
# 	https://www.imdb.com/title/tt0079470/
# 	Avg. Rating: 8.1
# 	# Votes: 346002
# 	Similarity: 0.5415267944335938
#
#
# Close-Up	1990
# 	https://www.imdb.com/title/tt0100234/
# 	Avg. Rating: 8.3
# 	# Votes: 13431
# 	Similarity: 0.5413904190063477
#
#
# That Obscure Object of Desire	1977
# 	https://www.imdb.com/title/tt0075824/
# 	Avg. Rating: 7.9
# 	# Votes: 18958
# 	Similarity: 0.5409834980964661
#
#
# Erasing Eden	2016
# 	https://www.imdb.com/title/tt2516326/
# 	Avg. Rating: 5.1
# 	# Votes: 347
# 	Similarity: 0.5409182906150818
#
#
# Easy Rider	1969
# 	https://www.imdb.com/title/tt0064276/
# 	Avg. Rating: 7.3
# 	# Votes: 93567
# 	Similarity: 0.5400384664535522
#
#
# Gate of Flesh	1964
# 	https://www.imdb.com/title/tt0058409/
# 	Avg. Rating: 7.4
# 	# Votes: 2580
# 	Similarity: 0.5398045778274536
#
#
# Ee. Ma. Yau	2018
# 	https://www.imdb.com/title/tt7231194/
# 	Avg. Rating: 8.3
# 	# Votes: 1567
# 	Similarity: 0.5390340089797974
#
#
# The War Is Over	1966
# 	https://www.imdb.com/title/tt0060481/
# 	Avg. Rating: 7.3
# 	# Votes: 1809
# 	Similarity: 0.5384184122085571
#
#
# Torment	1944
# 	https://www.imdb.com/title/tt0036914/
# 	Avg. Rating: 7.3
# 	# Votes: 2968
# 	Similarity: 0.5382590293884277
#
#
# Thanneermathan Dinangal	2019
# 	https://www.imdb.com/title/tt10551608/
# 	Avg. Rating: 8.1
# 	# Votes: 1465
# 	Similarity: 0.5377465486526489
#
#
# Charulata	1964
# 	https://www.imdb.com/title/tt0057935/
# 	Avg. Rating: 8.2
# 	# Votes: 4491
# 	Similarity: 0.53763747215271
#
#
# I Am Kalam	2010
# 	https://www.imdb.com/title/tt1805263/
# 	Avg. Rating: 8.0
# 	# Votes: 3233
# 	Similarity: 0.5374975204467773
#
#
# The Insider	1999
# 	https://www.imdb.com/title/tt0140352/
# 	Avg. Rating: 7.8
# 	# Votes: 153111
# 	Similarity: 0.5373513698577881
#
#
# Are You Glad I'm Here	2018
# 	https://www.imdb.com/title/tt6891516/
# 	Avg. Rating: 7.7
# 	# Votes: 70
# 	Similarity: 0.5372778177261353
#
#
# Hello & Goodbye	2018
# 	https://www.imdb.com/title/tt3100938/
# 	Avg. Rating: 7.1
# 	# Votes: 39
# 	Similarity: 0.5371541976928711
#
#
# The Lobster	2015
# 	https://www.imdb.com/title/tt3464902/
# 	Avg. Rating: 7.2
# 	# Votes: 195345
# 	Similarity: 0.537018895149231
#
#
# My Neighbors the Yamadas	1999
# 	https://www.imdb.com/title/tt0206013/
# 	Avg. Rating: 7.2
# 	# Votes: 9265
# 	Similarity: 0.5367897748947144
#
#
# Spotlight	2015
# 	https://www.imdb.com/title/tt1895587/
# 	Avg. Rating: 8.1
# 	# Votes: 384276
# 	Similarity: 0.5367745161056519
#
#
# People Places Things	2015
# 	https://www.imdb.com/title/tt4104022/
# 	Avg. Rating: 6.9
# 	# Votes: 7685
# 	Similarity: 0.5367695093154907
#
#
# The Life Aquatic with Steve Zissou	2004
# 	https://www.imdb.com/title/tt0362270/
# 	Avg. Rating: 7.3
# 	# Votes: 170437
# 	Similarity: 0.5366498231887817
#
#
# M	1931
# 	https://www.imdb.com/title/tt0022100/
# 	Avg. Rating: 8.3
# 	# Votes: 133369
# 	Similarity: 0.5365552306175232
#
#
# This Is Spinal Tap	1984
# 	https://www.imdb.com/title/tt0088258/
# 	Avg. Rating: 7.9
# 	# Votes: 123100
# 	Similarity: 0.5362763404846191
#
#
# Lolita	1962
# 	https://www.imdb.com/title/tt0056193/
# 	Avg. Rating: 7.6
# 	# Votes: 86559
# 	Similarity: 0.5361807346343994
#
#
# Helen	2019
# 	https://www.imdb.com/title/tt10735202/
# 	Avg. Rating: 7.8
# 	# Votes: 768
# 	Similarity: 0.5361678600311279
#
#
# Three Colors: Red	1994
# 	https://www.imdb.com/title/tt0111495/
# 	Avg. Rating: 8.1
# 	# Votes: 83250
# 	Similarity: 0.535943865776062
#
#
# The Bridge on the River Kwai	1957
# 	https://www.imdb.com/title/tt0050212/
# 	Avg. Rating: 8.1
# 	# Votes: 191813
# 	Similarity: 0.5357310175895691
#
#
# Malcolm	1986
# 	https://www.imdb.com/title/tt0091464/
# 	Avg. Rating: 7.3
# 	# Votes: 1916
# 	Similarity: 0.535677969455719
#
#
# Notes on Blindness	2016
# 	https://www.imdb.com/title/tt5117222/
# 	Avg. Rating: 7.1
# 	# Votes: 1780
# 	Similarity: 0.5355486869812012
#
#
# The Color of Lies	1999
# 	https://www.imdb.com/title/tt0164368/
# 	Avg. Rating: 6.8
# 	# Votes: 1903
# 	Similarity: 0.5353745818138123
#
#
# Star Wars: Episode VI - Return of the Jedi	1983
# 	https://www.imdb.com/title/tt0086190/
# 	Avg. Rating: 8.3
# 	# Votes: 898549
# 	Similarity: 0.5352219343185425
#
#
# Yeh Dillagi	1994
# 	https://www.imdb.com/title/tt0111793/
# 	Avg. Rating: 6.0
# 	# Votes: 4170
# 	Similarity: 0.5349066257476807
#
#
# Clerks	1994
# 	https://www.imdb.com/title/tt0109445/
# 	Avg. Rating: 7.7
# 	# Votes: 205368
# 	Similarity: 0.5349044799804688
#
#
# Mera Naam Joker	1970
# 	https://www.imdb.com/title/tt0066070/
# 	Avg. Rating: 8.0
# 	# Votes: 4331
# 	Similarity: 0.5345728993415833
#
#
# Belushi's Toilet	2018
# 	https://www.imdb.com/title/tt8159764/
# 	Avg. Rating: 6.6
# 	# Votes: 45
# 	Similarity: 0.5344399213790894
#
#
# Simshar	2014
# 	https://www.imdb.com/title/tt2521700/
# 	Avg. Rating: 6.7
# 	# Votes: 259
# 	Similarity: 0.5342093706130981
#
#
# Collateral	2004
# 	https://www.imdb.com/title/tt0369339/
# 	Avg. Rating: 7.5
# 	# Votes: 342795
# 	Similarity: 0.5341583490371704
#
#
# Gabbeh	1996
# 	https://www.imdb.com/title/tt0116384/
# 	Avg. Rating: 6.9
# 	# Votes: 2836
# 	Similarity: 0.5339854955673218
#
#
# Nannaku Prematho	2016
# 	https://www.imdb.com/title/tt5098128/
# 	Avg. Rating: 7.6
# 	# Votes: 8359
# 	Similarity: 0.5339288115501404
#
#
# NGK	2019
# 	https://www.imdb.com/title/tt8094252/
# 	Avg. Rating: 6.0
# 	# Votes: 2898
# 	Similarity: 0.53377366065979
#
#
# Alaap	1977
# 	https://www.imdb.com/title/tt0075653/
# 	Avg. Rating: 6.9
# 	# Votes: 291
# 	Similarity: 0.5337088108062744
#
#
# The Hunt	2012
# 	https://www.imdb.com/title/tt2106476/
# 	Avg. Rating: 8.3
# 	# Votes: 254689
# 	Similarity: 0.5335112810134888
#
#
# The Snows of Kilimanjaro	2011
# 	https://www.imdb.com/title/tt1852006/
# 	Avg. Rating: 7.2
# 	# Votes: 3489
# 	Similarity: 0.533380389213562
#
#
# Anomalisa	2015
# 	https://www.imdb.com/title/tt2401878/
# 	Avg. Rating: 7.3
# 	# Votes: 60707
# 	Similarity: 0.5333337783813477
#
#
# The Son	2002
# 	https://www.imdb.com/title/tt0291172/
# 	Avg. Rating: 7.6
# 	# Votes: 8543
# 	Similarity: 0.5332191586494446
#
#
# Birdwatchers	2008
# 	https://www.imdb.com/title/tt1054674/
# 	Avg. Rating: 6.8
# 	# Votes: 793
# 	Similarity: 0.532805323600769
#
#
# Au Hasard Balthazar	1966
# 	https://www.imdb.com/title/tt0060138/
# 	Avg. Rating: 7.9
# 	# Votes: 16034
# 	Similarity: 0.5327616930007935
#
#
# The Lighthouse	2019
# 	https://www.imdb.com/title/tt7984734/
# 	Avg. Rating: 7.8
# 	# Votes: 52091
# 	Similarity: 0.5326799154281616
#
#
# Carlito's Way	1993
# 	https://www.imdb.com/title/tt0106519/
# 	Avg. Rating: 7.9
# 	# Votes: 190350
# 	Similarity: 0.5326592326164246
#
#
# Unbreakable	2000
# 	https://www.imdb.com/title/tt0217869/
# 	Avg. Rating: 7.3
# 	# Votes: 368660
# 	Similarity: 0.532440721988678
#
#
# Man Is Not a Bird	1965
# 	https://www.imdb.com/title/tt0059063/
# 	Avg. Rating: 7.2
# 	# Votes: 961
# 	Similarity: 0.5322214365005493
#
#
# Miller's Crossing	1990
# 	https://www.imdb.com/title/tt0100150/
# 	Avg. Rating: 7.8
# 	# Votes: 120744
# 	Similarity: 0.5321580171585083
#
#
# PK	2014
# 	https://www.imdb.com/title/tt2338151/
# 	Avg. Rating: 8.1
# 	# Votes: 146230
# 	Similarity: 0.5317857265472412
#
#
# Waking Life	2001
# 	https://www.imdb.com/title/tt0243017/
# 	Avg. Rating: 7.8
# 	# Votes: 58367
# 	Similarity: 0.5317608714103699
#
#
# The Long Day Closes	1992
# 	https://www.imdb.com/title/tt0104753/
# 	Avg. Rating: 7.4
# 	# Votes: 2541
# 	Similarity: 0.531650185585022
#
#
# Bottle Rocket	1996
# 	https://www.imdb.com/title/tt0115734/
# 	Avg. Rating: 7.0
# 	# Votes: 65940
# 	Similarity: 0.5316286087036133
#
#
# Bombay Talkies	2013
# 	https://www.imdb.com/title/tt2797242/
# 	Avg. Rating: 6.7
# 	# Votes: 4646
# 	Similarity: 0.531588613986969
#
#
# Joker	2019
# 	https://www.imdb.com/title/tt7286456/
# 	Avg. Rating: 8.6
# 	# Votes: 620299
# 	Similarity: 0.531562864780426
#
#
# The Texture of Falling	2018
# 	https://www.imdb.com/title/tt4631048/
# 	Avg. Rating: 6.7
# 	# Votes: 1198
# 	Similarity: 0.5313209295272827
#
#
# Butch Cassidy and the Sundance Kid	1969
# 	https://www.imdb.com/title/tt0064115/
# 	Avg. Rating: 8.0
# 	# Votes: 192998
# 	Similarity: 0.5313051342964172
#
#
# Some Like It Hot	1959
# 	https://www.imdb.com/title/tt0053291/
# 	Avg. Rating: 8.2
# 	# Votes: 228904
# 	Similarity: 0.5311051607131958
#
#
# The Killing	1956
# 	https://www.imdb.com/title/tt0049406/
# 	Avg. Rating: 8.0
# 	# Votes: 76183
# 	Similarity: 0.53108811378479
#
#
# Three Billboards Outside Ebbing, Missouri	2017
# 	https://www.imdb.com/title/tt5027774/
# 	Avg. Rating: 8.2
# 	# Votes: 377394
# 	Similarity: 0.5307589769363403
#
#
# Fighting Elegy	1966
# 	https://www.imdb.com/title/tt0060586/
# 	Avg. Rating: 7.0
# 	# Votes: 1246
# 	Similarity: 0.5306190848350525
#
#
# The Devil's Eye	1960
# 	https://www.imdb.com/title/tt0053772/
# 	Avg. Rating: 7.2
# 	# Votes: 3249
# 	Similarity: 0.5304814577102661
#
#
# Paths of Glory	1957
# 	https://www.imdb.com/title/tt0050825/
# 	Avg. Rating: 8.4
# 	# Votes: 163638
# 	Similarity: 0.5302985310554504
#
#
# Cold War	2018
# 	https://www.imdb.com/title/tt6543652/
# 	Avg. Rating: 7.6
# 	# Votes: 40124
# 	Similarity: 0.5302842259407043
#
#
# The Missionary	1982
# 	https://www.imdb.com/title/tt0083449/
# 	Avg. Rating: 6.2
# 	# Votes: 1951
# 	Similarity: 0.5300086736679077
#
#
# Viridiana	1961
# 	https://www.imdb.com/title/tt0055601/
# 	Avg. Rating: 8.2
# 	# Votes: 20482
# 	Similarity: 0.5299496650695801
#
#
# The Intruder	2004
# 	https://www.imdb.com/title/tt0422491/
# 	Avg. Rating: 6.9
# 	# Votes: 1620
# 	Similarity: 0.5298723578453064
#
#
# Sweetie	1989
# 	https://www.imdb.com/title/tt0098725/
# 	Avg. Rating: 6.8
# 	# Votes: 3092
# 	Similarity: 0.5298367738723755
#
#
# Rahasya	2015
# 	https://www.imdb.com/title/tt3337550/
# 	Avg. Rating: 7.6
# 	# Votes: 4074
# 	Similarity: 0.5296788215637207
#
#
# Dead Poets Society	1989
# 	https://www.imdb.com/title/tt0097165/
# 	Avg. Rating: 8.1
# 	# Votes: 388885
# 	Similarity: 0.529569149017334
#
#
# Nayak: The Hero	1966
# 	https://www.imdb.com/title/tt0060742/
# 	Avg. Rating: 8.3
# 	# Votes: 2807
# 	Similarity: 0.5295626521110535
#
#
# A Story from Chikamatsu	1954
# 	https://www.imdb.com/title/tt0046851/
# 	Avg. Rating: 8.0
# 	# Votes: 3332
# 	Similarity: 0.5295523405075073
#
#
# Elephants	2018
# 	https://www.imdb.com/title/tt7125498/
# 	Avg. Rating: 5.9
# 	# Votes: 270
# 	Similarity: 0.5293521881103516
#
#
# The Firemen's Ball	1967
# 	https://www.imdb.com/title/tt0061781/
# 	Avg. Rating: 7.5
# 	# Votes: 8519
# 	Similarity: 0.5292705297470093
#
#
# Delicatessen	1991
# 	https://www.imdb.com/title/tt0101700/
# 	Avg. Rating: 7.6
# 	# Votes: 76784
# 	Similarity: 0.528974175453186
#
#
# Donnie Brasco	1997
# 	https://www.imdb.com/title/tt0119008/
# 	Avg. Rating: 7.7
# 	# Votes: 261485
# 	Similarity: 0.5289477109909058
#
#
# Ugly	2013
# 	https://www.imdb.com/title/tt2882328/
# 	Avg. Rating: 8.1
# 	# Votes: 17813
# 	Similarity: 0.5282229781150818
#
#
# 7th Day	2014
# 	https://www.imdb.com/title/tt3661988/
# 	Avg. Rating: 6.9
# 	# Votes: 2007
# 	Similarity: 0.528076171875
#
#
# Summer	1986
# 	https://www.imdb.com/title/tt0091830/
# 	Avg. Rating: 7.7
# 	# Votes: 5707
# 	Similarity: 0.5279710292816162
#
#
# Mystic River	2003
# 	https://www.imdb.com/title/tt0327056/
# 	Avg. Rating: 7.9
# 	# Votes: 398506
# 	Similarity: 0.5279616713523865
#
#
# Battleship Potemkin	1925
# 	https://www.imdb.com/title/tt0015648/
# 	Avg. Rating: 8.0
# 	# Votes: 49696
# 	Similarity: 0.5274505615234375
#
#
# Magamuni	2019
# 	https://www.imdb.com/title/tt10370932/
# 	Avg. Rating: 8.0
# 	# Votes: 1094
# 	Similarity: 0.5272719860076904
#
#
# Transition	2018
# 	https://www.imdb.com/title/tt5212488/
# 	Avg. Rating: 4.8
# 	# Votes: 95
# 	Similarity: 0.5272431373596191
#
#
# The Battle of Algiers	1966
# 	https://www.imdb.com/title/tt0058946/
# 	Avg. Rating: 8.1
# 	# Votes: 48994
# 	Similarity: 0.5270477533340454
#
#
# Tokyo Drifter	1966
# 	https://www.imdb.com/title/tt0061101/
# 	Avg. Rating: 7.2
# 	# Votes: 6855
# 	Similarity: 0.5268803834915161
#
#
# Bonnie and Clyde	1967
# 	https://www.imdb.com/title/tt0061418/
# 	Avg. Rating: 7.8
# 	# Votes: 97109
# 	Similarity: 0.526802122592926
#
#
# Shame	2011
# 	https://www.imdb.com/title/tt1723811/
# 	Avg. Rating: 7.2
# 	# Votes: 175304
# 	Similarity: 0.5264766216278076
#
#
# Hey Ram	2000
# 	https://www.imdb.com/title/tt0222012/
# 	Avg. Rating: 7.9
# 	# Votes: 10654
# 	Similarity: 0.5263786315917969
#
#
# Die Nibelungen: Kriemhild's Revenge	1924
# 	https://www.imdb.com/title/tt0015174/
# 	Avg. Rating: 8.0
# 	# Votes: 3680
# 	Similarity: 0.5259193778038025
#
#
# Will & Liz	2018
# 	https://www.imdb.com/title/tt6796028/
# 	Avg. Rating: 6.0
# 	# Votes: 160
# 	Similarity: 0.5258327722549438
#
#
# La Ciénaga	2001
# 	https://www.imdb.com/title/tt0240419/
# 	Avg. Rating: 7.1
# 	# Votes: 4937
# 	Similarity: 0.5249642133712769
#
#
# 12
# 20
# 63
# 117
# The model recommended 31 movies that were on the watchlist!
#
# 		 Average Rating: 7.497435897435897
#
# Schindler's List	1993
# 	https://www.imdb.com/title/tt0108052/
# 	Avg. Rating: 8.9
# 	# Votes: 1138968
# 	Similarity: 0.620111346244812
#
#
# One Flew Over the Cuckoo's Nest	1975
# 	https://www.imdb.com/title/tt0073486/
# 	Avg. Rating: 8.7
# 	# Votes: 860775
# 	Similarity: 0.6048362255096436
#
#
# The Last Supper	1976
# 	https://www.imdb.com/title/tt0075363/
# 	Avg. Rating: 7.5
# 	# Votes: 518
# 	Similarity: 0.5973092317581177
#
#
# Pan's Labyrinth	2006
# 	https://www.imdb.com/title/tt0457430/
# 	Avg. Rating: 8.2
# 	# Votes: 588428
# 	Similarity: 0.5969406962394714
#
#
# Star Wars: Episode IV - A New Hope	1977
# 	https://www.imdb.com/title/tt0076759/
# 	Avg. Rating: 8.6
# 	# Votes: 1168067
# 	Similarity: 0.5955407619476318
#
#
# 78/52: Hitchcock's Shower Scene	2017
# 	https://www.imdb.com/title/tt4372240/
# 	Avg. Rating: 7.3
# 	# Votes: 2652
# 	Similarity: 0.5904014706611633
#
#
# American Psycho	2000
# 	https://www.imdb.com/title/tt0144084/
# 	Avg. Rating: 7.6
# 	# Votes: 450780
# 	Similarity: 0.58875972032547
#
#
# Casino	1995
# 	https://www.imdb.com/title/tt0112641/
# 	Avg. Rating: 8.2
# 	# Votes: 432378
# 	Similarity: 0.5879273414611816
#
#
# Heat	1995
# 	https://www.imdb.com/title/tt0113277/
# 	Avg. Rating: 8.2
# 	# Votes: 541306
# 	Similarity: 0.5833345055580139
#
#
# Raatchasi	2019
# 	https://www.imdb.com/title/tt10431010/
# 	Avg. Rating: 7.3
# 	# Votes: 589
# 	Similarity: 0.5811085104942322
#
#
# Star Wars: Episode V - The Empire Strikes Back	1980
# 	https://www.imdb.com/title/tt0080684/
# 	Avg. Rating: 8.7
# 	# Votes: 1095881
# 	Similarity: 0.5763970017433167
#
#
# Aliens	1986
# 	https://www.imdb.com/title/tt0090605/
# 	Avg. Rating: 8.3
# 	# Votes: 619790
# 	Similarity: 0.5761480927467346
#
#
# Trainspotting	1996
# 	https://www.imdb.com/title/tt0117951/
# 	Avg. Rating: 8.1
# 	# Votes: 606132
# 	Similarity: 0.5761249661445618
#
#
# Brother	2010
# 	https://www.imdb.com/title/tt1588358/
# 	Avg. Rating: 7.3
# 	# Votes: 2413
# 	Similarity: 0.5741573572158813
#
#
# 12 Monkeys	1995
# 	https://www.imdb.com/title/tt0114746/
# 	Avg. Rating: 8.0
# 	# Votes: 551324
# 	Similarity: 0.573866069316864
#
#
# Chinatown	1974
# 	https://www.imdb.com/title/tt0071315/
# 	Avg. Rating: 8.2
# 	# Votes: 275306
# 	Similarity: 0.573837161064148
#
#
# Mommy	2014
# 	https://www.imdb.com/title/tt3612616/
# 	Avg. Rating: 8.1
# 	# Votes: 45282
# 	Similarity: 0.5701632499694824
#
#
# Ravening	2019
# 	https://www.imdb.com/title/tt9010522/
# 	Avg. Rating: 8.5
# 	# Votes: 195
# 	Similarity: 0.5660020709037781
#
#
# Eyes Wide Shut	1999
# 	https://www.imdb.com/title/tt0120663/
# 	Avg. Rating: 7.4
# 	# Votes: 282165
# 	Similarity: 0.5659576654434204
#
#
# Birdman or (The Unexpected Virtue of Ignorance)	2014
# 	https://www.imdb.com/title/tt2562232/
# 	Avg. Rating: 7.7
# 	# Votes: 541750
# 	Similarity: 0.5659047365188599
#
#
# Aruvi	2016
# 	https://www.imdb.com/title/tt5867800/
# 	Avg. Rating: 8.7
# 	# Votes: 9036
# 	Similarity: 0.5642490386962891
#
#
# Minority Report	2002
# 	https://www.imdb.com/title/tt0181689/
# 	Avg. Rating: 7.6
# 	# Votes: 482321
# 	Similarity: 0.5635637044906616
#
#
# Color Me Kubrick	2005
# 	https://www.imdb.com/title/tt0376543/
# 	Avg. Rating: 6.1
# 	# Votes: 6142
# 	Similarity: 0.5633829832077026
#
#
# Madeline's Madeline	2018
# 	https://www.imdb.com/title/tt6101602/
# 	Avg. Rating: 6.4
# 	# Votes: 2909
# 	Similarity: 0.5605792999267578
#
#
# Star Wars: Episode VI - Return of the Jedi	1983
# 	https://www.imdb.com/title/tt0086190/
# 	Avg. Rating: 8.3
# 	# Votes: 898549
# 	Similarity: 0.5601937770843506
#
#
# Dog Park	2017
# 	https://www.imdb.com/title/tt7070486/
# 	Avg. Rating: 6.3
# 	# Votes: 59
# 	Similarity: 0.5595104098320007
#
#
# Spotlight	2015
# 	https://www.imdb.com/title/tt1895587/
# 	Avg. Rating: 8.1
# 	# Votes: 384276
# 	Similarity: 0.5580727458000183
#
#
# It's a Wonderful Life	1946
# 	https://www.imdb.com/title/tt0038650/
# 	Avg. Rating: 8.6
# 	# Votes: 374566
# 	Similarity: 0.5574659109115601
#
#
# The Elephant Man	1980
# 	https://www.imdb.com/title/tt0080678/
# 	Avg. Rating: 8.1
# 	# Votes: 206385
# 	Similarity: 0.5573829412460327
#
#
# Widow	2009
# 	https://www.imdb.com/title/tt1508702/
# 	Avg. Rating: 5.3
# 	# Votes: 46
# 	Similarity: 0.5572619438171387
#
#
# Zodiac	2007
# 	https://www.imdb.com/title/tt0443706/
# 	Avg. Rating: 7.7
# 	# Votes: 413991
# 	Similarity: 0.5564044117927551
#
#
# Shanghai	2012
# 	https://www.imdb.com/title/tt2072227/
# 	Avg. Rating: 7.2
# 	# Votes: 9203
# 	Similarity: 0.5552530288696289
#
#
# Love Affair, or The Case of the Missing Switchboard Operator	1967
# 	https://www.imdb.com/title/tt0061912/
# 	Avg. Rating: 7.4
# 	# Votes: 1394
# 	Similarity: 0.5551630258560181
#
#
# PK	2014
# 	https://www.imdb.com/title/tt2338151/
# 	Avg. Rating: 8.1
# 	# Votes: 146230
# 	Similarity: 0.5543863773345947
#
#
# Joker	2019
# 	https://www.imdb.com/title/tt7286456/
# 	Avg. Rating: 8.6
# 	# Votes: 620299
# 	Similarity: 0.5540702939033508
#
#
# Thanneermathan Dinangal	2019
# 	https://www.imdb.com/title/tt10551608/
# 	Avg. Rating: 8.1
# 	# Votes: 1465
# 	Similarity: 0.5536260604858398
#
#
# Alaap	1977
# 	https://www.imdb.com/title/tt0075653/
# 	Avg. Rating: 6.9
# 	# Votes: 291
# 	Similarity: 0.5535461902618408
#
#
# NGK	2019
# 	https://www.imdb.com/title/tt8094252/
# 	Avg. Rating: 6.0
# 	# Votes: 2898
# 	Similarity: 0.5532083511352539
#
#
# People Places Things	2015
# 	https://www.imdb.com/title/tt4104022/
# 	Avg. Rating: 6.9
# 	# Votes: 7685
# 	Similarity: 0.5528428554534912
#
#
# 13th	2016
# 	https://www.imdb.com/title/tt5895028/
# 	Avg. Rating: 8.2
# 	# Votes: 21078
# 	Similarity: 0.5527060031890869
#
#
# Collateral	2004
# 	https://www.imdb.com/title/tt0369339/
# 	Avg. Rating: 7.5
# 	# Votes: 342795
# 	Similarity: 0.5526881814002991
#
#
# Erasing Eden	2016
# 	https://www.imdb.com/title/tt2516326/
# 	Avg. Rating: 5.1
# 	# Votes: 347
# 	Similarity: 0.5505724549293518
#
#
# Prisoners	2013
# 	https://www.imdb.com/title/tt1392214/
# 	Avg. Rating: 8.1
# 	# Votes: 550504
# 	Similarity: 0.549480140209198
#
#
# The Agronomist	2003
# 	https://www.imdb.com/title/tt0377031/
# 	Avg. Rating: 7.4
# 	# Votes: 868
# 	Similarity: 0.5493896007537842
#
#
# Sarbjit	2016
# 	https://www.imdb.com/title/tt5120640/
# 	Avg. Rating: 7.3
# 	# Votes: 3811
# 	Similarity: 0.5493754148483276
#
#
# Sawdust and Tinsel	1953
# 	https://www.imdb.com/title/tt0045848/
# 	Avg. Rating: 7.6
# 	# Votes: 5550
# 	Similarity: 0.548999547958374
#
#
# I Am Kalam	2010
# 	https://www.imdb.com/title/tt1805263/
# 	Avg. Rating: 8.0
# 	# Votes: 3233
# 	Similarity: 0.5489343404769897
#
#
# Brothers	2015
# 	https://www.imdb.com/title/tt3802576/
# 	Avg. Rating: 6.5
# 	# Votes: 10960
# 	Similarity: 0.5486569404602051
#
#
# Yeh Dillagi	1994
# 	https://www.imdb.com/title/tt0111793/
# 	Avg. Rating: 6.0
# 	# Votes: 4170
# 	Similarity: 0.5482895970344543
#
#
# General Idi Amin Dada: A Self Portrait	1974
# 	https://www.imdb.com/title/tt0071544/
# 	Avg. Rating: 7.4
# 	# Votes: 1555
# 	Similarity: 0.5480591654777527
#
#
# The Killing of a Sacred Deer	2017
# 	https://www.imdb.com/title/tt5715874/
# 	Avg. Rating: 7.0
# 	# Votes: 100970
# 	Similarity: 0.5480582118034363
#
#
# Life Is Beautiful	1997
# 	https://www.imdb.com/title/tt0118799/
# 	Avg. Rating: 8.6
# 	# Votes: 577812
# 	Similarity: 0.5478096008300781
#
#
# Mulholland Dr.	2001
# 	https://www.imdb.com/title/tt0166924/
# 	Avg. Rating: 7.9
# 	# Votes: 299680
# 	Similarity: 0.5477514266967773
#
#
# The Texture of Falling	2018
# 	https://www.imdb.com/title/tt4631048/
# 	Avg. Rating: 6.7
# 	# Votes: 1198
# 	Similarity: 0.5475221872329712
#
#
# Amores Perros	2000
# 	https://www.imdb.com/title/tt0245712/
# 	Avg. Rating: 8.1
# 	# Votes: 212203
# 	Similarity: 0.5471383333206177
#
#
# Pelli Choopulu	2016
# 	https://www.imdb.com/title/tt5824826/
# 	Avg. Rating: 8.3
# 	# Votes: 4624
# 	Similarity: 0.5470821857452393
#
#
# Sunset Blvd.	1950
# 	https://www.imdb.com/title/tt0043014/
# 	Avg. Rating: 8.4
# 	# Votes: 186742
# 	Similarity: 0.5468763113021851
#
#
# Helen	2019
# 	https://www.imdb.com/title/tt10735202/
# 	Avg. Rating: 7.8
# 	# Votes: 768
# 	Similarity: 0.5468447804450989
#
#
# Nanban	2012
# 	https://www.imdb.com/title/tt2180477/
# 	Avg. Rating: 7.4
# 	# Votes: 10776
# 	Similarity: 0.5465495586395264
#
#
# 7th Day	2014
# 	https://www.imdb.com/title/tt3661988/
# 	Avg. Rating: 6.9
# 	# Votes: 2007
# 	Similarity: 0.5464684963226318
#
#
# Clerks	1994
# 	https://www.imdb.com/title/tt0109445/
# 	Avg. Rating: 7.7
# 	# Votes: 205368
# 	Similarity: 0.546133279800415
#
#
# Whitey: United States of America v. James J. Bulger	2014
# 	https://www.imdb.com/title/tt3326366/
# 	Avg. Rating: 6.8
# 	# Votes: 2787
# 	Similarity: 0.5458626747131348
#
#
# 1 Nighter	2012
# 	https://www.imdb.com/title/tt1327196/
# 	Avg. Rating: 6.2
# 	# Votes: 58
# 	Similarity: 0.5456705689430237
#
#
# Are You Glad I'm Here	2018
# 	https://www.imdb.com/title/tt6891516/
# 	Avg. Rating: 7.7
# 	# Votes: 70
# 	Similarity: 0.5455784201622009
#
#
# Elephants	2018
# 	https://www.imdb.com/title/tt7125498/
# 	Avg. Rating: 5.9
# 	# Votes: 270
# 	Similarity: 0.5449709892272949
#
#
# Simshar	2014
# 	https://www.imdb.com/title/tt2521700/
# 	Avg. Rating: 6.7
# 	# Votes: 259
# 	Similarity: 0.544494092464447
#
#
# The Hunt	2012
# 	https://www.imdb.com/title/tt2106476/
# 	Avg. Rating: 8.3
# 	# Votes: 254689
# 	Similarity: 0.5442267656326294
#
#
# The Devil, Probably	1977
# 	https://www.imdb.com/title/tt0075938/
# 	Avg. Rating: 7.3
# 	# Votes: 3150
# 	Similarity: 0.5439483523368835
#
#
# Wheel of Time	2003
# 	https://www.imdb.com/title/tt0331080/
# 	Avg. Rating: 7.1
# 	# Votes: 2067
# 	Similarity: 0.5428864359855652
#
#
# Chashme Buddoor	1981
# 	https://www.imdb.com/title/tt0082162/
# 	Avg. Rating: 8.0
# 	# Votes: 2069
# 	Similarity: 0.5428556203842163
#
#
# The Handmaiden	2016
# 	https://www.imdb.com/title/tt4016934/
# 	Avg. Rating: 8.1
# 	# Votes: 89960
# 	Similarity: 0.5426472425460815
#
#
# His Girl Friday	1940
# 	https://www.imdb.com/title/tt0032599/
# 	Avg. Rating: 7.9
# 	# Votes: 50020
# 	Similarity: 0.5418115258216858
#
#
# Hello & Goodbye	2018
# 	https://www.imdb.com/title/tt3100938/
# 	Avg. Rating: 7.1
# 	# Votes: 39
# 	Similarity: 0.5411219596862793
#
#
# Waking Life	2001
# 	https://www.imdb.com/title/tt0243017/
# 	Avg. Rating: 7.8
# 	# Votes: 58367
# 	Similarity: 0.5407013893127441
#
#
# Unbreakable	2000
# 	https://www.imdb.com/title/tt0217869/
# 	Avg. Rating: 7.3
# 	# Votes: 368660
# 	Similarity: 0.5406123995780945
#
#
# Easy Rider	1969
# 	https://www.imdb.com/title/tt0064276/
# 	Avg. Rating: 7.3
# 	# Votes: 93567
# 	Similarity: 0.5403963923454285
#
#
# Transition	2018
# 	https://www.imdb.com/title/tt5212488/
# 	Avg. Rating: 4.8
# 	# Votes: 95
# 	Similarity: 0.5402605533599854
#
#
# Mere Dad Ki Maruti	2013
# 	https://www.imdb.com/title/tt2323964/
# 	Avg. Rating: 6.4
# 	# Votes: 4249
# 	Similarity: 0.5402017831802368
#
#
# Dawn of the Planet of the Apes	2014
# 	https://www.imdb.com/title/tt2103281/
# 	Avg. Rating: 7.6
# 	# Votes: 398329
# 	Similarity: 0.5401442646980286
#
#
# Werckmeister Harmonies	2000
# 	https://www.imdb.com/title/tt0249241/
# 	Avg. Rating: 8.2
# 	# Votes: 11693
# 	Similarity: 0.539931058883667
#
#
# Flirting	1991
# 	https://www.imdb.com/title/tt0101898/
# 	Avg. Rating: 7.2
# 	# Votes: 5472
# 	Similarity: 0.5399230122566223
#
#
# Carlito's Way	1993
# 	https://www.imdb.com/title/tt0106519/
# 	Avg. Rating: 7.9
# 	# Votes: 190350
# 	Similarity: 0.5399076342582703
#
#
# Nannaku Prematho	2016
# 	https://www.imdb.com/title/tt5098128/
# 	Avg. Rating: 7.6
# 	# Votes: 8359
# 	Similarity: 0.5397745370864868
#
#
# Vaaranam Aayiram	2008
# 	https://www.imdb.com/title/tt1180583/
# 	Avg. Rating: 8.0
# 	# Votes: 7896
# 	Similarity: 0.5396522879600525
#
#
# Lucknow Central	2017
# 	https://www.imdb.com/title/tt5697870/
# 	Avg. Rating: 6.2
# 	# Votes: 2331
# 	Similarity: 0.5391293168067932
#
#
# Coco	2017
# 	https://www.imdb.com/title/tt2380307/
# 	Avg. Rating: 8.4
# 	# Votes: 316533
# 	Similarity: 0.5389779806137085
#
#
# Summer 1993	2017
# 	https://www.imdb.com/title/tt5897636/
# 	Avg. Rating: 7.1
# 	# Votes: 5151
# 	Similarity: 0.5388779640197754
#
#
# 2 States	2014
# 	https://www.imdb.com/title/tt2372678/
# 	Avg. Rating: 6.9
# 	# Votes: 22199
# 	Similarity: 0.5388191938400269
#
#
# Kammara Sambhavam	2018
# 	https://www.imdb.com/title/tt6200656/
# 	Avg. Rating: 7.2
# 	# Votes: 835
# 	Similarity: 0.5381754636764526
#
#
# Jiivi	2019
# 	https://www.imdb.com/title/tt10556036/
# 	Avg. Rating: 7.9
# 	# Votes: 751
# 	Similarity: 0.5375300645828247
#
#
# Will & Liz	2018
# 	https://www.imdb.com/title/tt6796028/
# 	Avg. Rating: 6.0
# 	# Votes: 160
# 	Similarity: 0.5372821092605591
#
#
# Single Slipper Size - 7	2019
# 	https://www.imdb.com/title/tt10370116/
# 	Avg. Rating: 8.7
# 	# Votes: 1340
# 	Similarity: 0.537169873714447
#
#
# The Lobster	2015
# 	https://www.imdb.com/title/tt3464902/
# 	Avg. Rating: 7.2
# 	# Votes: 195345
# 	Similarity: 0.5369387865066528
#
#
# Uyare	2019
# 	https://www.imdb.com/title/tt9271408/
# 	Avg. Rating: 8.1
# 	# Votes: 1594
# 	Similarity: 0.5368098020553589
#
#
# Fighting Elegy	1966
# 	https://www.imdb.com/title/tt0060586/
# 	Avg. Rating: 7.0
# 	# Votes: 1246
# 	Similarity: 0.5366599559783936
#
#
# Anomalisa	2015
# 	https://www.imdb.com/title/tt2401878/
# 	Avg. Rating: 7.3
# 	# Votes: 60707
# 	Similarity: 0.5364645719528198
#
#
# The Snows of Kilimanjaro	2011
# 	https://www.imdb.com/title/tt1852006/
# 	Avg. Rating: 7.2
# 	# Votes: 3489
# 	Similarity: 0.5363576412200928
#
#
# Ente Ummante Peru	2018
# 	https://www.imdb.com/title/tt9118870/
# 	Avg. Rating: 6.7
# 	# Votes: 624
# 	Similarity: 0.5361374616622925
#
#
# Monty Python's Life of Brian	1979
# 	https://www.imdb.com/title/tt0079470/
# 	Avg. Rating: 8.1
# 	# Votes: 346002
# 	Similarity: 0.5361254215240479
#
#
# Butch Cassidy and the Sundance Kid	1969
# 	https://www.imdb.com/title/tt0064115/
# 	Avg. Rating: 8.0
# 	# Votes: 192998
# 	Similarity: 0.5359047651290894
#
#
# Bhoothnath Returns	2014
# 	https://www.imdb.com/title/tt3531852/
# 	Avg. Rating: 6.7
# 	# Votes: 4526
# 	Similarity: 0.535821795463562
#
#
# Belushi's Toilet	2018
# 	https://www.imdb.com/title/tt8159764/
# 	Avg. Rating: 6.6
# 	# Votes: 45
# 	Similarity: 0.5358126163482666
#
#
# The Insider	1999
# 	https://www.imdb.com/title/tt0140352/
# 	Avg. Rating: 7.8
# 	# Votes: 153111
# 	Similarity: 0.5357972979545593
#
#
# Do the Right Thing	1989
# 	https://www.imdb.com/title/tt0097216/
# 	Avg. Rating: 7.9
# 	# Votes: 78577
# 	Similarity: 0.5355852842330933
#
#
# The Life Aquatic with Steve Zissou	2004
# 	https://www.imdb.com/title/tt0362270/
# 	Avg. Rating: 7.3
# 	# Votes: 170437
# 	Similarity: 0.5352904796600342
#
#
# Ice Breaker	2017
# 	https://www.imdb.com/title/tt4497978/
# 	Avg. Rating: 5.5
# 	# Votes: 101
# 	Similarity: 0.5351628065109253
#
#
# Magamuni	2019
# 	https://www.imdb.com/title/tt10370932/
# 	Avg. Rating: 8.0
# 	# Votes: 1094
# 	Similarity: 0.5351254940032959
#
#
# Platoon	1986
# 	https://www.imdb.com/title/tt0091763/
# 	Avg. Rating: 8.1
# 	# Votes: 361945
# 	Similarity: 0.5351106524467468
#
#
# Nerkonda Paarvai	2019
# 	https://www.imdb.com/title/tt9675716/
# 	Avg. Rating: 8.3
# 	# Votes: 4603
# 	Similarity: 0.5349087119102478
#
#
# Donnie Brasco	1997
# 	https://www.imdb.com/title/tt0119008/
# 	Avg. Rating: 7.7
# 	# Votes: 261485
# 	Similarity: 0.5348799228668213
#
#
# Harry Potter and the Sorcerer's Stone	2001
# 	https://www.imdb.com/title/tt0241527/
# 	Avg. Rating: 7.6
# 	# Votes: 592421
# 	Similarity: 0.534804105758667
#
#
# Rocky	1976
# 	https://www.imdb.com/title/tt0075148/
# 	Avg. Rating: 8.1
# 	# Votes: 489203
# 	Similarity: 0.5344809293746948
#
#
# Beyond the Spectrum: Being Taken	2018
# 	https://www.imdb.com/title/tt9342846/
# 	Avg. Rating: 5.9
# 	# Votes: 108
# 	Similarity: 0.5342723727226257
#
#
# Star Wars: Episode VII - The Force Awakens	2015
# 	https://www.imdb.com/title/tt2488496/
# 	Avg. Rating: 7.9
# 	# Votes: 823258
# 	Similarity: 0.5342592597007751
#
#
# A Moment of Innocence	1996
# 	https://www.imdb.com/title/tt0117214/
# 	Avg. Rating: 7.9
# 	# Votes: 2804
# 	Similarity: 0.5340715050697327
#
#
# The Shape of Water	2017
# 	https://www.imdb.com/title/tt5580390/
# 	Avg. Rating: 7.3
# 	# Votes: 334603
# 	Similarity: 0.5340582728385925
#
#
# Ee. Ma. Yau	2018
# 	https://www.imdb.com/title/tt7231194/
# 	Avg. Rating: 8.3
# 	# Votes: 1567
# 	Similarity: 0.5339847207069397
# '\nSettings graded out of 100:\n11... \n12... \n\n\n\n\n'
